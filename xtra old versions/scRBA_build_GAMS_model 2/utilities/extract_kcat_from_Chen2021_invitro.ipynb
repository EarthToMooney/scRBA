# %%
import pandas as pd
import cobra

# %% [markdown]
# #### Get IDs and their mappings

# %%
mModel = cobra.io.load_json_model('../input/MODEL_y834_hvd_v4_rba.json')
rxns_model = [rxn.id for rxn in mModel.reactions]

# %%
df_enz = pd.read_excel('../input/ENZYME_stoich_curation_2021-10-01.xlsx')

# %%
for i in df_enz.index:
    rxnid = df_enz.rxn_src[i]
    if rxnid not in rxns_model:
        continue
    
    rxn = mModel.reactions.get_by_id(rxnid)
    if 'yeastgem.reaction' not in rxn.notes.keys():
        continue
    
    df_enz.loc[i, 'yeastgem.reaction'] = rxn.notes['yeastgem.reaction']

# %% [markdown]
# #### Map to Chen2021 data

# %%
df_kcat1 = pd.read_excel('../input/PARAMS_kapp_Chen2021_kcat.xlsx', sheet_name='BRENDA20210203')
for i in df_kcat1.index:
    yid = df_kcat1.Yeast8_rxn[i]
    if yid[-4:] in ['_fwd', '_rvs']:
        yid = yid[:-4]
        
    df = df_enz[df_enz['yeastgem.reaction'] == yid]
    rxns = ','.join(df.id)
    df_kcat1.loc[i, 'rxn_match'] = rxns

# %%
for i in df_kcat1.rxn_match:
    print(i)
# Out:
# RXN-IPPS_c_FWD-YOR108W,RXN-IPPS_c_FWD-YNL104C_c
# RXN-IPPS_m_FWD-YNL104C_m
# RXN-ALCD2i1_c_FWD-YMR303C
# RXN-ALCD24yi_c_FWD-YMR318C,RXN-ALCD24yi_c_FWD-YCR105W
# RXN-ANPRT_c_FWD-YDR354W
# RXN-ARGTRS_c_FWD-YDR341C
# RXN-ASPK_c_FWD-YER052C
# RXN-ASPTRS_c_FWD-YLL018C
# RXN-CHORM_c_FWD-YPR060C
# RXN-DHFRi_c_FWD-YOR236W_c
# RXN-ENO_c_FWD-YPL281C,RXN-ENO_c_REV-YPL281C,RXN-ENO_c_FWD-YOR393W,RXN-ENO_c_REV-YOR393W,RXN-ENO_c_FWD-YGR254W,RXN-ENO_c_REV-YGR254W,RXN-ENO_c_FWD-YMR323W,RXN-ENO_c_REV-YMR323W,RXN-ENO_c_FWD-YHR174W,RXN-ENO_c_REV-YHR174W
# RXN-FBP_c_FWD-YLR377C
# RXN-DHORDfum_c_FWD-YKL216W
# RXN-GAPD_c_FWD-YJR009C,RXN-GAPD_c_REV-YJR009C,RXN-GAPD_c_FWD-YGR192C,RXN-GAPD_c_REV-YGR192C,RXN-GAPD_c_FWD-YJL052W,RXN-GAPD_c_REV-YJL052W
# RXN-G3PT_c_FWD-YIL053W,RXN-G3PT_c_FWD-YER062C
# RXN-GLYTRS_c_FWD-YPR081C,RXN-GLYTRS_c_FWD-YBR121C
# RXN-METS_c_FWD-YER091C
# RXN-METTRS_c_FWD-MES1ARC1
# RXN-OMPDC_c_FWD-YEL021W
# RXN-PPCK_c_FWD-YKR097W
# RXN-PGK_c_FWD-YCR012W,RXN-PGK_c_REV-YCR012W
# RXN-PGK_c_FWD-YCR012W,RXN-PGK_c_REV-YCR012W
# RXN-PGM_c_FWD-YOR283W,RXN-PGM_c_REV-YOR283W,RXN-PGM_c_FWD-YKL152C,RXN-PGM_c_REV-YKL152C
# RXN-PC_c_FWD-YGL062W,RXN-PC_c_FWD-YBR218C
# RXN-ATPATF1_c_FWD-YDR530C
# RXN-ATPATF2_c_FWD-YCL050C
# RXN-CHOLK_c_FWD-YLR133W
# RXN-CHLPCTD_c_FWD-YGR202C
# RXN-CS_x_FWD-YCR005C
# RXN-CYSTGL_c_FWD-YAL012W
# RXN-CSND_c_FWD-YPR062W
# RXN-DGK1_c_FWD-YDR454C,RXN-DGK1_c_REV-YDR454C
# RXN-DHFRi_m_FWD-YOR236W_m
# RXN-DUTPDP_c_FWD-YBR252W,RXN-DUTPDP_c_FWD-YJR069C
# RXN-FRTT_c_FWD-YPL069C
# RXN-FECPOR_m_FWD-CCP1CYC7,RXN-FECPOR_m_FWD-CCP1CYC1
# RXN-FALDH_c_FWD-YDL168W
# RXN-GALKi_c_FWD-YBR020W
# RXN-GALT_c_FWD-YBR018C
# RXN-GLCGSD_v_FWD-YIL099W
# RXN-GLUDC_c_FWD-YMR250W
# RXN-GF6PTA_c_FWD-YKL104C,RXN-GF6PTA_c_FWD-YMR084W
# RXN-GLUTRS_m_FWD-YOL033W
# RXN-GTHO_c_FWD-GLR1GRX1,RXN-GTHO_c_FWD-GLR1GRX3,RXN-GTHO_c_FWD-GLR1GRX2,RXN-GTHO_c_FWD-GLR1GRX4
# RXN-GTHO_m_FWD-GLR1GRX5
# RXN-GUAD_1_c_FWD-YDL238C
# RXN-GK1_c_FWD-YDR454C
# RXN-GK2_c_FWD-YDR454C,RXN-GK2_c_REV-YDR454C
# RXN-HISTRS_m_FWD-YPR033C_m
#
# RXN-GLYOX_c_FWD-YDR272W
# RXN-GLYOX_m_FWD-YOR040W
# RXN-INDPYRD_c_FWD-YGR087C,RXN-INDPYRD_c_FWD-YLR044C,RXN-INDPYRD_c_FWD-YLR134W
# RXN-PPA_c_FWD-YBR011C
# RXN-ILETRS_m_FWD-YPL040C
# RXN-ALATA_L_m_FWD-YLR089C,RXN-ALATA_L_m_REV-YLR089C
# RXN-THRA2_c_FWD-YEL046C
# RXN-ATHRDHr_c_FWD-YMR226C,RXN-ATHRDHr_c_REV-YMR226C
# RXN-AASADy_c_FWD-LYS25
# RXN-ASNN_c_FWD-YDR321W
# RXN-ASNN_e_FWD-YLR157C,RXN-ASNN_e_FWD-YLR160C,RXN-ASNN_e_FWD-YLR155C,RXN-ASNN_e_FWD-YLR158C
# RXN-LSERDHi_c_FWD-YMR226C
# RXN-LGTHL_c_FWD-YML004C
# RXN-LEUTRS_m_FWD-YLR382C
# RXN-MAN6PI_c_FWD-YER003C,RXN-MAN6PI_c_REV-YER003C
# RXN-NADDP_x_FWD-YGL067W
# RXN-NADK_c_FWD-YJR049C,RXN-NADK_c_FWD-YEL041W
# RXN-NADK_m_FWD-YPL188W,RXN-NADK_m_FWD-YEL041W,RXN-NADK_m_FWD-YJR049C
# RXN-NADS2_n_FWD-YHR074W_n,RXN-NADS2_n_REV-YHR074W_n
# RXN-NADHK1_m_FWD-YPL188W,RXN-NADHK1_m_FWD-YJR049C,RXN-NADHK1_m_FWD-YEL041W
# RXN-NNAM_c_FWD-YGL037C
# RXN-NDPK4_c_FWD-YKL067W
# RXN-NDP3_g_FWD-YEL042W
# RXN-SHSL1_c_FWD-YAL012W,RXN-SHSL1_c_REV-YAL012W,RXN-SHSL1_c_FWD-YML082W,RXN-SHSL1_c_REV-YML082W,RXN-SHSL1_c_FWD-YLL058W,RXN-SHSL1_c_REV-YLL058W
# RXN-PHETRS_c_FWD-FRS12
# RXN-PHETRS_m_FWD-YPR047W
# RXN-PPYRDC_c_FWD-YDR380W
# RXN-PRAIi_c_FWD-YDR007W
# RXN-POLYAO2_c_FWD-YMR020W
# RXN-PNP_c_FWD-YLR209C
# RXN-PYAM5PO_c_FWD-YBR035C
# RXN-PDX5POi_c_FWD-YBR035C,RXN-PDX5POi_c_REV-YBR035C
# RXN-SAM24MT_c_FWD-YML008C
# RXN-SUCR_e_FWD-YIL162W
# RXN-TRDR_c_FWD-YDR353W
# RXN-TRDR_m_FWD-YHR106W
# RXN-THRA_c_FWD-YEL046C
# RXN-THRTRS_m_FWD-YKL194C
# RXN-TYRTRS_m_FWD-YPL097W
# RXN-UAGDP_c_FWD-YDL103C,RXN-UAGDP_c_REV-YDL103C
# RXN-UGLT_c_FWD-YBR018C,RXN-UGLT_c_REV-YBR018C
# RXN-XYLK_c_FWD-YGR194C
# RXN-3OAR40_m_FWD-YKL055C
# RXN-3OAR60_m_FWD-YKL055C
# RXN-3OAR80_m_FWD-YKL055C
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# RXN-URIH_c_FWD-YDR400W

# %%
df_enz[df_enz['yeastgem.reaction'] == 'r_0366']
# Out:
#                         id rxn_src      enz      gpr protein_stoich  \
# 419  RXN-ENO_c_FWD-YPL281C   ENO_c  YPL281C  YPL281C      YPL281C:2
# 420  RXN-ENO_c_REV-YPL281C   ENO_c  YPL281C  YPL281C      YPL281C:2
# 421  RXN-ENO_c_FWD-YOR393W   ENO_c  YOR393W  YOR393W      YOR393W:2
# 422  RXN-ENO_c_REV-YOR393W   ENO_c  YOR393W  YOR393W      YOR393W:2
# 423  RXN-ENO_c_FWD-YGR254W   ENO_c  YGR254W  YGR254W      YGR254W:2
# 424  RXN-ENO_c_REV-YGR254W   ENO_c  YGR254W  YGR254W      YGR254W:2
# 425  RXN-ENO_c_FWD-YMR323W   ENO_c  YMR323W  YMR323W      YMR323W:2
# 426  RXN-ENO_c_REV-YMR323W   ENO_c  YMR323W  YMR323W      YMR323W:2
# 427  RXN-ENO_c_FWD-YHR174W   ENO_c  YHR174W  YHR174W      YHR174W:2
# 428  RXN-ENO_c_REV-YHR174W   ENO_c  YHR174W  YHR174W      YHR174W:2
#
#     subunit_comments              status  MW (g/mmol) yeastgem.reaction
# 419              NaN  protStoichAsgnAuto     98.81816            r_0366
# 420              NaN  protStoichAsgnAuto     98.81816            r_0366
# 421              NaN  protStoichAsgnAuto     98.81816            r_0366
# 422              NaN  protStoichAsgnAuto     98.81816            r_0366
# 423              NaN  protStoichAsgnAuto     99.91134            r_0366
# 424              NaN  protStoichAsgnAuto     99.91134            r_0366
# 425              NaN  protStoichAsgnAuto     98.86432            r_0366
# 426              NaN  protStoichAsgnAuto     98.86432            r_0366
# 427              NaN  protStoichAsgnAuto    100.14178            r_0366
# 428              NaN  protStoichAsgnAuto    100.14178            r_0366

# %%
mModel.reactions.PGI_c.notes
# Out:
# {'Confidence Level': '3', 'yeastgem.reaction': 'r_0467'}
