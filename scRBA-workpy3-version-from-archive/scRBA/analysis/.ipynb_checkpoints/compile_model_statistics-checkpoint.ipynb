# %%
import pandas as pd

import sys
sys.path.append('../build_GAMS_model/')
from custom_functions_scRBA import extract_details_from_rxnid
from custom_functions_scRBA import metabolites_dict_from_reaction_equation_RBA

# %%
df_all = pd.read_excel('../build_GAMS_model/model/RBA_stoichiometry.xlsx')
df_all.index = df_all.id.to_list()

# %% [markdown]
# #### Check reactions and metabolites

# %%
rxns = []; mets = [];
for i in df_all.index:
    tag = i.split('-')[0]
    if tag == 'RXN':
        # Get reactions
        _,rxn,rdir,enz = extract_details_from_rxnid(i)
        rxns.append(rxn)
        
        # Get metabolites
        met_dict = metabolites_dict_from_reaction_equation_RBA(df_all.reaction[i])
        mets += list(met_dict.keys())
        
rxns = sorted(list(set(rxns)))
mets = sorted(list(set(mets)))
mets = [met for met in mets if met not in ['']]

# %%
print('Number of reactions:', len(rxns))
print('Number of metabolites:', len(mets))
# Out:
# Number of reactions: 1888
# Number of metabolites: 1602

# %% [markdown]
# #### Ribosomes
# Nucleus: 80 protein subunits and 4 rRNA subunits<br>
# Michondria: 74 protein subunits and 2 rRNA subunits

# %% [markdown]
# #### Check proteins and enzymes

# %%
with open('../build_GAMS_model/model/RBA_species.txt') as f:
    species = f.read().split('\n')
species = [i[1:-1] for i in species if i not in ['', '/']]

# %%
prots_raw = [i for i in species if i.split('-')[0] == 'PRO']
prots = []
for p in prots_raw:
    if '_' in p:
        comp = p.split('_')[-1]
        p_nocomp = p[:-len(comp)-1]
        prots.append(p_nocomp)
    else:
        prots.append(p)
prots = sorted(list(set(prots)))

enzs_raw = [i for i in species if i.split('-')[0] == 'ENZ']
enzs = []
for e in enzs_raw:
    if '_' in e:
        comp = e.split('_')[-1]
        e_nocomp = e[:-len(comp)-1]
        enzs.append(e_nocomp)
    else:
        enzs.append(e)
enzs = sorted(list(set(enzs)))

# %%
print('Number of proteins:', len(prots))
print('Number of enzymes:', len(enzs))
# Out:
# Number of proteins: 1177
# Number of enzymes: 903

# %%
species
# Out:
# ['BIO-13BDglucan_en',
#  'BIO-16BDglucan_en',
#  'BIO-atp_c',
#  'BIO-ca2_c',
#  'BIO-carb',
#  'BIO-chtn_c',
#  'BIO-coa_c',
#  'BIO-cofactor',
#  'BIO-ctp_c',
#  'BIO-cu2_c',
#  'BIO-datp_c',
#  'BIO-dctp_c',
#  'BIO-dgtp_c',
#  'BIO-dna',
#  'BIO-dttp_c',
#  'BIO-ergst161_rm',
#  'BIO-ergst181_rm',
#  'BIO-ergst_c',
#  'BIO-fad_c',
#  'BIO-fe2_c',
#  'BIO-glycogen_c',
#  'BIO-gtp_c',
#  'BIO-hdca_c',
#  'BIO-hdcea_c',
#  'BIO-hemeA_c',
#  'BIO-ipc_g',
#  'BIO-k_c',
#  'BIO-lipid',
#  'BIO-mannan_c',
#  'BIO-metal',
#  'BIO-mg2_c',
#  'BIO-mn2_c',
#  'BIO-mrna',
#  'BIO-nad_c',
#  'BIO-nadh_c',
#  'BIO-nadp_c',
#  'BIO-nadph_c',
#  'BIO-ocdca_c',
#  'BIO-ocdcea_c',
#  'BIO-pail_c',
#  'BIO-pc_c',
#  'BIO-pe_c',
#  'BIO-pi',
#  'BIO-prot',
#  'BIO-protcyt',
#  'BIO-protdummy',
#  'BIO-protmito',
#  'BIO-protmodeled',
#  'BIO-ps_c',
#  'BIO-ribflv_c',
#  'BIO-rna',
#  'BIO-rrna',
#  'BIO-so4',
#  'BIO-tag_c',
#  'BIO-thf_c',
#  'BIO-thmpp_c',
#  'BIO-tre_c',
#  'BIO-trna',
#  'BIO-utp_c',
#  'BIO-varbiom',
#  'BIO-zn2_c',
#  'ENZ-ACP1CEM1',
#  'ENZ-ACP1MCT1',
#  'ENZ-ALG1314',
#  'ENZ-ATPASECPLXgm',
#  'ENZ-ATPASECPLXvm',
#  'ENZ-ATPSCPLX',
#  'ENZ-CAB3SIS2',
#  'ENZ-CAB3SIS2VHS3',
#  'ENZ-CAB3VHS3',
#  'ENZ-CCP1CYC1',
#  'ENZ-CCP1CYC7',
#  'ENZ-CIR1AIM45',
#  'ENZ-COQCPLX',
#  'ENZ-COX15ARH1YAH1',
#  'ENZ-CPA12',
#  'ENZ-CSG2CSH1',
#  'ENZ-CSG2SUR1',
#  'ENZ-DIT12',
#  'ENZ-DUG23',
#  'ENZ-ERG11NCP1',
#  'ENZ-FAS12',
#  'ENZ-FECOORCPLX1',
#  'ENZ-FECOORCPLX2',
#  'ENZ-FECRq6CPLX',
#  'ENZ-FRS12',
#  'ENZ-GCV123LPD1',
#  'ENZ-GLR1GRX1',
#  'ENZ-GLR1GRX2',
#  'ENZ-GLR1GRX3',
#  'ENZ-GLR1GRX4',
#  'ENZ-GLR1GRX5',
#  'ENZ-GPI14PBN1',
#  'ENZ-GPI18PGA1',
#  'ENZ-GSC1RHO1',
#  'ENZ-GSC2RHO1',
#  'ENZ-GSY1GLG1',
#  'ENZ-GSY1GLG2',
#  'ENZ-GSY2GLG1',
#  'ENZ-GSY2GLG2',
#  'ENZ-GUS1ARC1',
#  'ENZ-HER2PET112GTF1',
#  'ENZ-IDH12',
#  'ENZ-ILV26',
#  'ENZ-KEI1AUR1',
#  'ENZ-KGDCPLX',
#  'ENZ-LCB12',
#  'ENZ-LCB12TSC3',
#  'ENZ-LIP1LAC1',
#  'ENZ-LIP1LAG1',
#  'ENZ-LSC12',
#  'ENZ-LYS25',
#  'ENZ-MES1ARC1',
#  'ENZ-MET16TRX1',
#  'ENZ-MET16TRX2',
#  'ENZ-MET510',
#  'ENZ-MPC12',
#  'ENZ-MPC13',
#  'ENZ-NATACPLX',
#  'ENZ-PDHCPLX',
#  'ENZ-PFK12',
#  'ENZ-PI35P2REGCPLX',
#  'ENZ-PIK1FRQ1',
#  'ENZ-PMT12',
#  'ENZ-PMT13',
#  'ENZ-PMT35',
#  'ENZ-PMT4',
#  'ENZ-PRS12',
#  'ENZ-PRS13',
#  'ENZ-PRS14',
#  'ENZ-PRS25',
#  'ENZ-PRS45',
#  'ENZ-PXA12',
#  'ENZ-RAM12',
#  'ENZ-RER2NUS1',
#  'ENZ-RNR1234',
#  'ENZ-RNR124',
#  'ENZ-SDH1234',
#  'ENZ-SDH9234',
#  'ENZ-SNZ1SNO1',
#  'ENZ-SNZ2SNO1',
#  'ENZ-SNZ3SNO1',
#  'ENZ-SRT1NUS1',
#  'ENZ-TPS123',
#  'ENZ-TPS12TSL1',
#  'ENZ-TRP23',
#  'ENZ-UTR4ADI1',
#  'ENZ-VAC14FIG4',
#  'ENZ-VPS15VPS34',
#  'ENZ-YAL012W',
#  'ENZ-YAL022C',
#  'ENZ-YAL026C',
#  'ENZ-YAL035W',
#  'ENZ-YAL038W',
#  'ENZ-YAL039C',
#  'ENZ-YAL054C_c',
#  'ENZ-YAL060W',
#  'ENZ-YAL061W_c',
#  'ENZ-YAL061W_n',
#  'ENZ-YAL062W',
#  'ENZ-YAR015W',
#  'ENZ-YAR035W',
#  'ENZ-YAR069W-A',
#  'ENZ-YAR071W',
#  'ENZ-YBL011W',
#  'ENZ-YBL013W_c',
#  'ENZ-YBL013W_m',
#  'ENZ-YBL015W',
#  'ENZ-YBL030C',
#  'ENZ-YBL033C',
#  'ENZ-YBL039C',
#  'ENZ-YBL042C',
#  'ENZ-YBL064C',
#  'ENZ-YBL076C',
#  'ENZ-YBL091C',
#  'ENZ-YBL098W',
#  'ENZ-YBR001C',
#  'ENZ-YBR003W',
#  'ENZ-YBR006W',
#  'ENZ-YBR011C',
#  'ENZ-YBR018C',
#  'ENZ-YBR019C',
#  'ENZ-YBR020W',
#  'ENZ-YBR021W',
#  'ENZ-YBR022W',
#  'ENZ-YBR023C',
#  'ENZ-YBR026C',
#  'ENZ-YBR029C',
#  'ENZ-YBR034C',
#  'ENZ-YBR035C',
#  'ENZ-YBR038W',
#  'ENZ-YBR041W',
#  'ENZ-YBR042C',
#  'ENZ-YBR046C',
#  'ENZ-YBR068C',
#  'ENZ-YBR069C',
#  'ENZ-YBR084W',
#  'ENZ-YBR085W',
#  'ENZ-YBR092C',
#  'ENZ-YBR093C',
#  'ENZ-YBR104W',
#  'ENZ-YBR110W',
#  'ENZ-YBR117C',
#  'ENZ-YBR121C',
#  'ENZ-YBR132C',
#  'ENZ-YBR145W',
#  'ENZ-YBR147W_mm',
#  'ENZ-YBR147W_vm',
#  'ENZ-YBR149W',
#  'ENZ-YBR153W',
#  'ENZ-YBR159W',
#  'ENZ-YBR166C',
#  'ENZ-YBR176W',
#  'ENZ-YBR180W',
#  'ENZ-YBR183W',
#  'ENZ-YBR192W',
#  'ENZ-YBR196C',
#  'ENZ-YBR199W',
#  'ENZ-YBR204C',
#  'ENZ-YBR205W',
#  'ENZ-YBR208C',
#  'ENZ-YBR213W',
#  'ENZ-YBR218C',
#  'ENZ-YBR235W',
#  'ENZ-YBR241C',
#  'ENZ-YBR248C',
#  'ENZ-YBR249C',
#  'ENZ-YBR252W',
#  'ENZ-YBR256C',
#  'ENZ-YBR263W',
#  'ENZ-YBR265W',
#  'ENZ-YBR291C',
#  'ENZ-YBR293W',
#  'ENZ-YBR294W',
#  'ENZ-YBR296C',
#  'ENZ-YBR298C',
#  'ENZ-YBR299W',
#  'ENZ-YCL004W',
#  'ENZ-YCL018W',
#  'ENZ-YCL025C',
#  'ENZ-YCL030C',
#  'ENZ-YCL038C',
#  'ENZ-YCL040W',
#  'ENZ-YCL047C',
#  'ENZ-YCL050C',
#  'ENZ-YCL064C',
#  'ENZ-YCL069W',
#  'ENZ-YCR005C',
#  'ENZ-YCR010C',
#  'ENZ-YCR012W',
#  'ENZ-YCR024C',
#  'ENZ-YCR028C',
#  'ENZ-YCR034W',
#  'ENZ-YCR036W',
#  'ENZ-YCR037C',
#  'ENZ-YCR048W',
#  'ENZ-YCR053W',
#  'ENZ-YCR068W',
#  'ENZ-YCR075C',
#  'ENZ-YCR098C',
#  'ENZ-YCR105W',
#  'ENZ-YDL015C',
#  'ENZ-YDL022W',
#  'ENZ-YDL024C',
#  'ENZ-YDL042C',
#  'ENZ-YDL045C',
#  'ENZ-YDL052C',
#  'ENZ-YDL055C',
#  'ENZ-YDL066W',
#  'ENZ-YDL078C',
#  'ENZ-YDL085W',
#  'ENZ-YDL100C',
#  'ENZ-YDL103C',
#  'ENZ-YDL119C',
#  'ENZ-YDL131W',
#  'ENZ-YDL142C',
#  'ENZ-YDL166C',
#  'ENZ-YDL168W',
#  'ENZ-YDL171C',
#  'ENZ-YDL174C',
#  'ENZ-YDL178W',
#  'ENZ-YDL182W',
#  'ENZ-YDL198C',
#  'ENZ-YDL205C',
#  'ENZ-YDL210W',
#  'ENZ-YDL215C',
#  'ENZ-YDL238C',
#  'ENZ-YDL245C',
#  'ENZ-YDL246C',
#  'ENZ-YDL247W',
#  'ENZ-YDR001C',
#  'ENZ-YDR007W',
#  'ENZ-YDR017C',
#  'ENZ-YDR020C',
#  'ENZ-YDR023W',
#  'ENZ-YDR035W',
#  'ENZ-YDR037W',
#  'ENZ-YDR038C',
#  'ENZ-YDR039C',
#  'ENZ-YDR040C',
#  'ENZ-YDR044W',
#  'ENZ-YDR046C',
#  'ENZ-YDR047W',
#  'ENZ-YDR050C',
#  'ENZ-YDR058C',
#  'ENZ-YDR071C',
#  'ENZ-YDR072C',
#  'ENZ-YDR105C',
#  'ENZ-YDR127W',
#  'ENZ-YDR135C',
#  'ENZ-YDR147W',
#  'ENZ-YDR158W',
#  'ENZ-YDR173C',
#  'ENZ-YDR191W',
#  'ENZ-YDR196C',
#  'ENZ-YDR208W_en',
#  'ENZ-YDR208W_n',
#  'ENZ-YDR226W',
#  'ENZ-YDR232W',
#  'ENZ-YDR234W',
#  'ENZ-YDR236C_mm',
#  'ENZ-YDR236C_r',
#  'ENZ-YDR248C',
#  'ENZ-YDR256C',
#  'ENZ-YDR261C',
#  'ENZ-YDR268W',
#  'ENZ-YDR272W',
#  'ENZ-YDR284C',
#  'ENZ-YDR287W',
#  'ENZ-YDR294C',
#  'ENZ-YDR297W',
#  'ENZ-YDR300C',
#  'ENZ-YDR302W',
#  'ENZ-YDR305C',
#  'ENZ-YDR315C',
#  'ENZ-YDR321W',
#  'ENZ-YDR341C',
#  'ENZ-YDR342C',
#  'ENZ-YDR343C',
#  'ENZ-YDR345C',
#  'ENZ-YDR352W',
#  'ENZ-YDR353W',
#  'ENZ-YDR354W',
#  'ENZ-YDR368W',
#  'ENZ-YDR376W',
#  'ENZ-YDR380W',
#  'ENZ-YDR384C',
#  'ENZ-YDR387C',
#  'ENZ-YDR399W',
#  'ENZ-YDR400W',
#  'ENZ-YDR403W',
#  'ENZ-YDR408C',
#  'ENZ-YDR428C',
#  'ENZ-YDR441C',
#  'ENZ-YDR452W',
#  'ENZ-YDR453C',
#  'ENZ-YDR454C',
#  'ENZ-YDR456W',
#  'ENZ-YDR481C',
#  'ENZ-YDR483W',
#  'ENZ-YDR487C',
#  'ENZ-YDR497C',
#  'ENZ-YDR502C',
#  'ENZ-YDR503C',
#  'ENZ-YDR508C',
#  'ENZ-YDR530C',
#  'ENZ-YDR531W',
#  'ENZ-YDR536W',
#  'ENZ-YDR538W',
#  'ENZ-YDR539W',
#  'ENZ-YEL006W',
#  'ENZ-YEL021W',
#  'ENZ-YEL029C',
#  'ENZ-YEL031W',
#  'ENZ-YEL041W',
#  'ENZ-YEL042W',
#  'ENZ-YEL046C',
#  'ENZ-YEL047C',
#  'ENZ-YEL058W',
#  'ENZ-YEL063C',
#  'ENZ-YEL069C',
#  'ENZ-YEL071W',
#  'ENZ-YER003C',
#  'ENZ-YER005W',
#  'ENZ-YER010C',
#  'ENZ-YER014W',
#  'ENZ-YER015W',
#  'ENZ-YER019W_mm',
#  'ENZ-YER019W_rm',
#  'ENZ-YER023W',
#  'ENZ-YER024W',
#  'ENZ-YER026C',
#  'ENZ-YER037W',
#  'ENZ-YER043C',
#  'ENZ-YER052C',
#  'ENZ-YER053C',
#  'ENZ-YER055C',
#  'ENZ-YER056C',
#  'ENZ-YER060W',
#  'ENZ-YER060W-A',
#  'ENZ-YER062C',
#  'ENZ-YER065C',
#  'ENZ-YER069W',
#  'ENZ-YER073W',
#  'ENZ-YER081W',
#  'ENZ-YER091C',
#  'ENZ-YER119C',
#  'ENZ-YER152C',
#  'ENZ-YER163C',
#  'ENZ-YER170W',
#  'ENZ-YER175C',
#  'ENZ-YER183C',
#  'ENZ-YFL001W',
#  'ENZ-YFL011W',
#  'ENZ-YFL017C',
#  'ENZ-YFL030W',
#  'ENZ-YFL045C',
#  'ENZ-YFL053W',
#  'ENZ-YFL054C',
#  'ENZ-YFL055W',
#  'ENZ-YFL058W',
#  'ENZ-YFL060C',
#  'ENZ-YFR025C',
#  'ENZ-YFR044C',
#  'ENZ-YFR047C',
#  'ENZ-YFR053C',
#  'ENZ-YFR055W',
#  'ENZ-YGL001C',
#  'ENZ-YGL008C',
#  'ENZ-YGL009C',
#  'ENZ-YGL012W',
#  'ENZ-YGL026C',
#  'ENZ-YGL037C',
#  'ENZ-YGL040C',
#  'ENZ-YGL055W',
#  'ENZ-YGL062W',
#  'ENZ-YGL063W',
#  'ENZ-YGL067W',
#  'ENZ-YGL077C',
#  'ENZ-YGL084C',
#  'ENZ-YGL104C',
#  'ENZ-YGL125W',
#  'ENZ-YGL142C',
#  'ENZ-YGL148W',
#  'ENZ-YGL184C',
#  'ENZ-YGL186C',
#  'ENZ-YGL202W',
#  'ENZ-YGL205W',
#  'ENZ-YGL224C',
#  'ENZ-YGL225W',
#  'ENZ-YGL234W',
#  'ENZ-YGL248W',
#  'ENZ-YGL253W',
#  'ENZ-YGL255W',
#  'ENZ-YGL256W',
#  'ENZ-YGR007W',
#  'ENZ-YGR010W',
#  'ENZ-YGR019W',
#  'ENZ-YGR043C',
#  'ENZ-YGR055W',
#  'ENZ-YGR060W',
#  'ENZ-YGR061C',
#  'ENZ-YGR065C',
#  'ENZ-YGR087C',
#  'ENZ-YGR088W',
#  'ENZ-YGR094W_c',
#  'ENZ-YGR094W_m',
#  'ENZ-YGR096W',
#  'ENZ-YGR110W',
#  'ENZ-YGR121C',
#  'ENZ-YGR124W',
#  'ENZ-YGR138C',
#  'ENZ-YGR143W',
#  'ENZ-YGR155W',
#  'ENZ-YGR157W',
#  'ENZ-YGR170W',
#  'ENZ-YGR171C',
#  'ENZ-YGR175C',
#  'ENZ-YGR177C',
#  'ENZ-YGR185C',
#  'ENZ-YGR191W',
#  'ENZ-YGR192C',
#  'ENZ-YGR194C',
#  'ENZ-YGR202C',
#  'ENZ-YGR204W',
#  'ENZ-YGR208W',
#  'ENZ-YGR247W',
#  'ENZ-YGR248W',
#  'ENZ-YGR254W',
#  'ENZ-YGR256W',
#  'ENZ-YGR260W',
#  'ENZ-YGR267C',
#  'ENZ-YGR277C',
#  'ENZ-YGR282C',
#  'ENZ-YGR286C',
#  'ENZ-YGR287C',
#  'ENZ-YGR289C',
#  'ENZ-YGR292W',
#  'ENZ-YHL012W',
#  'ENZ-YHL016C',
#  'ENZ-YHL032C',
#  'ENZ-YHL036W',
#  'ENZ-YHR002W',
#  'ENZ-YHR011W',
#  'ENZ-YHR018C',
#  'ENZ-YHR019C',
#  'ENZ-YHR020W',
#  'ENZ-YHR025W',
#  'ENZ-YHR037W',
#  'ENZ-YHR046C',
#  'ENZ-YHR063C',
#  'ENZ-YHR067W',
#  'ENZ-YHR068W',
#  'ENZ-YHR072W',
#  'ENZ-YHR074W_c',
#  'ENZ-YHR074W_n',
#  'ENZ-YHR091C',
#  'ENZ-YHR092C',
#  'ENZ-YHR094C',
#  'ENZ-YHR096C',
#  'ENZ-YHR100C',
#  'ENZ-YHR104W',
#  'ENZ-YHR106W',
#  'ENZ-YHR123W',
#  'ENZ-YHR128W',
#  'ENZ-YHR137W',
#  'ENZ-YHR144C',
#  'ENZ-YHR163W',
#  'ENZ-YHR174W',
#  'ENZ-YHR183W',
#  'ENZ-YHR190W',
#  'ENZ-YHR208W',
#  'ENZ-YHR214W-F',
#  'ENZ-YHR215W',
#  'ENZ-YHR216W',
#  'ENZ-YIL002C',
#  'ENZ-YIL006W',
#  'ENZ-YIL009W',
#  'ENZ-YIL010W',
#  'ENZ-YIL013C',
#  'ENZ-YIL020C',
#  'ENZ-YIL023C',
#  'ENZ-YIL048W',
#  'ENZ-YIL053W',
#  'ENZ-YIL074C',
#  'ENZ-YIL078W',
#  'ENZ-YIL083C',
#  'ENZ-YIL094C',
#  'ENZ-YIL099W',
#  'ENZ-YIL107C',
#  'ENZ-YIL116W',
#  'ENZ-YIL124W_l',
#  'ENZ-YIL124W_r',
#  'ENZ-YIL134W',
#  'ENZ-YIL145C',
#  'ENZ-YIL155C',
#  'ENZ-YIL160C',
#  'ENZ-YIL162W',
#  'ENZ-YIL172C',
#  'ENZ-YIR027C',
#  'ENZ-YIR028W',
#  'ENZ-YIR029W',
#  'ENZ-YIR031C',
#  'ENZ-YIR032C',
#  'ENZ-YIR034C',
#  'ENZ-YJL005W',
#  'ENZ-YJL052W',
#  'ENZ-YJL060W',
#  'ENZ-YJL068C',
#  'ENZ-YJL071W',
#  'ENZ-YJL088W',
#  'ENZ-YJL091C',
#  'ENZ-YJL097W',
#  'ENZ-YJL100W_en',
#  'ENZ-YJL100W_vm',
#  'ENZ-YJL101C',
#  'ENZ-YJL121C',
#  'ENZ-YJL129C',
#  'ENZ-YJL130C',
#  'ENZ-YJL133W',
#  'ENZ-YJL134W',
#  'ENZ-YJL139C',
#  'ENZ-YJL153C',
#  'ENZ-YJL155C',
#  'ENZ-YJL167W',
#  'ENZ-YJL198W',
#  'ENZ-YJL200C',
#  'ENZ-YJL212C',
#  'ENZ-YJL214W',
#  'ENZ-YJL216C',
#  'ENZ-YJL219W',
#  'ENZ-YJL221C',
#  'ENZ-YJR001W',
#  'ENZ-YJR009C',
#  'ENZ-YJR010W',
#  'ENZ-YJR016C',
#  'ENZ-YJR019C',
#  'ENZ-YJR024C',
#  'ENZ-YJR025C',
#  'ENZ-YJR049C',
#  'ENZ-YJR051W',
#  'ENZ-YJR057W',
#  'ENZ-YJR069C',
#  'ENZ-YJR073C',
#  'ENZ-YJR077C',
#  'ENZ-YJR078W',
#  'ENZ-YJR095W',
#  'ENZ-YJR103W',
#  'ENZ-YJR105W',
#  'ENZ-YJR110W',
#  'ENZ-YJR130C',
#  'ENZ-YJR133W',
#  'ENZ-YJR139C',
#  'ENZ-YJR148W',
#  'ENZ-YJR152W',
#  'ENZ-YJR153W',
#  'ENZ-YJR158W',
#  'ENZ-YJR159W',
#  'ENZ-YJR160C',
#  'ENZ-YKL001C',
#  'ENZ-YKL024C_c',
#  'ENZ-YKL024C_n',
#  'ENZ-YKL029C',
#  'ENZ-YKL035W',
#  'ENZ-YKL055C',
#  'ENZ-YKL060C',
#  'ENZ-YKL067W',
#  'ENZ-YKL085W',
#  'ENZ-YKL087C',
#  'ENZ-YKL094W',
#  'ENZ-YKL104C',
#  'ENZ-YKL106W',
#  'ENZ-YKL120W',
#  'ENZ-YKL127W',
#  'ENZ-YKL132C',
#  'ENZ-YKL140W',
#  'ENZ-YKL146W',
#  'ENZ-YKL152C',
#  'ENZ-YKL165C',
#  'ENZ-YKL184W',
#  'ENZ-YKL192C',
#  'ENZ-YKL194C',
#  'ENZ-YKL212W_gm',
#  'ENZ-YKL212W_rm',
#  'ENZ-YKL215C',
#  'ENZ-YKL216W',
#  'ENZ-YKL217W',
#  'ENZ-YKR009C',
#  'ENZ-YKR031C',
#  'ENZ-YKR039W_en',
#  'ENZ-YKR039W_rm',
#  'ENZ-YKR043C',
#  'ENZ-YKR052C',
#  'ENZ-YKR053C',
#  'ENZ-YKR061W',
#  'ENZ-YKR067W_l',
#  'ENZ-YKR067W_rm',
#  'ENZ-YKR069W',
#  'ENZ-YKR080W',
#  'ENZ-YKR089C',
#  'ENZ-YKR097W',
#  'ENZ-YLL012W',
#  'ENZ-YLL015W',
#  'ENZ-YLL018C',
#  'ENZ-YLL028W',
#  'ENZ-YLL031C',
#  'ENZ-YLL043W',
#  'ENZ-YLL048C',
#  'ENZ-YLL052C_en',
#  'ENZ-YLL052C_rm',
#  'ENZ-YLL057C',
#  'ENZ-YLL058W',
#  'ENZ-YLL061W',
#  'ENZ-YLL062C',
#  'ENZ-YLR011W',
#  'ENZ-YLR017W',
#  'ENZ-YLR020C',
#  'ENZ-YLR027C_c',
#  'ENZ-YLR027C_x',
#  'ENZ-YLR028C',
#  'ENZ-YLR044C',
#  'ENZ-YLR056W',
#  'ENZ-YLR058C',
#  'ENZ-YLR070C',
#  'ENZ-YLR081W',
#  'ENZ-YLR089C',
#  'ENZ-YLR092W',
#  'ENZ-YLR100W',
#  'ENZ-YLR109W',
#  'ENZ-YLR130C',
#  'ENZ-YLR133W',
#  'ENZ-YLR134W',
#  'ENZ-YLR138W',
#  'ENZ-YLR142W',
#  'ENZ-YLR146C',
#  'ENZ-YLR153C',
#  'ENZ-YLR155C',
#  'ENZ-YLR157C',
#  'ENZ-YLR158C',
#  'ENZ-YLR160C',
#  'ENZ-YLR172C',
#  'ENZ-YLR174W',
#  'ENZ-YLR180W',
#  'ENZ-YLR189C',
#  'ENZ-YLR209C',
#  'ENZ-YLR231C',
#  'ENZ-YLR237W',
#  'ENZ-YLR239C',
#  'ENZ-YLR244C',
#  'ENZ-YLR245C',
#  'ENZ-YLR260W',
#  'ENZ-YLR284C',
#  'ENZ-YLR285W',
#  'ENZ-YLR299W',
#  'ENZ-YLR300W',
#  'ENZ-YLR303W',
#  'ENZ-YLR304C_c',
#  'ENZ-YLR304C_m',
#  'ENZ-YLR305C',
#  'ENZ-YLR307W',
#  'ENZ-YLR308W',
#  'ENZ-YLR328W_c',
#  'ENZ-YLR328W_n',
#  'ENZ-YLR345W',
#  'ENZ-YLR348C',
#  'ENZ-YLR354C',
#  'ENZ-YLR355C',
#  'ENZ-YLR359W',
#  'ENZ-YLR372W',
#  'ENZ-YLR377C',
#  'ENZ-YLR382C',
#  'ENZ-YLR410W',
#  'ENZ-YLR420W',
#  'ENZ-YLR432W',
#  'ENZ-YLR438W',
#  'ENZ-YLR446W',
#  'ENZ-YLR450W',
#  'ENZ-YML004C',
#  'ENZ-YML008C',
#  'ENZ-YML022W',
#  'ENZ-YML035C',
#  'ENZ-YML042W_mm',
#  'ENZ-YML042W_x',
#  'ENZ-YML054C',
#  'ENZ-YML056C',
#  'ENZ-YML059C',
#  'ENZ-YML070W',
#  'ENZ-YML075C',
#  'ENZ-YML082W',
#  'ENZ-YML086C',
#  'ENZ-YML106W',
#  'ENZ-YML120C',
#  'ENZ-YML123C',
#  'ENZ-YML126C',
#  'ENZ-YMR006C',
#  'ENZ-YMR008C',
#  'ENZ-YMR011W',
#  'ENZ-YMR013C',
#  'ENZ-YMR015C',
#  'ENZ-YMR020W',
#  'ENZ-YMR041C',
#  'ENZ-YMR056C',
#  'ENZ-YMR058W',
#  'ENZ-YMR062C',
#  'ENZ-YMR083W',
#  'ENZ-YMR084W',
#  'ENZ-YMR087W',
#  'ENZ-YMR088C',
#  'ENZ-YMR105C',
#  'ENZ-YMR108W',
#  'ENZ-YMR110C',
#  'ENZ-YMR113W',
#  'ENZ-YMR120C',
#  'ENZ-YMR145C',
#  'ENZ-YMR162C',
#  'ENZ-YMR165C',
#  'ENZ-YMR169C',
#  'ENZ-YMR170C',
#  'ENZ-YMR202W',
#  'ENZ-YMR207C',
#  'ENZ-YMR208W',
#  'ENZ-YMR217W',
#  'ENZ-YMR220W',
#  'ENZ-YMR226C',
#  'ENZ-YMR241W',
#  'ENZ-YMR246W',
#  'ENZ-YMR250W',
#  'ENZ-YMR267W',
#  'ENZ-YMR271C',
#  'ENZ-YMR272C',
#  'ENZ-YMR278W',
#  'ENZ-YMR281W',
#  'ENZ-YMR289W',
#  'ENZ-YMR300C',
#  'ENZ-YMR303C',
#  'ENZ-YMR313C',
#  'ENZ-YMR318C',
#  'ENZ-YMR319C',
#  'ENZ-YMR323W',
#  'ENZ-YNL003C',
#  'ENZ-YNL009W',
#  'ENZ-YNL029C',
#  'ENZ-YNL036W',
#  'ENZ-YNL045W_c',
#  'ENZ-YNL045W_n',
#  'ENZ-YNL065W',
#  'ENZ-YNL073W',
#  'ENZ-YNL101W',
#  'ENZ-YNL104C_c',
#  'ENZ-YNL104C_m',
#  'ENZ-YNL106C',
#  'ENZ-YNL117W',
#  'ENZ-YNL129W',
#  'ENZ-YNL130C',
#  'ENZ-YNL141W',
#  'ENZ-YNL142W',
#  'ENZ-YNL169C',
#  'ENZ-YNL192W',
#  'ENZ-YNL202W',
#  'ENZ-YNL220W',
#  'ENZ-YNL241C',
#  'ENZ-YNL247W',
#  'ENZ-YNL256W',
#  'ENZ-YNL267W',
#  'ENZ-YNL268W',
#  'ENZ-YNL270C',
#  'ENZ-YNL277W',
#  'ENZ-YNL280C',
#  'ENZ-YNL292W',
#  'ENZ-YNL316C',
#  'ENZ-YNL318C',
#  'ENZ-YNL334C',
#  'ENZ-YNR001C',
#  'ENZ-YNR008W',
#  'ENZ-YNR012W',
#  'ENZ-YNR013C',
#  'ENZ-YNR016C',
#  'ENZ-YNR019W',
#  'ENZ-YNR027W',
#  'ENZ-YNR033W',
#  'ENZ-YNR041C',
#  'ENZ-YNR043W',
#  'ENZ-YNR050C',
#  'ENZ-YNR056C',
#  'ENZ-YNR057C',
#  'ENZ-YNR058W',
#  'ENZ-YNR067C',
#  'ENZ-YNR072W',
#  'ENZ-YOL011W',
#  'ENZ-YOL020W',
#  'ENZ-YOL033W',
#  'ENZ-YOL049W',
#  'ENZ-YOL052C',
#  'ENZ-YOL055C',
#  'ENZ-YOL058W',
#  'ENZ-YOL059W_c',
#  'ENZ-YOL059W_m',
#  'ENZ-YOL064C',
#  'ENZ-YOL065C',
#  'ENZ-YOL066C',
#  'ENZ-YOL068C',
#  'ENZ-YOL086C',
#  'ENZ-YOL092W',
#  'ENZ-YOL097C',
#  'ENZ-YOL103W',
#  'ENZ-YOL122C',
#  'ENZ-YOL126C',
#  'ENZ-YOL130W',
#  'ENZ-YOL136C',
#  'ENZ-YOL140W',
#  'ENZ-YOL143C',
#  'ENZ-YOL151W',
#  'ENZ-YOL156W',
#  'ENZ-YOR011W',
#  'ENZ-YOR025W',
#  'ENZ-YOR040W',
#  'ENZ-YOR071C',
#  'ENZ-YOR074C',
#  'ENZ-YOR081C',
#  'ENZ-YOR095C',
#  'ENZ-YOR099W',
#  'ENZ-YOR100C',
#  'ENZ-YOR108W',
#  'ENZ-YOR109W',
#  'ENZ-YOR120W',
#  'ENZ-YOR126C',
#  'ENZ-YOR128C',
#  'ENZ-YOR130C',
#  'ENZ-YOR143C',
#  'ENZ-YOR155C',
#  'ENZ-YOR161C',
#  'ENZ-YOR163W',
#  'ENZ-YOR168W',
#  'ENZ-YOR171C',
#  'ENZ-YOR175C',
#  'ENZ-YOR176W',
#  'ENZ-YOR180C',
#  'ENZ-YOR184W',
#  'ENZ-YOR190W',
#  'ENZ-YOR192C',
#  'ENZ-YOR196C',
#  'ENZ-YOR202W',
#  'ENZ-YOR209C',
#  'ENZ-YOR222W',
#  'ENZ-YOR236W_c',
#  'ENZ-YOR236W_m',
#  'ENZ-YOR241W',
#  'ENZ-YOR245C_l',
#  'ENZ-YOR245C_rm',
#  'ENZ-YOR273C',
#  'ENZ-YOR278W',
#  'ENZ-YOR283W',
#  'ENZ-YOR306C',
#  'ENZ-YOR311C',
#  'ENZ-YOR317W',
#  'ENZ-YOR323C',
#  'ENZ-YOR334W',
#  'ENZ-YOR335C',
#  'ENZ-YOR347C',
#  'ENZ-YOR348C',
#  'ENZ-YOR360C',
#  'ENZ-YOR374W',
#  'ENZ-YOR375C',
#  'ENZ-YOR377W',
#  'ENZ-YOR388C',
#  'ENZ-YOR393W',
#  'ENZ-YPL015C',
#  'ENZ-YPL023C',
#  'ENZ-YPL028W',
#  'ENZ-YPL036W',
#  'ENZ-YPL040C',
#  'ENZ-YPL053C',
#  'ENZ-YPL060W',
#  'ENZ-YPL061W',
#  'ENZ-YPL069C',
#  'ENZ-YPL087W',
#  'ENZ-YPL091W',
#  'ENZ-YPL092W',
#  'ENZ-YPL097W',
#  'ENZ-YPL104W',
#  'ENZ-YPL110C',
#  'ENZ-YPL111W',
#  'ENZ-YPL117C',
#  'ENZ-YPL134C',
#  'ENZ-YPL148C',
#  'ENZ-YPL160W',
#  'ENZ-YPL172C',
#  'ENZ-YPL188W',
#  'ENZ-YPL206C',
#  'ENZ-YPL212C',
#  'ENZ-YPL214C',
#  'ENZ-YPL252C',
#  'ENZ-YPL258C',
#  'ENZ-YPL262W_c',
#  'ENZ-YPL262W_m',
#  'ENZ-YPL265W',
#  'ENZ-YPL268W',
#  'ENZ-YPL273W',
#  'ENZ-YPL274W',
#  'ENZ-YPL281C',
#  'ENZ-YPR001W',
#  'ENZ-YPR002W',
#  'ENZ-YPR006C',
#  'ENZ-YPR011C',
#  'ENZ-YPR021C',
#  'ENZ-YPR026W',
#  'ENZ-YPR033C_c',
#  'ENZ-YPR033C_m',
#  'ENZ-YPR035W',
#  'ENZ-YPR047W',
#  'ENZ-YPR058W',
#  'ENZ-YPR060C',
#  'ENZ-YPR062W',
#  'ENZ-YPR069C',
#  'ENZ-YPR074C',
#  'ENZ-YPR081C',
#  'ENZ-YPR113W',
#  'ENZ-YPR118W',
#  'ENZ-YPR121W',
#  'ENZ-YPR127W',
#  'ENZ-YPR128C',
#  'ENZ-YPR138C',
#  'ENZ-YPR140W',
#  'ENZ-YPR145W',
#  'ENZ-YPR156C',
#  'ENZ-YPR159W',
#  'ENZ-YPR160W',
#  'ENZ-YPR183W',
#  'ENZ-YPR184W',
#  'ENZ-YPR192W_en',
#  'ENZ-YPR192W_rm',
#  'MET-10fthf_c',
#  'MET-10fthf_m',
#  'MET-13BDglucan_c',
#  'MET-13BDglucan_e',
#  'MET-13BDglucan_en',
#  'MET-13dampp_c',
#  'MET-13dpg_c',
#  'MET-13em3gacpail_r',
#  'MET-14bsq_c',
#  ...]

# %%
rxns
# Out:
# ['12AMANTF_g',
#  '13BDGLUCANt_c_en',
#  '13BGH_e',
#  '13GS_c',
#  '14BMANTF_c',
#  '14DMLANOSTt_c_e',
#  '16GS_c',
#  '1AGPCt_l_rm',
#  '1AGPEt_l_rm',
#  '1MLCLAT_mm',
#  '23CAPPD_c',
#  '2DDA7Pt_c_m',
#  '2DHPt_c_m',
#  '2HGOR_c',
#  '2MBACt_c_e',
#  '2MBALDt_c_e',
#  '2MBALDt_c_m',
#  '2MBTOHt_c_e',
#  '2MBTOHt_c_m',
#  '2OBUTt_c_m',
#  '2OXOADPt_c_m',
#  '2PHETOHt_c_e',
#  '2PHETOHt_c_m',
#  '3C3HMPt_c_e',
#  '3C3HMPt_c_m',
#  '3C4MOPt_c_m',
#  '3DH5HPBMT_m',
#  '3DH5HPBt_c_m',
#  '3DSPHR_r',
#  '3HACD200_rm',
#  '3HACD220_rm',
#  '3HACD240_rm',
#  '3HACD260_rm',
#  '3HAD40_m',
#  '3HAD60_m',
#  '3HAD80_m',
#  '3HAO_c',
#  '3HPH5MBDC_m',
#  '3HXPHBH_c',
#  '3HXPHBt_c_m',
#  '3IPM3MT_c',
#  '3MBALDt_c_e',
#  '3MBALDt_c_m',
#  '3MLCLAT_mm',
#  '3MOBDC_c',
#  '3MOPt_c_e',
#  '3MOPt_c_m',
#  '3OACE200_rm',
#  '3OACE220_rm',
#  '3OACE240_rm',
#  '3OACE260_rm',
#  '3OACR200_rm',
#  '3OACR220_rm',
#  '3OACR240_rm',
#  '3OACR260_rm',
#  '3OAR40_m',
#  '3OAR60_m',
#  '3OAR80_m',
#  '3OAS60_m',
#  '3OAS80_m',
#  '4ABTORx_c',
#  '4ABTORy_c',
#  '4ABUTNt_c_m',
#  '4ABUTt_c_m',
#  '4ABUTtps_e',
#  '4ABZt_c_e',
#  '4ABZt_c_m',
#  '4DPMIPPH_c',
#  '4H2OGLTt_c_m',
#  '4H2OGLTt_c_x',
#  '4HBZF_m',
#  '4HBZt_c_m',
#  '4HGLSD_m',
#  '4HTHRS_c',
#  '5AOPt_c_m',
#  '5AOPtps_e',
#  '5DPMIPPH_c',
#  '5FTHFt_c_e',
#  '5OPROAH_c',
#  '6DPMIPPH_c',
#  '8AONNtps_e',
#  'AACTOOR_c',
#  'AASADy_c',
#  'AATA_c',
#  'ABTA_c',
#  'ABTt_c_e',
#  'ABUTD_m',
#  'ACACT100i_x',
#  'ACACT120i_x',
#  'ACACT121ai_x',
#  'ACACT140i_x',
#  'ACACT141ai_x',
#  'ACACT141bi_x',
#  'ACACT160i_x',
#  'ACACT161ai_x',
#  'ACACT161bi_x',
#  'ACACT180i_x',
#  'ACACT181ai_x',
#  'ACACT200i_x',
#  'ACACT220i_x',
#  'ACACT240i_x',
#  'ACACT260i_x',
#  'ACACT40i_x',
#  'ACACT40ir_c',
#  'ACACT40ir_m',
#  'ACACT60i_x',
#  'ACACT80i_x',
#  'ACALDCD_c',
#  'ACALDt_c_e',
#  'ACALDt_c_m',
#  'ACCOAC_c',
#  'ACCOAC_m',
#  'ACCOAt_c_n',
#  'ACGAM6PS_c',
#  'ACGAMPM_c',
#  'ACGK_m',
#  'ACGS_m',
#  'ACHBS_m',
#  'ACHLE1_c',
#  'ACHLE2_c',
#  'ACHLE3_c',
#  'ACLS_m',
#  'ACOADS160_rm',
#  'ACOADS180_rm',
#  'ACOAHi_m',
#  'ACOAO100_x',
#  'ACOAO120_x',
#  'ACOAO121a_x',
#  'ACOAO140_x',
#  'ACOAO141a_x',
#  'ACOAO141b_x',
#  'ACOAO160_x',
#  'ACOAO161a_x',
#  'ACOAO161b_x',
#  'ACOAO180_x',
#  'ACOAO181a_x',
#  'ACOAO200_x',
#  'ACOAO220_x',
#  'ACOAO240_x',
#  'ACOAO260_x',
#  'ACOAO40_x',
#  'ACOAO60_x',
#  'ACOAO80_x',
#  'ACOATA_m',
#  'ACONIs_c',
#  'ACONIs_m',
#  'ACONMT_c',
#  'ACONT2_m',
#  'ACONTa_c',
#  'ACONTa_m',
#  'ACONTb_c',
#  'ACONTb_m',
#  'ACOTAi_m',
#  'ACP1_e',
#  'ACRNt_c_m',
#  'ACRNt_c_x',
#  'ACS_c',
#  'ACTNOR_c',
#  'ACTNOR_n',
#  'ACt_c_e',
#  'ACt_c_n',
#  'ADA_c',
#  'ADCL_c',
#  'ADCS_c',
#  'ADD_c',
#  'ADEt_c_m',
#  'ADEtps_e',
#  'ADK1_c',
#  'ADK1_m',
#  'ADK3_m',
#  'ADMDC_c',
#  'ADNCYC_c',
#  'ADNK1_c',
#  'ADNtps_e',
#  'ADPATPt_c_m',
#  'ADPATPt_c_x',
#  'ADPRIB1P_c',
#  'ADPT_c',
#  'ADPt_c_en',
#  'ADPt_c_gm',
#  'ADPt_c_n',
#  'ADPt_c_r',
#  'ADPt_c_vm',
#  'ADSK_c',
#  'ADSL1r_c',
#  'ADSL2i_c',
#  'ADSS_c',
#  'AFAT_c',
#  'AGNPR_l',
#  'AGNPR_rm',
#  'AGPAT_l',
#  'AGPAT_rm',
#  'AGPRi_m',
#  'AGTi_c',
#  'AHCYSt_c_m',
#  'AHCYSt_c_rm',
#  'AHCi_c',
#  'AHMMPS4_c',
#  'AHSERL2_c',
#  'AHSERL_c',
#  'AICART_c',
#  'AIRC1_c',
#  'AKGCITta_m',
#  'AKGDH_m',
#  'AKGMALt_c_e',
#  'AKGMALta_m',
#  'AKGt_c_e',
#  'AKGt_c_n',
#  'AKGt_c_x',
#  'AKP1_c',
#  'ALAS_m',
#  'ALATA_L_m',
#  'ALATRS_c',
#  'ALAt_c_m',
#  'ALAtps_e',
#  'ALCD19y_c',
#  'ALCD22xi_c',
#  'ALCD22xi_m',
#  'ALCD22yi_c',
#  'ALCD23xi_c',
#  'ALCD23xi_m',
#  'ALCD23yi_c',
#  'ALCD24xi_c',
#  'ALCD24xi_m',
#  'ALCD24yi_c',
#  'ALCD25xi_c',
#  'ALCD25xi_m',
#  'ALCD25yi_c',
#  'ALCD26xi_c',
#  'ALCD26xi_m',
#  'ALCD2i1_c',
#  'ALCD2i2_c',
#  'ALCD2i2_m',
#  'ALDD19xi_c',
#  'ALDD20x_m',
#  'ALDD20y_c',
#  'ALDD20y_m',
#  'ALDD22x_c',
#  'ALDD2x_c',
#  'ALDD2x_m',
#  'ALDD2y_c',
#  'ALDD2y_m',
#  'ALG14RXN_r',
#  'ALLTN_c',
#  'ALLTNt_c_e',
#  'ALLTTt_c_e',
#  'ALPHNH_c',
#  'AMAOTr_c',
#  'AMETt_c_m',
#  'AMETt_c_rm',
#  'AMETtps_e',
#  'AMID_c',
#  'AMPATPt_c_x',
#  'AMPDA_c',
#  'AMPt_c_l',
#  'AMPt_c_n',
#  'AMPt_c_rm',
#  'ANNAT_c',
#  'ANNAT_n',
#  'ANPRT_c',
#  'ANS_c',
#  'AOBUTDs_c',
#  'AOXS_c',
#  'AP4AH_c',
#  'APOLIPT_m',
#  'APOOCT_m',
#  'ARAB14LO_c',
#  'ARAB1D2_c',
#  'ARAB1Dx_c',
#  'ARABDt_c',
#  'ARABLt_c',
#  'ARABR_c',
#  'ARGN_c',
#  'ARGSL_c',
#  'ARGSS_c',
#  'ARGTRS_c',
#  'ARGTRS_m',
#  'ARGt_c_v',
#  'ARGtpa_v',
#  'ARGtps_e',
#  'ARGtps_m',
#  'ARMT_c',
#  'ASAD_c',
#  'ASNN_c',
#  'ASNN_e',
#  'ASNS1_c',
#  'ASNTRS_c',
#  'ASNTRS_m',
#  'ASNt_c_m',
#  'ASNtpa_v',
#  'ASNtps_e',
#  'ASNtps_v',
#  'ASPCT_c',
#  'ASPGLUt_c_m',
#  'ASPGLUt_c_x',
#  'ASPK_c',
#  'ASPTA_c',
#  'ASPTA_x',
#  'ASPTAi_m',
#  'ASPTRS_c',
#  'ASPTRS_m',
#  'ASPtps_e',
#  'ASPtps_v',
#  'ATAH_c',
#  'ATHRDHr_c',
#  'ATPASEP2e_c',
#  'ATPASEVg_c',
#  'ATPASEVv_c',
#  'ATPATF1_c',
#  'ATPATF2_c',
#  'ATPATF3_c',
#  'ATPHs_c',
#  'ATPM_c',
#  'ATPPRT_c',
#  'ATPS_m',
#  'ATPt_c_en',
#  'ATPt_c_gm',
#  'ATPt_c_l',
#  'ATPt_c_n',
#  'ATPt_c_r',
#  'ATPt_c_rm',
#  'ATPt_c_vm',
#  'BPNT_c',
#  'BTDDH_c',
#  'BTDt_c_e',
#  'BTNtps_e',
#  'BTS1_c',
#  'BUTt_c_e',
#  'BUTt_c_x',
#  'C14STR_c',
#  'C22STDSy_c',
#  'C24STR_r',
#  'C3STDH1_c',
#  'C3STDH2_c',
#  'C3STKR1_c',
#  'C3STKR2_c',
#  'C4STMO1_c',
#  'C4STMO2_c',
#  'C4STMO3_c',
#  'C4STMO4_c',
#  'C5STDS_c',
#  'C8STI_c',
#  'CA2tps_c_e',
#  'CAT_c',
#  'CAT_x',
#  'CBL_c',
#  'CBPS_c',
#  'CDPCHOLt_c_rm',
#  'CDPDAGS_rm',
#  'CDPEAt_c_rm',
#  'CDPt_c_n',
#  'CDPt_c_rm',
#  'CER2B24_g_r',
#  'CER2B26_g_r',
#  'CERH124A_r',
#  'CERH124B_r',
#  'CERH126A_r',
#  'CERH126B_r',
#  'CERH2A24_r',
#  'CERH2A26_r',
#  'CERH324_r',
#  'CERH326_r',
#  'CERS124_r',
#  'CERS126_r',
#  'CERS2A24_r',
#  'CERS2A26_r',
#  'CERSFA2A24_r',
#  'CERt_g_r',
#  'CHLPCTD_c',
#  'CHLSTI_c',
#  'CHOLK_c',
#  'CHOLPT_rm',
#  'CHOLt_c_e',
#  'CHOLt_c_en',
#  'CHOLtps_e',
#  'CHORM_c',
#  'CHORS_c',
#  'CHRPL_c',
#  'CHTNDA_c',
#  'CHTNS_c',
#  'CITICITt_c_m',
#  'CITICTta_x',
#  'CITMALta_m',
#  'CITMALta_x',
#  'CITPEPt_c_m',
#  'CITt_c_e',
#  'CLPNS_mm',
#  'CMPN_c',
#  'CMPt_c_rm',
#  'CMPt_m_mm',
#  'CO2t_c_e',
#  'CO2t_c_gm',
#  'CO2t_c_m',
#  'CO2t_c_mm',
#  'CO2t_c_n',
#  'CO2t_c_r',
#  'CO2t_c_rm',
#  'CO2t_c_vm',
#  'CO2t_c_x',
#  'COAHL_m',
#  'COAt_c_l',
#  'COAt_c_m',
#  'COAt_c_mm',
#  'COAt_c_n',
#  'COAt_c_r',
#  'COAt_c_rm',
#  'COAt_c_x',
#  'COBALT2t_c_e',
#  'CPPPGO_c',
#  'CRNACRNt_c_m',
#  'CRNCARt_c_x',
#  'CRNOAT_c',
#  'CRNOAT_m',
#  'CRNOAT_x',
#  'CRNt_c_m',
#  'CRNt_c_x',
#  'CRNt_e',
#  'CSND_c',
#  'CSNtps_e',
#  'CS_m',
#  'CS_x',
#  'CTPCMPt_c_m',
#  'CTPS2_c',
#  'CTPt2_m',
#  'CTPt_c_rm',
#  'CTPt_m_mm',
#  'CUtps_c_e',
#  'CYCCL_m',
#  'CYSGLYP_c',
#  'CYSItps_v',
#  'CYSS_c',
#  'CYSTGL_c',
#  'CYSTRS_c',
#  'CYSTS_c',
#  'CYStps_e',
#  'CYTDK2_c',
#  'CYTD_c',
#  'CYTDtps_e',
#  'CYTK1_c',
#  'CYTK2_c',
#  'DADA_c',
#  'DADK_c',
#  'DADPt_c_n',
#  'DADt_c_e',
#  'DAGK_rm',
#  'DAGL_l',
#  'DAGL_m',
#  'DAGt_c_l',
#  'DAGt_c_mm',
#  'DAGt_c_n',
#  'DAGt_c_rm',
#  'DAGt_gm_rm',
#  'DANNt_c_e',
#  'DB4PS_c',
#  'DBTS_c',
#  'DCAt_c_e',
#  'DCAt_c_x',
#  'DCDPt_c_n',
#  'DCMPDA_c',
#  'DCTPD_c',
#  'DCYTD_c',
#  'DCYTt_c_e',
#  'DDCACOAt_c_l',
#  'DDCACOAt_c_rm',
#  'DDCAt_c_e',
#  'DDCAt_c_rm',
#  'DDCAt_l_rm',
#  'DDPA_c',
#  'DGAT_l',
#  'DGAT_rm',
#  'DGDPt_c_n',
#  'DGK1_c',
#  'DGPP_gm',
#  'DGPP_vm',
#  'DGSNt_c_e',
#  'DHAD1_m',
#  'DHAD2_m',
#  'DHAK_c',
#  'DHAPAT_l',
#  'DHAPAT_rm',
#  'DHAPt_c_l',
#  'DHAPt_c_m',
#  'DHAPt_c_rm',
#  'DHCRD124_r',
#  'DHCRD126_r',
#  'DHCRD2A24_r',
#  'DHCRD2A26_r',
#  'DHFRi_c',
#  'DHFRi_m',
#  'DHFS_1_c',
#  'DHFt_c_m',
#  'DHNPA2i_m',
#  'DHNPTt_c_m',
#  'DHORDfum_c',
#  'DHORTS_c',
#  'DHPPDA2_c',
#  'DHPTS_m',
#  'DHPTt_c_m',
#  'DHQS_c',
#  'DHQTi_c',
#  'DICAT1_c',
#  'DICAT2_c',
#  'DICAT3_c',
#  'DICAT4_c',
#  'DICAT5_c',
#  'DICAT6_c',
#  'DICAT7_c',
#  'DICAT8_c',
#  'DINt_c_e',
#  'DIPS_c',
#  'DKMPPD_c',
#  'DMATT_c',
#  'DNADt_c_n',
#  'DNMPPA_c',
#  'DNTPPA_c',
#  'DNTPPY1_c',
#  'DNTPPY2_c',
#  'DNTPPY3_c',
#  'DOCOSCOAt_c_en',
#  'DOCOSCOAt_c_l',
#  'DOCOSCOAt_c_rm',
#  'DOLK_c',
#  'DOLPMMT_r',
#  'DOLPMT_c',
#  'DOLPt_c_r',
#  'DPCOAK_c',
#  'DPCOAK_m',
#  'DPGM_c',
#  'DPMVD_c',
#  'DPR_c',
#  'DRAPPRy_c',
#  'DRBK_c',
#  'DTMPK_c',
#  'DTTPt_c',
#  'DUDPt_c_n',
#  'DUMPt_c_n',
#  'DURIK1_c',
#  'DURIt_c_e',
#  'DUTPDP_c',
#  'DXHPS_c',
#  'E4HGLUt_c_m',
#  'E4HGLUt_c_x',
#  'E4Pt_c_m',
#  'EAR40y_m',
#  'EAR60y_m',
#  'EAR80y_m',
#  'ECOAH100_x',
#  'ECOAH120_x',
#  'ECOAH121a_x',
#  'ECOAH140_x',
#  'ECOAH141b_x',
#  'ECOAH141c_x',
#  'ECOAH160_x',
#  'ECOAH161b_x',
#  'ECOAH161c_x',
#  'ECOAH180_x',
#  'ECOAH181a_x',
#  'ECOAH200_x',
#  'ECOAH220_x',
#  'ECOAH240_x',
#  'ECOAH260_x',
#  'ECOAH40_x',
#  'ECOAH60_x',
#  'ECOAH80_x',
#  'ECOAI101a_x',
#  'ECOAI121a_x',
#  'ECOAI121b_x',
#  'ECOAI122c_x',
#  'ECOAI141a_x',
#  'ECOAI142c_x',
#  'ECOAI5d_x',
#  'ECOAI6d_x',
#  'ECOAR122_x',
#  'ECOAR142_x',
#  'ECOAR200_rm',
#  'ECOAR220_rm',
#  'ECOAR240_rm',
#  'ECOAR260_rm',
#  'EGHLAT_c',
#  'EGHLAT_m',
#  'EGHLAT_x',
#  'ENO_c',
#  'ENPP_c',
#  'EPGALURS_e',
#  'EPIST161t_l_rm',
#  'EPIST181t_l_rm',
#  'EPISTt_c_e',
#  'EPISTt_c_rm',
#  'EPISTt_l_rm',
#  'ERGST161t_l_rm',
#  'ERGST181t_l_rm',
#  'ERGSTGLCT_c',
#  'ERGSTt_c_e',
#  'ERGSTt_c_en',
#  'ERGSTt_c_l',
#  'ERGSTt_c_r',
#  'ERGSTt_c_rm',
#  'ERGSTt_r_rm',
#  'ERGTETROLt_c_e',
#  'ERGTETROLt_c_r',
#  'ETACt_c_e',
#  'ETFOXRq6_m',
#  'ETHAK_c',
#  'ETHAPT_rm',
#  'ETHAt_c_e',
#  'ETOHt_c_e',
#  'ETOHt_c_m',
#  'EX_13BDglucan_e',
#  'EX_14dmlanost_e',
#  'EX_1agpc_gen_e',
#  'EX_2mbac_e',
#  'EX_2mbald_e',
#  'EX_2mbtoh_e',
#  'EX_2phetoh_e',
#  'EX_3c3hmp_e',
#  'EX_3mbald_e',
#  'EX_3mop_e',
#  'EX_4abz_e',
#  'EX_5aop_e',
#  'EX_5fthf_e',
#  'EX_8aonn_e',
#  'EX_Nfortyr2_e',
#  'EX_abt__L_e',
#  'EX_ac_e',
#  'EX_acald_e',
#  'EX_akg_e',
#  'EX_ala__L_e',
#  'EX_alltt_e',
#  'EX_amet_e',
#  'EX_arab__D_e',
#  'EX_arab__L_e',
#  'EX_arg__L_e',
#  'EX_asn__L_e',
#  'EX_asp__L_e',
#  'EX_btd_e',
#  'EX_btn_e',
#  'EX_but_e',
#  'EX_ca2_e',
#  'EX_chol_e',
#  'EX_cit_e',
#  'EX_cl_e',
#  'EX_co2_e',
#  'EX_cobalt2_e',
#  'EX_crn_e',
#  'EX_cu2_e',
#  'EX_cys__L_e',
#  'EX_dad_2_e',
#  'EX_dann_e',
#  'EX_dcyt_e',
#  'EX_ddca_e',
#  'EX_dgsn_e',
#  'EX_din_e',
#  'EX_dttp_e',
#  'EX_duri_e',
#  'EX_epist_e',
#  'EX_ergst_e',
#  'EX_ergtetrol_e',
#  'EX_etac_e',
#  'EX_etha_e',
#  'EX_etoh_e',
#  'EX_fe2_e',
#  'EX_fecost_e',
#  'EX_fmn_e',
#  'EX_fol_e',
#  'EX_for_e',
#  'EX_fru_e',
#  'EX_fum_e',
#  'EX_g3pc_e',
#  'EX_g3pi_e',
#  'EX_gal_e',
#  'EX_galur_e',
#  'EX_gcald_e',
#  'EX_glc__D_e',
#  'EX_gln__L_e',
#  'EX_glu__L_e',
#  'EX_glx_e',
#  'EX_gly_e',
#  'EX_glyc_e',
#  'EX_gthox_e',
#  'EX_h2o_e',
#  'EX_h_e',
#  'EX_hdca_e',
#  'EX_hdcea_e',
#  'EX_his__L_e',
#  'EX_hxa_e',
#  'EX_hxan_e',
#  'EX_hxdcal_e',
#  'EX_iamac_e',
#  'EX_iamoh_e',
#  'EX_ibtald_e',
#  'EX_ibutac_e',
#  'EX_ibutoh_e',
#  'EX_id3acald_e',
#  'EX_ile__L_e',
#  'EX_ind3eth_e',
#  'EX_inost_e',
#  'EX_k_e',
#  'EX_lac__D_e',
#  'EX_lac__L_e',
#  'EX_lanost_e',
#  'EX_leu__L_e',
#  'EX_lys__L_e',
#  'EX_mal__L_e',
#  'EX_malt_e',
#  'EX_man_e',
#  'EX_melib_e',
#  'EX_met__L_e',
#  'EX_mev__R_e',
#  'EX_mg2_e',
#  'EX_mmet_e',
#  'EX_mn2_e',
#  'EX_na1_e',
#  'EX_nac_e',
#  'EX_nh4_e',
#  'EX_ni2_e',
#  'EX_nmn_e',
#  'EX_o2_e',
#  'EX_oaa_e',
#  'EX_ocdca_e',
#  'EX_ocdcea_e',
#  'EX_octa_e',
#  'EX_pacald_e',
#  'EX_pap_e',
#  'EX_pectin_e',
#  'EX_phe__L_e',
#  'EX_pheac_e',
#  'EX_pi_e',
#  'EX_pnto__R_e',
#  'EX_pro__L_e',
#  'EX_ptrc_e',
#  'EX_pydxn_e',
#  'EX_pyr_e',
#  'EX_rib__D_e',
#  'EX_ribflv_e',
#  'EX_sbt__D_e',
#  'EX_sbt__L_e',
#  'EX_ser__L_e',
#  'EX_so3_e',
#  'EX_so4_e',
#  'EX_spmd_e',
#  'EX_sprm_e',
#  'EX_srb__L_e',
#  'EX_succ_e',
#  'EX_sucr_e',
#  'EX_taur_e',
#  'EX_thm_e',
#  'EX_thmmp_e',
#  'EX_thmpp_e',
#  'EX_thr__L_e',
#  'EX_thymd_e',
#  'EX_tre_e',
#  'EX_trp__L_e',
#  'EX_ttdca_e',
#  'EX_tyr__L_e',
#  'EX_ura_e',
#  'EX_urea_e',
#  'EX_uri_e',
#  'EX_val__L_e',
#  'EX_xan_e',
#  'EX_xtsn_e',
#  'EX_xyl__D_e',
#  'EX_xylt_e',
#  'EX_zn2_e',
#  'EX_zymst_e',
#  'FACOA120tabc_x',
#  'FACOA140tabc_x',
#  'FACOA160tabc_x',
#  'FACOA161tabc_x',
#  'FACOA180tabc_x',
#  'FACOA181tabc_x',
#  'FACOA200tabc_x',
#  'FACOA220tabc_x',
#  'FACOA240tabc_x',
#  'FACOA260tabc_x',
#  'FACOAE100_x',
#  'FACOAE120_x',
#  'FACOAE140_x',
#  'FACOAE160_x',
#  'FACOAE161_x',
#  'FACOAE180_x',
#  'FACOAE181_x',
#  'FACOAE40_x',
#  'FACOAE60_x',
#  'FACOAE80_x',
#  'FACOAL100_x',
#  'FACOAL120_l',
#  'FACOAL120_rm',
#  'FACOAL120_x',
#  'FACOAL140_l',
#  'FACOAL140_rm',
#  'FACOAL140_x',
#  'FACOAL160_l',
#  'FACOAL160_rm',
#  'FACOAL160_x',
#  'FACOAL161_l',
#  'FACOAL161_rm',
#  'FACOAL161_x',
#  'FACOAL180_l',
#  'FACOAL180_rm',
#  'FACOAL180_x',
#  'FACOAL181_l',
#  'FACOAL181_rm',
#  'FACOAL181_x',
#  'FACOAL200_en',
#  'FACOAL220_en',
#  'FACOAL220_l',
#  'FACOAL240_en',
#  'FACOAL240_l',
#  'FACOAL260_en',
#  'FACOAL260_l',
#  'FACOAL80_x',
#  'FADH2t_c_m',
#  'FADt_c_m',
#  'FALDH_c',
#  'FBA2_c',
#  'FBA3_c',
#  'FBA_c',
#  'FBP2_c',
#  'FBP_c',
#  'FCLT_m',
#  'FDH_c',
#  'FE2t_c_e',
#  'FE2t_c_m',
#  'FECOOR_m',
#  'FECOST161t_l_rm',
#  'FECOST181t_l_rm',
#  'FECOSTt_c_rm',
#  'FECOSTt_e',
#  'FECOSTt_en',
#  'FECOSTt_l_rm',
#  'FECPOR_m',
#  'FECRq6_m',
#  'FKYNH_c',
#  'FLPT_c',
#  'FMETTRS_c',
#  'FMETTRS_m',
#  'FMNAT_m',
#  'FMNH_c',
#  'FMNRx2_c',
#  'FMNRx_c',
#  'FOLD3_m',
#  'FOLt_c_e',
#  'FORt_c_e',
#  'FORt_c_m',
#  'FRDPt_c_m',
#  'FRD_c',
#  'FRD_m',
#  'FRTT4HBZ_c',
#  'FRTT_c',
#  'FRTT_l',
#  'FRTT_rm',
#  'FRUK_c',
#  'FRUtps_e',
#  'FTHFCL_m',
#  'FTHFL_c',
#  'FTHFL_m',
#  'FUM_c',
#  'FUM_m',
#  'FUMt_c_e',
#  'G3PAT_l',
#  'G3PAT_rm',
#  'G3PCt_c_e',
#  'G3PCt_c_en',
#  'G3PCt_c_rm',
#  'G3PD1i_m',
#  'G3PD1r_c',
#  'G3PDf_m',
#  'G3PIt_c_e',
#  'G3PIt_c_en',
#  'G3PT_c',
#  'G5SADr_c',
#  'G5SDy_c',
#  'G6PDA_c',
#  'G6PDH2i_c',
#  'GALKi_c',
#  'GALUi_c',
#  'GALtps_e',
#  'GAM6Pt_c',
#  'GAPD_c',
#  'GARFT_c',
#  'GCALDt_c_e',
#  'GCALDt_c_m',
#  'GDPMANNt_c_g',
#  'GDPMANt_c_g',
#  'GDPt_c_g',
#  'GDPt_c_n',
#  'GF6PTA_c',
#  'GGTT_c',
#  'GGTT_l',
#  'GGTT_rm',
#  'GHMT2r_c',
#  'GHMT2r_m',
#  'GK1_c',
#  'GK2_c',
#  'GLCGSD_c',
#  'GLCGSD_v',
#  'GLCNK_c',
#  'GLCP_c',
#  'GLCt_c_e',
#  'GLCt_c_v',
#  'GLNS_c',
#  'GLNTRS_c',
#  'GLNt_c_n',
#  'GLNtpa_v',
#  'GLNtps_e',
#  'GLNtps_v',
#  'GLU5K_c',
#  'GLUCYS_c',
#  'GLUDC_c',
#  'GLUDxi_c',
#  'GLUDy_c',
#  'GLUN_c',
#  'GLUPRT_c',
#  'GLUSx_c',
#  'GLUTRS_c',
#  'GLUTRS_m',
#  'GLUt_c_m',
#  'GLUt_c_n',
#  'GLUtps_e',
#  'GLUtps_v',
#  'GLXt_c_e',
#  'GLXt_c_x',
#  'GLYAT_c',
#  'GLYC3Pt_c_l',
#  'GLYC3Pt_c_m',
#  'GLYC3Pt_c_rm',
#  'GLYC3Pt_m_mm',
#  'GLYCDy_c',
#  'GLYCL_m',
#  'GLYCOGENt_c_v',
#  'GLYCt_c_l',
#  'GLYCt_e',
#  'GLYCtps_e',
#  'GLYGS_c',
#  'GLYK_c',
#  'GLYOX_c',
#  'GLYOX_m',
#  'GLYTRS_c',
#  'GLYt_c_m',
#  'GLYtps_e',
#  'GMPS2_c',
#  'GND_c',
#  'GPDDA1pp_c',
#  'GPIA2_r',
#  'GPIA3_r',
#  'GPIA5_r',
#  'GPIA6_r',
#  'GPIA7_r',
#  'GPIA8_r',
#  'GPIA9_r',
#  'GRTT_c',
#  'GSNK_c',
#  'GSNt_c_e',
#  'GSNt_c_m',
#  'GTHCT_c',
#  'GTHH_c',
#  'GTHOXt_c_e',
#  'GTHO_c',
#  'GTHO_m',
#  'GTHP_c',
#  'GTHP_m',
#  'GTHRDt_c_e',
#  'GTHRDt_c_v',
#  'GTHRDtabc_v',
#  'GTHS_c',
#  'GTMLT_c',
#  'GTPCII2_c',
#  'GTPCI_c',
#  'GTPGDPtp_m',
#  'GUAD_1_c',
#  'GUAPRT_c',
#  'GUAt_c_m',
#  'GUAtps_e',
#  'H2O2t_c_n',
#  'H2Ot_c_e',
#  'H2Ot_c_en',
#  'H2Ot_c_g',
#  'H2Ot_c_gm',
#  'H2Ot_c_l',
#  'H2Ot_c_m',
#  'H2Ot_c_mm',
#  'H2Ot_c_n',
#  'H2Ot_c_r',
#  'H2Ot_c_rm',
#  'H2Ot_c_v',
#  'H2Ot_c_vm',
#  'H2Ot_c_x',
#  'HACD100i_x',
#  'HACD120i_x',
#  'HACD121ai_x',
#  'HACD140i_x',
#  'HACD141ai_x',
#  'HACD141bi_x',
#  'HACD160i_x',
#  'HACD161ai_x',
#  'HACD161bi_x',
#  'HACD180i_x',
#  'HACD181ai_x',
#  'HACD200i_x',
#  'HACD220i_x',
#  ...]

# %%
mets
# Out:
# ['MET-10fthf_c',
#  'MET-10fthf_m',
#  'MET-13BDglucan_c',
#  'MET-13BDglucan_e',
#  'MET-13BDglucan_en',
#  'MET-13dampp_c',
#  'MET-13dpg_c',
#  'MET-13em3gacpail_r',
#  'MET-14bsq_c',
#  'MET-14dmlanost_c',
#  'MET-14dmlanost_e',
#  'MET-16BDglucan_en',
#  'MET-1agp_c',
#  'MET-1agp_gm',
#  'MET-1agp_l',
#  'MET-1agp_rm',
#  'MET-1agp_vm',
#  'MET-1agpc_en',
#  'MET-1agpc_gen_e',
#  'MET-1agpc_l',
#  'MET-1agpc_mm',
#  'MET-1agpc_rm',
#  'MET-1agpe_en',
#  'MET-1agpe_l',
#  'MET-1agpe_rm',
#  'MET-1agpi_en',
#  'MET-1agps_en',
#  'MET-1em2gacpail_r',
#  'MET-1em3gacpail_r',
#  'MET-1mag_c',
#  'MET-1mag_gm',
#  'MET-1mag_l',
#  'MET-1mag_m',
#  'MET-1mag_vm',
#  'MET-1mlcl_mm',
#  'MET-1mncam_c',
#  'MET-1p3h5c_c',
#  'MET-1p3h5c_m',
#  'MET-1pyr5c_c',
#  'MET-1pyr5c_m',
#  'MET-23camp_c',
#  'MET-23dhmb_m',
#  'MET-23dhmp_m',
#  'MET-23dpg_c',
#  'MET-25aics_c',
#  'MET-25dhtpp_c',
#  'MET-25drapp_c',
#  'MET-2agpi_rm',
#  'MET-2ahbut_m',
#  'MET-2ahhmd_m',
#  'MET-2amsa_c',
#  'MET-2aobut_c',
#  'MET-2cpr5p_c',
#  'MET-2dda7p_c',
#  'MET-2dda7p_m',
#  'MET-2dhp_c',
#  'MET-2dhp_m',
#  'MET-2dr5p_c',
#  'MET-2hgl_c',
#  'MET-2hp6mbq_m',
#  'MET-2hp6mp_m',
#  'MET-2hpmhmbq_m',
#  'MET-2hpmmbq_m',
#  'MET-2ippm_c',
#  'MET-2kmb_c',
#  'MET-2mahmp_c',
#  'MET-2mbac_c',
#  'MET-2mbac_e',
#  'MET-2mbald_c',
#  'MET-2mbald_e',
#  'MET-2mbald_m',
#  'MET-2mbtoh_c',
#  'MET-2mbtoh_e',
#  'MET-2mbtoh_m',
#  'MET-2mcit_m',
#  'MET-2obut_c',
#  'MET-2obut_m',
#  'MET-2oxoadp_c',
#  'MET-2oxoadp_m',
#  'MET-2pg_c',
#  'MET-2phetoh_c',
#  'MET-2phetoh_e',
#  'MET-2phetoh_m',
#  'MET-34hpp_c',
#  'MET-34hpp_x',
#  'MET-35ccmp_c',
#  'MET-35cdamp_c',
#  'MET-35cgmp_c',
#  'MET-35cimp_c',
#  'MET-3c2hmp_c',
#  'MET-3c3hmp_c',
#  'MET-3c3hmp_e',
#  'MET-3c3hmp_m',
#  'MET-3c4mop_c',
#  'MET-3c4mop_m',
#  'MET-3d4mzym_c',
#  'MET-3dh5hpb_c',
#  'MET-3dh5hpb_m',
#  'MET-3dhq_c',
#  'MET-3dhsk_c',
#  'MET-3dsphgn_r',
#  'MET-3h2ip4mo4obut_c',
#  'MET-3hanthrn_c',
#  'MET-3hbcoa__R_x',
#  'MET-3hbtACP_m',
#  'MET-3hdccoa__R_x',
#  'MET-3hdccoa_rm',
#  'MET-3hdcoa_x',
#  'MET-3hdd5coa_x',
#  'MET-3hddcoa_x',
#  'MET-3hhdcoa_x',
#  'MET-3hhexACP_m',
#  'MET-3hhxccoa__R_rm',
#  'MET-3hhxccoa__R_x',
#  'MET-3hhxcoa_x',
#  'MET-3hhxd7coa_x',
#  'MET-3hiccoa_x',
#  'MET-3hicoscoa_rm',
#  'MET-3hoccoa_x',
#  'MET-3hoctACP_m',
#  'MET-3hod9coa_x',
#  'MET-3hodcoa_x',
#  'MET-3hph5mb_m',
#  'MET-3htccoa__R_x',
#  'MET-3htccoa_rm',
#  'MET-3htd5coa_x',
#  'MET-3htd7coa_x',
#  'MET-3htdcoa_x',
#  'MET-3hxphb_c',
#  'MET-3hxphb_m',
#  'MET-3ig3p_c',
#  'MET-3mbald_c',
#  'MET-3mbald_e',
#  'MET-3mbald_m',
#  'MET-3mlcl_mm',
#  'MET-3mob_c',
#  'MET-3mob_m',
#  'MET-3mop_c',
#  'MET-3mop_e',
#  'MET-3mop_m',
#  'MET-3nphb_c',
#  'MET-3odccoa_rm',
#  'MET-3odccoa_x',
#  'MET-3odcoa_x',
#  'MET-3odd5coa_x',
#  'MET-3oddcoa_x',
#  'MET-3ohdcoa_x',
#  'MET-3ohexACP_m',
#  'MET-3ohodcoa_x',
#  'MET-3ohxccoa_rm',
#  'MET-3ohxccoa_x',
#  'MET-3ohxcoa_x',
#  'MET-3ohxd7coa_x',
#  'MET-3ohxd9coa_x',
#  'MET-3oiccoa_rm',
#  'MET-3oiccoa_x',
#  'MET-3ooccoa_x',
#  'MET-3ooctACP_m',
#  'MET-3ood9coa_x',
#  'MET-3otccoa_rm',
#  'MET-3otccoa_x',
#  'MET-3otd5coa_x',
#  'MET-3otd7coa_x',
#  'MET-3otdcoa_x',
#  'MET-3pg_c',
#  'MET-3php_c',
#  'MET-3psme_c',
#  'MET-44mctr_c',
#  'MET-45dpmitp_c',
#  'MET-4abut_c',
#  'MET-4abut_e',
#  'MET-4abut_m',
#  'MET-4abutn_c',
#  'MET-4abutn_m',
#  'MET-4abz_c',
#  'MET-4abz_e',
#  'MET-4abz_m',
#  'MET-4adcho_c',
#  'MET-4ahmmp_c',
#  'MET-4ampm_c',
#  'MET-4dpmipp_c',
#  'MET-4gudbd_c',
#  'MET-4gudbutn_c',
#  'MET-4h2oglt_c',
#  'MET-4h2oglt_m',
#  'MET-4h2oglt_x',
#  'MET-4hbz_c',
#  'MET-4hbz_m',
#  'MET-4hbzcoa_m',
#  'MET-4hglusa_m',
#  'MET-4hpro_LT_c',
#  'MET-4hthr_c',
#  'MET-4mhetz_c',
#  'MET-4mop_c',
#  'MET-4mop_m',
#  'MET-4mpetz_c',
#  'MET-4mzym4c_c',
#  'MET-4mzym_c',
#  'MET-4pasp_c',
#  'MET-4ppan_c',
#  'MET-4ppcys_c',
#  'MET-4r5au_c',
#  'MET-56dpmitp_c',
#  'MET-56hicte_c',
#  'MET-56hicte_n',
#  'MET-5aizc_c',
#  'MET-5aop_c',
#  'MET-5aop_e',
#  'MET-5aop_m',
#  'MET-5aprbu_c',
#  'MET-5dpmev_c',
#  'MET-5dpmipp_c',
#  'MET-5fthf_c',
#  'MET-5fthf_e',
#  'MET-5fthf_m',
#  'MET-5mdr1p_c',
#  'MET-5mdru1p_c',
#  'MET-5mta_c',
#  'MET-5mthf_c',
#  'MET-5opro_c',
#  'MET-5pmev_c',
#  'MET-6dpmipp_c',
#  'MET-6hmhpt_m',
#  'MET-6pgc_c',
#  'MET-6pgl_c',
#  'MET-8aonn_c',
#  'MET-8aonn_e',
#  'MET-ACP_m',
#  'MET-Dara14lac_c',
#  'MET-G00146_r',
#  'MET-G00147_r',
#  'MET-G00148_r',
#  'MET-G00149_r',
#  'MET-L2aadp6sa_c',
#  'MET-L2aadp_c',
#  'MET-Lfmkynr_c',
#  'MET-LgluDala_c',
#  'MET-Lkynr_c',
#  'MET-N1aspmd_c',
#  'MET-N1sprm_c',
#  'MET-NPmehis_c',
#  'MET-Nfortyr2_c',
#  'MET-Nfortyr2_e',
#  'MET-Nfortyr_c',
#  'MET-Sfglutth_c',
#  'MET-Ssq23epx_c',
#  'MET-Ssq23epx_r',
#  'MET-aacald_c',
#  'MET-aacoa_c',
#  'MET-aacoa_m',
#  'MET-aacoa_x',
#  'MET-aact_c',
#  'MET-abt__L_c',
#  'MET-abt__L_e',
#  'MET-acACP_m',
#  'MET-ac_c',
#  'MET-ac_e',
#  'MET-ac_m',
#  'MET-ac_n',
#  'MET-ac_r',
#  'MET-acald_c',
#  'MET-acald_e',
#  'MET-acald_m',
#  'MET-accoa_c',
#  'MET-accoa_m',
#  'MET-accoa_n',
#  'MET-accoa_x',
#  'MET-acg5p_m',
#  'MET-acg5sa_m',
#  'MET-acgam1p_c',
#  'MET-acgam6p_c',
#  'MET-acglu_m',
#  'MET-acgpail_r',
#  'MET-achms_c',
#  'MET-acon_C_c',
#  'MET-acon_C_m',
#  'MET-acon_T_c',
#  'MET-acon_T_m',
#  'MET-aconm_c',
#  'MET-acorn_m',
#  'MET-acrn_c',
#  'MET-acrn_m',
#  'MET-acrn_x',
#  'MET-acser_c',
#  'MET-actACP_m',
#  'MET-actn__R_c',
#  'MET-actn__R_n',
#  'MET-acylcoa_c',
#  'MET-acylcoa_l',
#  'MET-acylcoa_m',
#  'MET-acylcoa_mm',
#  'MET-acylcoa_r',
#  'MET-acylcoa_rm',
#  'MET-acylcoa_x',
#  'MET-ade_c',
#  'MET-ade_e',
#  'MET-ade_m',
#  'MET-adn_c',
#  'MET-adn_e',
#  'MET-adp_c',
#  'MET-adp_en',
#  'MET-adp_gm',
#  'MET-adp_m',
#  'MET-adp_n',
#  'MET-adp_r',
#  'MET-adp_vm',
#  'MET-adp_x',
#  'MET-adpr1p_c',
#  'MET-adprib_c',
#  'MET-adprib_n',
#  'MET-agdp_gm',
#  'MET-agdp_vm',
#  'MET-agnp_l',
#  'MET-agnp_rm',
#  'MET-ahcys_c',
#  'MET-ahcys_m',
#  'MET-ahcys_rm',
#  'MET-ahdt_c',
#  'MET-aicar_c',
#  'MET-air_c',
#  'MET-akg_c',
#  'MET-akg_e',
#  'MET-akg_m',
#  'MET-akg_n',
#  'MET-akg_x',
#  'MET-ala_B_c',
#  'MET-ala__L_c',
#  'MET-ala__L_e',
#  'MET-ala__L_m',
#  'MET-alac_m',
#  'MET-alatrna_c',
#  'MET-allphn_c',
#  'MET-alltn_c',
#  'MET-alltn_e',
#  'MET-alltt_c',
#  'MET-alltt_e',
#  'MET-amet_c',
#  'MET-amet_e',
#  'MET-amet_m',
#  'MET-amet_rm',
#  'MET-ametam_c',
#  'MET-amob_c',
#  'MET-amp2_c',
#  'MET-amp_c',
#  'MET-amp_en',
#  'MET-amp_l',
#  'MET-amp_m',
#  'MET-amp_n',
#  'MET-amp_rm',
#  'MET-amp_x',
#  'MET-anth_c',
#  'MET-ap4a_c',
#  'MET-ap4g_c',
#  'MET-apocytc_m',
#  'MET-apop_m',
#  'MET-apoplip_m',
#  'MET-apopoct_m',
#  'MET-aproa_c',
#  'MET-aprut_c',
#  'MET-aps_c',
#  'MET-arab__D_c',
#  'MET-arab__D_e',
#  'MET-arab__L_c',
#  'MET-arab__L_e',
#  'MET-arach_en',
#  'MET-arg__L_c',
#  'MET-arg__L_e',
#  'MET-arg__L_m',
#  'MET-arg__L_v',
#  'MET-argsuc_c',
#  'MET-argtrna_c',
#  'MET-argtrna_m',
#  'MET-asn__L_c',
#  'MET-asn__L_e',
#  'MET-asn__L_m',
#  'MET-asn__L_v',
#  'MET-asntrna_c',
#  'MET-asntrna_m',
#  'MET-asp__L_c',
#  'MET-asp__L_e',
#  'MET-asp__L_m',
#  'MET-asp__L_v',
#  'MET-asp__L_x',
#  'MET-aspsa_c',
#  'MET-asptrna_c',
#  'MET-asptrna_m',
#  'MET-athr__L_c',
#  'MET-atp_c',
#  'MET-atp_en',
#  'MET-atp_gm',
#  'MET-atp_l',
#  'MET-atp_m',
#  'MET-atp_n',
#  'MET-atp_r',
#  'MET-atp_rm',
#  'MET-atp_vm',
#  'MET-atp_x',
#  'MET-bt2coa_x',
#  'MET-btcoa_x',
#  'MET-btd_c',
#  'MET-btd_e',
#  'MET-btn_c',
#  'MET-btn_e',
#  'MET-but2eACP_m',
#  'MET-butACP_m',
#  'MET-but_c',
#  'MET-but_e',
#  'MET-but_x',
#  'MET-ca2_c',
#  'MET-ca2_e',
#  'MET-camp_c',
#  'MET-caphis_c',
#  'MET-cbasp_c',
#  'MET-cbp_c',
#  'MET-cdp_c',
#  'MET-cdp_n',
#  'MET-cdp_rm',
#  'MET-cdpchol_c',
#  'MET-cdpchol_rm',
#  'MET-cdpdag_mm',
#  'MET-cdpdag_rm',
#  'MET-cdpea_c',
#  'MET-cdpea_rm',
#  'MET-cer1_24_g',
#  'MET-cer1_24_m',
#  'MET-cer1_24_r',
#  'MET-cer1_26_g',
#  'MET-cer1_26_m',
#  'MET-cer1_26_r',
#  'MET-cer2A_24_g',
#  'MET-cer2A_24_m',
#  'MET-cer2A_24_r',
#  'MET-cer2A_26_g',
#  'MET-cer2A_26_m',
#  'MET-cer2A_26_r',
#  'MET-cer2B_24_g',
#  'MET-cer2B_24_m',
#  'MET-cer2B_24_r',
#  'MET-cer2B_26_g',
#  'MET-cer2B_26_m',
#  'MET-cer2B_26_r',
#  'MET-cer3_24_g',
#  'MET-cer3_24_m',
#  'MET-cer3_24_r',
#  'MET-cer3_26_g',
#  'MET-cer3_26_m',
#  'MET-cer3_26_r',
#  'MET-cer4_24_g',
#  'MET-cer4_24_m',
#  'MET-cer4_24_r',
#  'MET-cer4_26_g',
#  'MET-cer4_26_m',
#  'MET-cer4_26_r',
#  'MET-cer_g',
#  'MET-cer_m',
#  'MET-cer_r',
#  'MET-cgly_c',
#  'MET-ch4s_c',
#  'MET-chito2pdol_c',
#  'MET-chitos_en',
#  'MET-chol_c',
#  'MET-chol_e',
#  'MET-chol_en',
#  'MET-cholp_c',
#  'MET-chor_c',
#  'MET-chtn_c',
#  'MET-cit_c',
#  'MET-cit_e',
#  'MET-cit_m',
#  'MET-cit_x',
#  'MET-citr__L_c',
#  'MET-cl_c',
#  'MET-cl_e',
#  'MET-cl_v',
#  'MET-clpn_mm',
#  'MET-cmaphis_c',
#  'MET-cmp_c',
#  'MET-cmp_m',
#  'MET-cmp_mm',
#  'MET-cmp_rm',
#  'MET-cmusa_c',
#  'MET-co2_c',
#  'MET-co2_e',
#  'MET-co2_gm',
#  'MET-co2_m',
#  'MET-co2_mm',
#  'MET-co2_n',
#  'MET-co2_r',
#  'MET-co2_rm',
#  'MET-co2_vm',
#  'MET-co2_x',
#  'MET-coa_c',
#  'MET-coa_en',
#  'MET-coa_l',
#  'MET-coa_m',
#  'MET-coa_mm',
#  'MET-coa_n',
#  'MET-coa_r',
#  'MET-coa_rm',
#  'MET-coa_x',
#  'MET-cobalt2_c',
#  'MET-cobalt2_e',
#  'MET-cpppg3_c',
#  'MET-crn_c',
#  'MET-crn_e',
#  'MET-crn_m',
#  'MET-crn_x',
#  'MET-csn_c',
#  'MET-csn_e',
#  'MET-ctp_c',
#  'MET-ctp_m',
#  'MET-ctp_mm',
#  'MET-ctp_rm',
#  'MET-cu2_c',
#  'MET-cu2_e',
#  'MET-cycc_m',
#  'MET-cys__L_c',
#  'MET-cys__L_e',
#  'MET-cysi__L_c',
#  'MET-cysi__L_v',
#  'MET-cyst__L_c',
#  'MET-cystrna_c',
#  'MET-cytd_c',
#  'MET-cytd_e',
#  'MET-dad_2_c',
#  'MET-dad_2_e',
#  'MET-dad_5_c',
#  'MET-dad_5_m',
#  'MET-dadp_c',
#  'MET-dadp_n',
#  'MET-dag_c',
#  'MET-dag_gm',
#  'MET-dag_l',
#  'MET-dag_m',
#  'MET-dag_mm',
#  'MET-dag_n',
#  'MET-dag_r',
#  'MET-dag_rm',
#  'MET-dag_vm',
#  'MET-damp_c',
#  'MET-damp_m',
#  'MET-dann_c',
#  'MET-dann_e',
#  'MET-datp_c',
#  'MET-db4p_c',
#  'MET-dc2coa_x',
#  'MET-dc3coa_x',
#  'MET-dca_c',
#  'MET-dca_e',
#  'MET-dca_x',
#  'MET-dcacoa_x',
#  'MET-dcamp_c',
#  'MET-dcdp_c',
#  'MET-dcdp_n',
#  'MET-dcmp_c',
#  'MET-dctp_c',
#  'MET-dcyt_c',
#  'MET-dcyt_e',
#  'MET-dd24coa_x',
#  'MET-dd25coa_x',
#  'MET-dd2coa_x',
#  'MET-dd35coa_x',
#  'MET-dd3coa__E_x',
#  'MET-dd3coa__Z_x',
#  'MET-dd5coa_x',
#  'MET-ddca_c',
#  'MET-ddca_e',
#  'MET-ddca_l',
#  'MET-ddca_rm',
#  'MET-ddca_x',
#  'MET-ddcacoa_c',
#  'MET-ddcacoa_l',
#  'MET-ddcacoa_rm',
#  'MET-ddcacoa_x',
#  'MET-dgdp_c',
#  'MET-dgdp_n',
#  'MET-dgmp_c',
#  'MET-dgmp_m',
#  'MET-dgsn_c',
#  'MET-dgsn_e',
#  'MET-dgtp_c',
#  'MET-dhDara14lac_c',
#  'MET-dha_c',
#  'MET-dhap_c',
#  'MET-dhap_l',
#  'MET-dhap_m',
#  'MET-dhap_rm',
#  'MET-dhf_c',
#  'MET-dhf_m',
#  'MET-dhnpt_c',
#  'MET-dhnpt_m',
#  'MET-dhor__S_c',
#  'MET-dhpmp_c',
#  'MET-dhpt_c',
#  'MET-dhpt_m',
#  'MET-dhsch_c',
#  'MET-diact_c',
#  'MET-diact_n',
#  'MET-dic2coa_rm',
#  'MET-dic2coa_x',
#  'MET-dicat_c',
#  'MET-didp_c',
#  'MET-din_c',
#  'MET-din_e',
#  'MET-ditp_c',
#  'MET-dkmpp_c',
#  'MET-dmlz_c',
#  'MET-dmpp_c',
#  'MET-dnad_c',
#  'MET-dnad_n',
#  'MET-docosa_en',
#  'MET-docosa_l',
#  'MET-docoscoa_c',
#  'MET-docoscoa_en',
#  'MET-docoscoa_l',
#  'MET-docoscoa_rm',
#  'MET-docoscoa_x',
#  'MET-dolichol_c',
#  'MET-dolmanp_r',
#  'MET-dolp_c',
#  'MET-dolp_r',
#  'MET-dpcoa_c',
#  'MET-dpcoa_m',
#  'MET-drib_c',
#  'MET-dtbt_c',
#  'MET-dtdp_c',
#  'MET-dtmp_c',
#  'MET-dttp_c',
#  'MET-dttp_e',
#  'MET-dudp_c',
#  'MET-dudp_n',
#  'MET-dump_c',
#  'MET-dump_n',
#  'MET-duri_c',
#  'MET-duri_e',
#  'MET-dutp_c',
#  'MET-e4hglu_c',
#  'MET-e4hglu_m',
#  'MET-e4hglu_x',
#  'MET-e4p_c',
#  'MET-e4p_m',
#  'MET-eig3p_c',
#  'MET-epist161_l',
#  'MET-epist161_rm',
#  'MET-epist181_l',
#  'MET-epist181_rm',
#  'MET-epist_c',
#  'MET-epist_e',
#  'MET-epist_l',
#  'MET-epist_rm',
#  'MET-ergst161_l',
#  'MET-ergst161_rm',
#  'MET-ergst181_l',
#  'MET-ergst181_rm',
#  'MET-ergst3glc_c',
#  'MET-ergst_c',
#  'MET-ergst_e',
#  'MET-ergst_en',
#  'MET-ergst_l',
#  'MET-ergst_r',
#  'MET-ergst_rm',
#  'MET-ergtetrol_c',
#  'MET-ergtetrol_e',
#  'MET-ergtetrol_r',
#  'MET-ergtrol_c',
#  'MET-etac_c',
#  'MET-etac_e',
#  'MET-etha_c',
#  'MET-etha_e',
#  'MET-ethamp_c',
#  'MET-ethamp_r',
#  'MET-etoh_c',
#  'MET-etoh_e',
#  'MET-etoh_m',
#  'MET-f1p_c',
#  'MET-f26bp_c',
#  'MET-f6p_c',
#  'MET-fad_c',
#  'MET-fad_m',
#  'MET-fadh2_c',
#  'MET-fadh2_m',
#  'MET-fald_c',
#  'MET-falpd_en',
#  'MET-falpd_l',
#  'MET-falpd_m',
#  'MET-falpd_mm',
#  'MET-falpd_rm',
#  'MET-fdp_c',
#  'MET-fdxox_c',
#  'MET-fdxrd_c',
#  'MET-fe2_c',
#  'MET-fe2_e',
#  'MET-fe2_m',
#  'MET-fecost161_l',
#  'MET-fecost161_rm',
#  'MET-fecost181_l',
#  'MET-fecost181_rm',
#  'MET-fecost_c',
#  'MET-fecost_e',
#  'MET-fecost_en',
#  'MET-fecost_l',
#  'MET-fecost_rm',
#  'MET-fgam_c',
#  'MET-ficytC_m',
#  'MET-fmettrna_c',
#  'MET-fmettrna_m',
#  'MET-fmn_c',
#  'MET-fmn_e',
#  'MET-fmn_m',
#  'MET-fmnh2_c',
#  'MET-focytC_m',
#  'MET-fol_c',
#  'MET-fol_e',
#  'MET-for_c',
#  'MET-for_e',
#  'MET-for_m',
#  'MET-fpram_c',
#  'MET-fprica_c',
#  'MET-frdp_c',
#  'MET-frdp_l',
#  'MET-frdp_m',
#  'MET-frdp_rm',
#  'MET-fru_c',
#  'MET-fru_e',
#  'MET-fum_c',
#  'MET-fum_e',
#  'MET-fum_m',
#  'MET-g1p_c',
#  'MET-g3p_c',
#  'MET-g3pc_c',
#  'MET-g3pc_e',
#  'MET-g3pc_en',
#  'MET-g3pc_rm',
#  'MET-g3pe_en',
#  'MET-g3pi_c',
#  'MET-g3pi_e',
#  'MET-g3pi_en',
#  'MET-g3ps_en',
#  'MET-g6p_c',
#  'MET-gacpail_r',
#  'MET-gal1p_c',
#  'MET-gal_c',
#  'MET-gal_e',
#  'MET-galur_e',
#  'MET-gam1p_c',
#  'MET-gam6p_c',
#  'MET-gam6p_e',
#  'MET-gar_c',
#  'MET-gcald_c',
#  'MET-gcald_e',
#  'MET-gcald_m',
#  'MET-gdp_c',
#  'MET-gdp_g',
#  'MET-gdp_m',
#  'MET-gdp_n',
#  'MET-gdpmann_c',
#  'MET-gdpmann_g',
#  'MET-ggdp_c',
#  'MET-ggdp_l',
#  'MET-ggdp_rm',
#  'MET-glc__D_c',
#  'MET-glc__D_e',
#  'MET-glc__D_v',
#  'MET-glcn_c',
#  'MET-gln__L_c',
#  'MET-gln__L_e',
#  'MET-gln__L_n',
#  'MET-gln__L_v',
#  'MET-glntrna_c',
#  'MET-glu5p_c',
#  'MET-glu5sa_c',
#  'MET-glu__L_c',
#  'MET-glu__L_e',
#  'MET-glu__L_m',
#  'MET-glu__L_n',
#  'MET-glu__L_v',
#  'MET-glu__L_x',
#  'MET-glucys_c',
#  'MET-glutrna_c',
#  'MET-glutrna_m',
#  'MET-glx_c',
#  'MET-glx_e',
#  'MET-glx_x',
#  'MET-gly_c',
#  'MET-gly_e',
#  'MET-gly_m',
#  'MET-glyald_c',
#  'MET-glyc3p_c',
#  'MET-glyc3p_l',
#  'MET-glyc3p_m',
#  'MET-glyc3p_mm',
#  'MET-glyc3p_rm',
#  'MET-glyc_c',
#  'MET-glyc_e',
#  'MET-glyc_l',
#  'MET-glycogen_c',
#  'MET-glycogen_v',
#  'MET-glytrna_c',
#  'MET-gmp_c',
#  'MET-gmp_g',
#  'MET-gp4g_c',
#  'MET-gpail_r',
#  'MET-grdp_c',
#  'MET-gsn_c',
#  'MET-gsn_e',
#  'MET-gsn_m',
#  'MET-gthox_c',
#  'MET-gthox_e',
#  'MET-gthox_m',
#  'MET-gthrd_c',
#  'MET-gthrd_e',
#  'MET-gthrd_m',
#  'MET-gthrd_v',
#  'MET-gtp_c',
#  'MET-gtp_m',
#  'MET-gua_c',
#  'MET-gua_e',
#  'MET-gua_m',
#  'MET-h2o2_c',
#  'MET-h2o2_m',
#  'MET-h2o2_n',
#  'MET-h2o2_x',
#  'MET-h2o_c',
#  'MET-h2o_e',
#  'MET-h2o_en',
#  'MET-h2o_g',
#  'MET-h2o_gm',
#  'MET-h2o_l',
#  'MET-h2o_m',
#  'MET-h2o_mm',
#  'MET-h2o_n',
#  'MET-h2o_r',
#  'MET-h2o_rm',
#  'MET-h2o_v',
#  'MET-h2o_vm',
#  'MET-h2o_x',
#  'MET-h2s_c',
#  'MET-hLkynr_c',
#  'MET-h_c',
#  'MET-h_e',
#  'MET-h_en',
#  'MET-h_g',
#  'MET-h_gm',
#  'MET-h_l',
#  'MET-h_m',
#  'MET-h_mm',
#  'MET-h_n',
#  'MET-h_r',
#  'MET-h_rm',
#  'MET-h_v',
#  'MET-h_vm',
#  'MET-h_x',
#  'MET-hacon_C_m',
#  'MET-hcit_c',
#  'MET-hcit_m',
#  'MET-hco3_c',
#  'MET-hco3_e',
#  'MET-hco3_m',
#  'MET-hco3_n',
#  'MET-hcys__L_c',
#  'MET-hdca_c',
#  'MET-hdca_e',
#  'MET-hdca_en',
#  'MET-hdca_l',
#  'MET-hdca_m',
#  'MET-hdca_mm',
#  'MET-hdca_rm',
#  'MET-hdca_x',
#  'MET-hdcea_c',
#  'MET-hdcea_e',
#  'MET-hdcea_en',
#  'MET-hdcea_l',
#  'MET-hdcea_m',
#  'MET-hdcea_mm',
#  'MET-hdcea_rm',
#  'MET-hdcea_x',
#  'MET-hdcoa_c',
#  'MET-hdcoa_l',
#  'MET-hdcoa_m',
#  'MET-hdcoa_mm',
#  'MET-hdcoa_r',
#  'MET-hdcoa_rm',
#  'MET-hdcoa_x',
#  'MET-hdd2coa_x',
#  'MET-hemeA_c',
#  'MET-hemeA_m',
#  'MET-hemeO_m',
#  'MET-hemegen_c',
#  'MET-hexACP_m',
#  'MET-hhxdcal_r',
#  'MET-hicit_m',
#  'MET-his__L_c',
#  'MET-his__L_e',
#  'MET-his__L_m',
#  'MET-his__L_v',
#  'MET-hisp_c',
#  'MET-histd_c',
#  'MET-histrna_c',
#  'MET-histrna_m',
#  'MET-hmbil_c',
#  'MET-hmgcoa_c',
#  'MET-hmgcoa_m',
#  'MET-hom__L_c',
#  'MET-hom__L_e',
#  'MET-hpglu_c',
#  'MET-hx2coa_x',
#  'MET-hxa_c',
#  'MET-hxa_e',
#  'MET-hxa_x',
#  'MET-hxan_c',
#  'MET-hxan_e',
#  'MET-hxc2coa_rm',
#  'MET-hxc2coa_x',
#  'MET-hxc9coa_x',
#  'MET-hxca_en',
#  'MET-hxca_l',
#  'MET-hxca_r',
#  'MET-hxca_rm',
#  'MET-hxccoa_c',
#  'MET-hxccoa_en',
#  'MET-hxccoa_l',
#  'MET-hxccoa_r',
#  'MET-hxccoa_rm',
#  'MET-hxccoa_x',
#  'MET-hxcoa_x',
#  'MET-hxd27coa_x',
#  'MET-hxd29coa_x',
#  'MET-hxd7coa_x',
#  'MET-hxdcal_e',
#  'MET-hxdcal_r',
#  'MET-iamac_c',
#  'MET-iamac_e',
#  'MET-iamoh_c',
#  'MET-iamoh_e',
#  'MET-iamoh_m',
#  'MET-ibtald_c',
#  'MET-ibtald_e',
#  'MET-ibtald_m',
#  'MET-ibutac_c',
#  'MET-ibutac_e',
#  'MET-ibutoh_c',
#  'MET-ibutoh_e',
#  'MET-ibutoh_m',
#  'MET-ic2coa_rm',
#  'MET-ic2coa_x',
#  'MET-icit_c',
#  'MET-icit_m',
#  'MET-icit_x',
#  'MET-icoscoa_c',
#  'MET-icoscoa_en',
#  'MET-icoscoa_rm',
#  'MET-icoscoa_x',
#  'MET-id3acald_c',
#  'MET-id3acald_e',
#  'MET-id3acald_m',
#  'MET-idp_c',
#  'MET-ile__L_c',
#  'MET-ile__L_e',
#  'MET-ile__L_m',
#  'MET-ile__L_v',
#  'MET-iletrna_c',
#  'MET-iletrna_m',
#  'MET-imacp_c',
#  'MET-imp_c',
#  'MET-ind3ac_c',
#  'MET-ind3ac_m',
#  'MET-ind3eth_c',
#  'MET-ind3eth_e',
#  'MET-ind3eth_m',
#  'MET-indpyr_c',
#  'MET-inoshp_c',
#  'MET-inoshp_n',
#  'MET-inost_c',
#  'MET-inost_e',
#  'MET-inost_rm',
#  'MET-ins_c',
#  'MET-ins_e',
#  'MET-ipc_g',
#  'MET-ipc_m',
#  'MET-ipc_r',
#  'MET-ipdp_c',
#  'MET-ipdp_l',
#  'MET-ipdp_m',
#  'MET-ipdp_rm',
#  'MET-itaccoa_m',
#  'MET-itacon_m',
#  'MET-itp_c',
#  'MET-k_c',
#  'MET-k_e',
#  'MET-k_v',
#  'MET-kynate_c',
#  'MET-lac__D_c',
#  'MET-lac__D_e',
#  'MET-lac__D_m',
#  'MET-lac__L_c',
#  'MET-lac__L_e',
#  'MET-lac__L_m',
#  'MET-lald__L_c',
#  'MET-lanost161_l',
#  'MET-lanost161_rm',
#  ...]

# %%
df_all.head()
# Out:
#                                                           id       type  \
# RXN-EX_13BDglucan_e_FWD-SPONT  RXN-EX_13BDglucan_e_FWD-SPONT  metabolic
# RXN-EX_13BDglucan_e_REV-SPONT  RXN-EX_13BDglucan_e_REV-SPONT  metabolic
# RXN-EX_crn_e_FWD-SPONT                RXN-EX_crn_e_FWD-SPONT  metabolic
# RXN-EX_crn_e_REV-SPONT                RXN-EX_crn_e_REV-SPONT  metabolic
# RXN-EX_lac__D_e_FWD-SPONT          RXN-EX_lac__D_e_FWD-SPONT  metabolic
#
#                               coupling_type coupling_species  \
# RXN-EX_13BDglucan_e_FWD-SPONT           NaN              NaN
# RXN-EX_13BDglucan_e_REV-SPONT           NaN              NaN
# RXN-EX_crn_e_FWD-SPONT                  NaN              NaN
# RXN-EX_crn_e_REV-SPONT                  NaN              NaN
# RXN-EX_lac__D_e_FWD-SPONT               NaN              NaN
#
#                                            reaction
# RXN-EX_13BDglucan_e_FWD-SPONT  MET-13BDglucan_e -->
# RXN-EX_13BDglucan_e_REV-SPONT   -->MET-13BDglucan_e
# RXN-EX_crn_e_FWD-SPONT                MET-crn_e -->
# RXN-EX_crn_e_REV-SPONT                 -->MET-crn_e
# RXN-EX_lac__D_e_FWD-SPONT          MET-lac__D_e -->

# %%
met_dict
# Out:
# {'MET-ficytC_m': -2.0,
#  'MET-lac__L_c': -1.0,
#  'MET-focytC_m': 2.0,
#  'MET-h_c': 2.0,
#  'MET-pyr_c': 1.0}
