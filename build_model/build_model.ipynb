# %% [markdown]
# # Build Excel stoich for GAMS (originally A01_build_excel_stoich_for_GAMS.ipynb)

# %% [markdown]
# #### Load data

# %%
import cobra,json,os,sys,openpyxl,re,pandas as pd
from collections import OrderedDict
from copy import deepcopy

model_root_path = '../'
sys.path.append(model_root_path)
from pycore.gsm_custom_functions import *
from pycore.cobrapy_custom_extras import *
kribo_default = 22*3600 #(22 aa/ribo/s converted to aa/ribo/h)
mito_compartments = ['m', 'mm'] # IDs for mitochondria compartments

# %%
# Metabolic model (COBRApy json)
# If you have to use multiple stoichiometric models (SMs), 
#   it's best to keep 1 as the main copy and then use transaction files to apply differences to the others. Helps improve consistency in annotations, stoich. etc.
chosen_model = '_rba' # c: carbon, n: nitrogen

# List parameters for your model version(s), such as:
	# max_allowed_mito_proteome_allo_fraction: maximum fraction of proteome that can be allocated to mitochondria
	# nonmodeled_proteome_allocation: fraction of proteome not accounted for in the model
	# predicted_but_unused_proteins_path: path to file with predicted proteins that are not used in the model
	# sheet_name: name of sheet in relevant excel files (e.g., biomass, dummy protein) to use
modelVersions = {
    '_rba':{
        'max_allowed_mito_proteome_allo_fraction':0.05,
        # 'nonmodeled_proteome_allocation':0.3148, # disable since MPFS constraints now replace this
        'dummy_sheet':''
    }
    }
modelname = 'GSM_iSace1144_rba'
model = load_cobra_model('./input/'+modelname+'.json')
# if not choosing between nutrient-limited models, uncomment the following lines:
# model = cobra.io.load_json_model('./input/iRhtoC.json')
# chosen_model = ''

# Update GAMS settings file to reflect model version, 
#   and add NGAM, mito capacity, etc.
#   If not using multiple models, replace everything in the curly braces with the values you want
with open('./model/model-version-settings.txt', 'w') as f:
	npa = modelVersions[chosen_model].get('nonmodeled_proteome_allocation', 0)
	mampaf = modelVersions[chosen_model]['max_allowed_mito_proteome_allo_fraction'] if 'max_allowed_mito_proteome_allo_fraction' in modelVersions[chosen_model] else 1
	f.write(f"* file with settings updated by build_model scripts, to help with managing multiple SMs\n"
		f"$setGlobal max_allowed_mito_proteome_allo_fraction {mampaf}\n"
		f"$setGlobal nonmodeled_proteome_allocation {npa}\n")
	if 'measured_but_unused_proteins_path' in modelVersions[chosen_model]:
		f.write('* unless specified otherwise (e.g., in test_kapp.gms), include prosyn constraints to reflect production of unused proteins; comment out if using dummy protein instead\n')
		if modelVersions[chosen_model]['predicted_but_unused_proteins_path']:
			if os.path.exists(modelVersions[chosen_model]['predicted_but_unused_proteins_path']):
				f.write(f"$if not %ignore_measured_unused_constraints%==1 $include {modelVersions[chosen_model]['predicted_but_unused_proteins_path']}\n")

# Protein
df_pro = read_spreadsheet('./input/PROTEIN_stoich_curation.xlsx')
## OPTIONAL: add "special cases only" sheet to df_pro. 
##   Good for distinguishing proteins in the organism from ones added for testing purposes.
include_special_case_proteins = False # affects protein and enzyme stoichiometry
if include_special_case_proteins:
	df_pro_special = read_spreadsheet('./input/PROTEIN_stoich_curation.xlsx',sheet_name='special cases only',header=1)
	df_pro = pd.concat([df_pro,df_pro_special],ignore_index=True)

# Amino acid info
df_aamap = pd.read_csv('./input/PROTEIN_amino_acid_map.txt', sep='\t')
df_aamap.index = df_aamap.aa_abbv.to_list()

# Dummy protein
dummy_path = './input/PROTEIN_dummy_prot_calc.xlsx'
# df_aa_dummy = read_spreadsheet(dummy_path)
# df_aa_dummy2 = read_spreadsheet(dummy_path,sheet_name='unidentified')
# 1st entry is default dummy protein; remove 2nd entry unless needed
dummy_list = [{"df":read_spreadsheet(dummy_path),"name":"PROSYN-PROTDUMMY"}]
			#   {"df":read_spreadsheet(dummy_path,sheet_name='unidentified'),"name":"PROSYN-PROTDUMMYUNIDENTIFIED"}]
for prot in dummy_list:
	prot["df"].index = prot["df"].aa_abbv.to_list()
	prot["medianL"] = int(round(prot["df"].loc['A', 'Unnamed: 5'], 0))
	# Add 1e-5 g/mmol to prevent number round lost of protein MW
	#dummy_MW
	prot["MW"] = round(prot["df"].loc['C', 'Unnamed: 5'], 5) + 1e-5
	prot["biosyn"] = prot["name"].replace('PROSYN-','BIOSYN-')
	prot["met"] = prot["name"].lower().replace('prosyn-','BIO-')
	prot["translation_loc"] = 'unknown' if not 'translation_loc' in prot else prot['translation_loc']

# Enzyme
df_enz = read_spreadsheet('./input/ENZYME_stoich_curation.tsv')
# add 'id' column to df_enz, which is 'RXN-' + rxn_src + '_' + dir + '-' + enz
if include_special_case_proteins:
	df_enz_special = read_spreadsheet('./input/ENZYME_stoich_curation_special_cases.tsv')
	df_enz = pd.concat([df_enz,df_enz_special],ignore_index=True)

# RNA
df_rnas = read_spreadsheet('./input/RNA_stoich.xlsx')
df_rnas.index = df_rnas.RNAid.to_list()

# Ribosome ('_c' for nucleus or nucleoid, '_m' for mitochondria)
ribo_dict = {'_c':read_spreadsheet('./input/RIBOSOME_nucleus.xlsx'), 
			 '_m':read_spreadsheet('./input/RIBOSOME_mitochondria.xlsx')}

# Biomass
# heading start at cell X4
df_biom = read_spreadsheet('./input/BIOMASS_RBA.xlsx', sheet_name='RBABioRxns')
# list of biomass rxns to turn off by default and only turn on when needed; any rxns not found will be excluded from list
whole_biomass_rxns = ['BIOSYN-' + i for i in ['BIODILAERO','COFACTORANAEROBIC','compCERANAEROBIC','BIODILBATCHANAERO','BIODILCHEMOANAERO','BIODILSTARVE','BIODILNOGAM','BIODILAERO-NOGAM']]

# checks which rxns to ignore when seeing if all necessary enzymes are modeled.
rxns_not_needing_enzymes = [rxn.id for rxn in find_biomass_reactions(model)] + ['BIOMASS_MFA','BIOMASS_MFA_NO_GAM']
# Gene-Protein Reaction associations (GPRs) representing spontaneous reactions (i.e., no enzyme needed in model)
spont_GPRs = ['SPONT', 'UNKNOWN']
# take IDs of all rxns
print('Reactions to ignore when checking if enzymes must be added:')
print(rxns_not_needing_enzymes)
# Out:
# Reactions to ignore when checking if enzymes must be added:
# ['BIOMASS_AERO_SC_hvd', 'BIOMASS_MFA', 'BIOMASS_MFA_NO_GAM']

# %%
# Expanding df_pro to include sublocations as separate proteins
## remove the 'id' column
# df_pro = df_pro.drop(columns=['id'])
# if the 'gene_src' column is empty, fill it with the 'name' column
df_pro['gene_src'] = df_pro['gene_src'].fillna(df_pro['name'])
## for each protein, if there are commas in subloc_assigned, split them into separate entries with 'id' modified to reflect sublocation
df_pro['subloc_assigned'] = df_pro['subloc_assigned'].apply(lambda x: x.split(',') if type(x) == str and ',' in x else x)
# add the 'id' column back in, assigning it to "gene_src" plus "subloc_assigned" if the latter is not 'unknown'
# modify IDs to reflect sublocation
# add location only if there are multiple proteins with the same gene source
df_pro = df_pro.explode('subloc_assigned').reset_index(drop=True)
if 'id' not in df_pro.columns:
	df_pro['id'] = df_pro.apply(
		lambda row: row['id_manual_override (clear when using new sheet)']
		if pd.notna(row['id_manual_override (clear when using new sheet)'])
		else (
			str(row['gene_src'])
			+ (
				'_' + row['subloc_assigned']
				if row['subloc_assigned'] != 'unknown'
				and df_pro[df_pro['gene_src'] == row['gene_src']].shape[0] > 1
				else ''
			)
		),
		axis=1
	)
df_pro.index = df_pro.id.to_list()
# save df_pro to model folder
df_pro[['id'] + [col for col in df_pro.columns if col != 'id']].to_csv('./model/PROTEIN_stoich_curation.tsv', sep='\t', index=False)

# %%
# calculate MW of enzymes = sum of MW of all proteins in protein_stoich (MW from df_pro) * number of protein_stoich
df_enz['id'] = df_enz.apply(lambda x: 'RXN-' + x['rxn_src'] + '_' + x['dir'] + '-' + x['enz'], axis=1)
df_enz.index = df_enz.id.to_list()
mw = 'MW (g/mmol)'
for enz in df_enz.index:
	enz_mw = 0
	for pro in df_enz.loc[enz, 'protein_stoich'].split(','):
		# find protein stoichiometry in df_pro
		delim = ':'
		if delim in pro:
			prot_id = pro.split(delim)[0].strip()
			prot_stoich = float(pro.split(delim)[1].strip())
			pro_matches = df_pro.loc[df_pro.gene_src == prot_id]
			# if no matches, check if prot_id is in df_pro.index
			if len(pro_matches) == 0:
				if prot_id in df_pro.index:
					pro_matches = df_pro.loc[prot_id]
				else:
					print(f'Warning: {prot_id} not found in protein stoichiometry file')
					continue
			pro_mw = pro_matches[mw]
			if isinstance(pro_matches[mw], pd.Series):
				if pro_matches[mw].nunique() > 1:
					print(f'Warning: {prot_id} has multiple MWs in df_pro')
				pro_mw = pro_matches[mw].iloc[0]
			if float(pro_mw) == 0:
				print(f'Warning: MW for {prot_id} is 0 in protein stoichiometry file')
				continue
			enz_mw += pro_mw * prot_stoich
	# set enz_mw to NaN if it is 0
	if enz_mw == 0:
		enz_mw = float('nan')
	df_enz.loc[enz, mw] = enz_mw
# move 'id' column to the front
df_enz[['id'] + [col for col in df_enz.columns if col != 'id']].to_csv('./model/ENZYME_stoich_curation.tsv', sep='\t', index=False)

# %%
# list all genes, to map them to translation (PROSYN) rxns and other rxns making their products where needed
# combine all genes from df_pro and model
# combine all genes from df_pro and model, ensuring all are strings and not NaN
genes_model = [str(gene.id) for gene in model.genes if pd.notna(gene.id)]
genes_pro = [str(g) for g in df_pro.gene_src.to_list() if pd.notna(g)]
genes_rna = [str(r) for r in df_rnas.RNAid.to_list() if pd.notna(r)]
genes = sorted(list(dict.fromkeys(genes_model + genes_pro + genes_rna)))
gene_expression_dict = {}

# %%
# testing only
# # tag_c formula weight
# # print(model.metabolites.get_by_id('tag_c').formula_weight-227.000000) # 227.000000 from Ac element accidentally listed in it
# # TAG MW is 89.07 w/o Acyl3, 882.40 w/ Acyl3 according to https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6838544/. Thus, Acyl MW is (882.40-89.07)/3 = 264.4433333333
# # calculate_molecular_weight('C28H43O')
# # (12.010700*28)+(1.007940*43)+15.999400 = 395.64042
# # print(model.metabolites.get_by_id('ergstest_c').formula_weight-227.000000+264.4433333333) # 227.000000 from Ac element accidentally listed in it
# print(model.metabolites.get_by_id('o2_c').formula_weight)

# %%
# Make version of model with no generic cofactors, for publication and for MEMOTE testing
model_no_generics = deepcopy(model)
# remove rxns with names beginning with "GENERIC_"
for rxn in model.reactions:
	if rxn.id.startswith("GENERIC_"):
		# print(rxn.id)
		model_no_generics.reactions.get_by_id(rxn.id).remove_from_model()
report_mass_balance(model_no_generics)
# remove metabolites with names beginning with "pseudometabolite "
for met in model.metabolites:
	if met.name.startswith("pseudometabolite "):
		# print(met.name)
		model_no_generics.metabolites.get_by_id(met.id).remove_from_model()
# write JSON version of the model w/o these additions (for future use)
cobra.io.save_json_model(model_no_generics, "./input/"+modelname+"-no-generic-cofactors.json")
# convert to xml file
cobra.io.write_sbml_model(model_no_generics, "./input/"+modelname+"-no-generic-cofactors.xml")
# Out:
# GPIA3_r
# gpail_r + pmtcoa_r <=> coa_r + gacpail_r
# coa_r	C21H32N7O16P3S1	-4	C00010	coenzyme A [endoplasmic reticulum]
# gacpail_r		0	      	6-(alpha-D-glucosaminyl)-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]
# gpail_r	C17H28NO17PR2	0	C04248	6-(alpha-D-glucosaminyl)-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]
# pmtcoa_r	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [endoplasmic reticulum]
# C:-33, H:-58, N:-1, O:-18, P:-1, S:0, R:-2, charge:0
#
# GPIA8_r
# 1em2gacpail_r + dolmanp_r <=> 1em3gacpail_r
# 1em2gacpail_r		0	      	6-O-{alpha-D-mannosyl-(1->6)-2-O-[(2-aminoethyl)phosphoryl]-alpha-D-mannosyl-(1->4)-alpha-D-glucosaminyl}-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]
# 1em3gacpail_r		0	      	6-O-{alpha-D-mannosyl-(1->2)-alpha-D-mannosyl-(1->6)-2-O-[(2-aminoethyl)phosphoryl]-alpha-D-mannosyl-(1->4)-alpha-D-glucosaminyl}-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]
# dolmanp_r	C6H12O9PPolyprenyl	-1	C03862	dolichyl D-mannosyl phosphate [endoplasmic reticulum]
# C:-6, H:-12, O:-9, P:-1, Polyprenyl:-1, charge:1
#
# GPIA9_r
# 1em3gacpail_r + pe_gen_r <=> 13em3gacpail_r + dag_r
# 13em3gacpail_r	C43H44N9O	0	      	6-[6-(2-aminoethylphosphoryl)-alpha-mannosyl-(1->6)-2-(2-aminoethylphosphoryl)-alpha-mannosyl-(1->6)-alpha-2-(2-aminoethylphosphoryl)mannosyl-(1->4)-alpha-glucosaminyl]-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]
# 1em3gacpail_r		0	      	6-O-{alpha-D-mannosyl-(1->2)-alpha-D-mannosyl-(1->6)-2-O-[(2-aminoethyl)phosphoryl]-alpha-D-mannosyl-(1->4)-alpha-D-glucosaminyl}-O-acyl-1-phosphatidyl-1D-myo-inositol [endoplasmic reticulum]
# dag_r	C3H6O3Acyl2	0	C00165	diglyceride backbone [endoplasmic reticulum]
# pe_gen_r	C39H75NO8P	0	C00350	phosphatidylethanolamine backbone [endoplasmic reticulum]
# C:7, H:-25, N:8, O:-4, Acyl:2, P:-1, charge:0
#
# Q6MT2_m
# 2hpmhmbq_m + amet_m + h_m --> ahcys_m + q6h2_m
# 2hpmhmbq_m	C38H56O4	0	C05805	2-hexaprenyl-5-hydroxy-6-methoxy-3-methyl-1,4-benzoquinone [mitochondrion]
# ahcys_m	C14H20N6O5S1	0	C00021	S-adenosyl-L-homocysteine [mitochondrion]
# amet_m	C15H23N6O5S	1	C00019	S-adenosyl-L-methionine [mitochondrion]
# h_m	H1	1	C00080	H+ [mitochondrion]
# q6h2_m	C39H60O4	0	C00390	ubiquinol-6 [mitochondrion]
# C:0, H:0, O:0, N:0, S:0, charge:-2
#
# KYNIs_c
# kynate_c --> qunld_c
# kynate_c	C10H5N1O3	-2	C01717	kynurenic acid [cytoplasm]
# qunld_c	C10H7NO2	0	C06325	quinaldic acid [cytoplasm]
# C:0, H:2, N:0, O:-1, charge:2
#
# APOLIPT_m
# apop_m + lipACP_m <=> ACP_m + apoplip_m
# ACP_m	Acp	-1	C00229	ACP1 [mitochondrion]
# apop_m	NH2R	0	C16240	Apoprotein [mitochondrion]
# apoplip_m	C8H14NOS2R	0	C16237	Protein N6-(lipoyl)lysine [mitochondrion]
# lipACP_m	C8H13OS3R	0	C16239	Lipoyl-[acp] [mitochondrion]
# Acp:1, N:0, H:-1, R:-1, C:0, O:0, S:-1, charge:-1
#
# r_4323_m
# 2.0 amet_m + apopoct_m + 2.0 sdonor_m --> apoplip_m + 2.0 dad_5_m + 2.0 met__L_m
# amet_m	C15H23N6O5S	1	C00019	S-adenosyl-L-methionine [mitochondrion]
# apoplip_m	C8H14NOS2R	0	C16237	Protein N6-(lipoyl)lysine [mitochondrion]
# apopoct_m	C8H16NOR	0	C16236	Protein N6-(octanoyl)lysine [mitochondrion]
# dad_5_m	C10H13N5O3	0	C05198	5'-Deoxyadenosine [mitochondrion]
# met__L_m	C5H11N1O2S1	0	C00073	L-methionine [mitochondrion]
# sdonor_m		0	C17023	Sulfur donor [mitochondrion]
# C:0, H:0, N:0, O:0, S:2, R:0, charge:-2
#
# r_4324_m
# 2.0 amet_m + ocACP_m + 2.0 sdonor_m --> 2.0 dad_5_m + lipACP_m + 2.0 met__L_m
# amet_m	C15H23N6O5S	1	C00019	S-adenosyl-L-methionine [mitochondrion]
# dad_5_m	C10H13N5O3	0	C05198	5'-Deoxyadenosine [mitochondrion]
# lipACP_m	C8H13OS3R	0	C16239	Lipoyl-[acp] [mitochondrion]
# met__L_m	C5H11N1O2S1	0	C00073	L-methionine [mitochondrion]
# ocACP_m	C8H14OAcp	-1	C05752	octanoyl-ACP [mitochondrion]
# sdonor_m		0	C17023	Sulfur donor [mitochondrion]
# C:0, H:1, N:0, O:0, S:3, R:1, Acp:-1, charge:-1
#
# compCER_m
# 0.1 cer1_24_m + 0.1 cer1_26_m + 0.1 cer2A_24_m + 0.1 cer2A_26_m + 0.1 cer2B_24_m + 0.1 cer2B_26_m + 0.1 cer3_24_m + 0.1 cer3_26_m + 0.1 cer4_24_m + 0.1 cer4_26_m <=> cer_m
# cer1_24_m	C42H85N1O3	0	      	ceramide-1 (C24) [mitochondrion]
# cer1_26_m	C44H89N1O3	0	      	ceramide-1 (C26) [mitochondrion]
# cer2A_24_m	C42H85N1O4	0	      	ceramide-2 (C24) [mitochondrion]
# cer2A_26_m	C44H89N1O4	0	      	ceramide-2 (C26) [mitochondrion]
# cer2B_24_m	C42H85NO4	0	      	ceramide-2' (C24) [mitochondrion]
# cer2B_26_m	C44H89NO4	0	      	ceramide-2' (C26) [mitochondrion]
# cer3_24_m	C42H85NO5	0	      	ceramide-3 (C24) [mitochondrion]
# cer3_26_m	C44H89NO5	0	      	ceramide-3 (C26) [mitochondrion]
# cer4_24_m	C42H85NO6	0	      	ceramide-4 (C24) [mitochondrion]
# cer4_26_m	C44H89NO6	0	      	ceramide-4 (C26) [mitochondrion]
# cer_m	Cer	0	C00195	Ceramide
# C:-43.00000000000001, H:-87, N:-0.9999999999999999, O:-4.4, Cer:1, charge:0
#
# compCER_r
# 0.1 cer1_24_r + 0.1 cer1_26_r + 0.1 cer2A_24_r + 0.1 cer2A_26_r + 0.1 cer2B_24_r + 0.1 cer2B_26_r + 0.1 cer3_24_r + 0.1 cer3_26_r + 0.1 cer4_24_r + 0.1 cer4_26_r <=> cer_r
# cer1_24_r	C42H85N1O3	0	      	ceramide-1 (C24) [endoplasmic reticulum]
# cer1_26_r	C44H89N1O3	0	      	ceramide-1 (C26) [endoplasmic reticulum]
# cer2A_24_r	C42H85N1O4	0	      	ceramide-2 (C24) [endoplasmic reticulum]
# cer2A_26_r	C44H89N1O4	0	      	ceramide-2 (C26) [endoplasmic reticulum]
# cer2B_24_r	C42H85N1O4	0	      	ceramide-2' (C24) [endoplasmic reticulum]
# cer2B_26_r	C44H89N1O4	0	      	ceramide-2' (C26) [endoplasmic reticulum]
# cer3_24_r	C42H85N1O5	0	      	ceramide-3 (C24) [endoplasmic reticulum]
# cer3_26_r	C44H89N1O5	0	      	ceramide-3 (C26) [endoplasmic reticulum]
# cer4_24_r	C42H85N1O6	0	      	ceramide-4 (C24) [endoplasmic reticulum]
# cer4_26_r	C44H89N1O6	0	      	ceramide-4 (C26) [endoplasmic reticulum]
# cer_r	Cer	0	C00195	Ceramide
# C:-43.00000000000001, H:-87, N:-0.9999999999999999, O:-4.4, Cer:1, charge:0
#
# compCER_g
# 0.1 cer1_24_g + 0.1 cer1_26_g + 0.1 cer2A_24_g + 0.1 cer2A_26_g + 0.1 cer2B_24_g + 0.1 cer2B_26_g + 0.1 cer3_24_g + 0.1 cer3_26_g + 0.1 cer4_24_g + 0.1 cer4_26_g <=> cer_g
# cer1_24_g	C42H85N1O3	0	      	ceramide-1 (C24) [Golgi]
# cer1_26_g	C44H89N1O3	0	      	ceramide-1 (C26) [Golgi]
# cer2A_24_g	C42H85N1O4	0	      	ceramide-2 (C24) [Golgi]
# cer2A_26_g	C44H89N1O4	0	      	ceramide-2 (C26) [Golgi]
# cer2B_24_g	C42H85NO4	0	      	ceramide-2' (C24) [Golgi]
# cer2B_26_g	C44H89NO4	0	      	ceramide-2' (C26) [Golgi]
# cer3_24_g	C42H85NO5	0	      	ceramide-3 (C24) [Golgi]
# cer3_26_g	C44H89NO5	0	      	ceramide-3 (C26) [Golgi]
# cer4_24_g	C42H85NO6	0	      	ceramide-4 (C24) [Golgi]
# cer4_26_g	C44H89NO6	0	      	ceramide-4 (C26) [Golgi]
# cer_g	Cer	0	C00195	Ceramide
# C:-43.00000000000001, H:-87, N:-0.9999999999999999, O:-4.4, Cer:1, charge:0
#
# compACYLCOA_c
# 0.554586 hdcoa_c + 0.203479 odecoa_c + 0.18897 pmtcoa_c + 0.052965 stcoa_c --> acylcoa_c
# acylcoa_c	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA
# hdcoa_c	C37H60N7O17P3S1	-4	C21072	palmitoleoyl-CoA(4-) [cytoplasm]
# odecoa_c	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA [cytoplasm]
# pmtcoa_c	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [cytoplasm]
# stcoa_c	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA [cytoplasm]
# C:-16.512888, H:-30.509646, N:-5.551115123125783e-17, O:-1.0000000000000009, P:-1.1102230246251565e-16, S:-1.3877787807814457e-17, Acyl:1, charge:5.551115123125783e-17
#
# compACYLCOA_l
# 0.554586 hdcoa_l + 0.203479 odecoa_l + 0.18897 pmtcoa_l + 0.052965 stcoa_l --> acylcoa_l
# acylcoa_l	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA
# hdcoa_l	C37H60N7O17P3S1	-4	C21072	palmitoleoyl-CoA(4-) [lipid particle]
# odecoa_l	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA [lipid particle]
# pmtcoa_l	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [lipid particle]
# stcoa_l	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA [lipid particle]
# C:-16.512888, H:-30.509646, N:-5.551115123125783e-17, O:-1.0000000000000009, P:-1.1102230246251565e-16, S:-1.3877787807814457e-17, Acyl:1, charge:5.551115123125783e-17
#
# compACYLCOA_m
# 0.554586 hdcoa_m + 0.203479 odecoa_m + 0.18897 pmtcoa_m + 0.052965 stcoa_m --> acylcoa_m
# acylcoa_m	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA
# hdcoa_m	C37H60N7O17P3S	-4	C21072	palmitoleoyl-CoA(4-) [cytoplasm]
# odecoa_m	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA [cytoplasm]
# pmtcoa_m	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [cytoplasm]
# stcoa_m	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA [cytoplasm]
# C:-16.512888, H:-30.509646, N:-5.551115123125783e-17, O:-1.0000000000000009, P:-1.1102230246251565e-16, S:-1.3877787807814457e-17, Acyl:1, charge:5.551115123125783e-17
#
# compACYLCOA_r
# 0.554586 hdcoa_r + 0.203479 odecoa_r + 0.18897 pmtcoa_r + 0.052965 stcoa_r --> acylcoa_r
# acylcoa_r	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA
# hdcoa_r	C37H60N7O17P3S	-4	C21072	palmitoleoyl-CoA(4-) [cytoplasm]
# odecoa_r	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA [cytoplasm]
# pmtcoa_r	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [endoplasmic reticulum]
# stcoa_r	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA [cytoplasm]
# C:-16.512888, H:-30.509646, N:-5.551115123125783e-17, O:-1.0000000000000009, P:-1.1102230246251565e-16, S:-1.3877787807814457e-17, Acyl:1, charge:5.551115123125783e-17
#
# compACYLCOA_rm
# 0.554586 hdcoa_rm + 0.203479 odecoa_rm + 0.18897 pmtcoa_rm + 0.052965 stcoa_rm --> acylcoa_rm
# acylcoa_rm	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA
# hdcoa_rm	C37H60N7O17P3S1	-4	C21072	palmitoleoyl-CoA(4-) [endoplasmic reticulum membrane]
# odecoa_rm	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA [endoplasmic reticulum membrane]
# pmtcoa_rm	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [endoplasmic reticulum membrane]
# stcoa_rm	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA [endoplasmic reticulum membrane]
# C:-16.512888, H:-30.509646, N:-5.551115123125783e-17, O:-1.0000000000000009, P:-1.1102230246251565e-16, S:-1.3877787807814457e-17, Acyl:1, charge:5.551115123125783e-17
#
# compACYLCOA_x
# 0.554586 hdcoa_x + 0.203479 odecoa_x + 0.18897 pmtcoa_x + 0.052965 stcoa_x --> acylcoa_x
# acylcoa_x	C21H31N7O16P3SAcyl	-4	C00040	Acyl-CoA
# hdcoa_x	C37H60N7O17P3S1	-4	C21072	palmitoleoyl-CoA(4-) [peroxisome]
# odecoa_x	C39H64N7O17P3S1	-4	C00510	oleoyl-CoA [peroxisome]
# pmtcoa_x	C37H62N7O17P3S1	-4	C00154	palmitoyl-CoA [peroxisome]
# stcoa_x	C39H66N7O17P3S1	-4	C00412	stearoyl-CoA [peroxisome]
# C:-16.512888, H:-30.509646, N:-5.551115123125783e-17, O:-1.0000000000000009, P:-1.1102230246251565e-16, S:-1.3877787807814457e-17, Acyl:1, charge:5.551115123125783e-17
#
# compFALPD_mm
# 0.18897 hdca_mm + 0.554586 hdcea_mm + 0.052965 ocdca_mm + 0.203479 ocdcea_mm <=> falpd_mm
# falpd_mm	AcylO	-1	C00162	Fatty acid (from lipid)
# hdca_mm	C16H31O2	-1	C00249	palmitate [mitochondrial membrane]
# hdcea_mm	C16H29O2	-1	C08362	palmitoleate [cytoplasm]
# ocdca_mm	C18H35O2	-1	C01530	stearate [mitochondrial membrane]
# ocdcea_mm	C18H33O2	-1	C00712	oleate [cytoplasm]
# Acyl:1, O:-1, C:-16.512888, H:-30.509645999999996, charge:-2.7755575615628914e-17
#
# compFALPD_l
# 0.18897 hdca_l + 0.554586 hdcea_l + 0.052965 ocdca_l + 0.203479 ocdcea_l <=> falpd_l
# falpd_l	AcylO	-1	C00162	Fatty acid (from lipid)
# hdca_l	C16H31O2	-1	C00249	palmitate [lipid particle]
# hdcea_l	C16H29O2	-1	C08362	palmitoleate [lipid particle]
# ocdca_l	C18H35O2	-1	C01530	stearate [lipid particle]
# ocdcea_l	C18H33O2	-1	C00712	oleate [lipid particle]
# Acyl:1, O:-1, C:-16.512888, H:-30.509645999999996, charge:-2.7755575615628914e-17
#
# compFALPD_m
# 0.18897 hdca_m + 0.554586 hdcea_m + 0.052965 ocdca_m + 0.203479 ocdcea_m <=> falpd_m
# falpd_m	AcylO	-1	C00162	Fatty acid (from lipid)
# hdca_m	C16H31O2	-1	C00249	palmitate [cytoplasm]
# hdcea_m	C16H29O2	-1	C08362	palmitoleate [cytoplasm]
# ocdca_m	C18H35O2	-1	C01530	stearate [cytoplasm]
# ocdcea_m	C18H33O2	-1	C00712	oleate [mitochondrion]
# Acyl:1, O:-1, C:-16.512888, H:-30.509645999999996, charge:-2.7755575615628914e-17
#
# compFALPD_rm
# 0.18897 hdca_rm + 0.554586 hdcea_rm + 0.052965 ocdca_rm + 0.203479 ocdcea_rm <=> falpd_rm
# falpd_rm	AcylO	-1	C00162	Fatty acid (from lipid)
# hdca_rm	C16H31O2	-1	C00249	palmitate [endoplasmic reticulum membrane]
# hdcea_rm	C16H29O2	-1	C08362	palmitoleate [endoplasmic reticulum membrane]
# ocdca_rm	C18H35O2	-1	C01530	stearate [endoplasmic reticulum membrane]
# ocdcea_rm	C18H33O2	-1	C00712	oleate [endoplasmic reticulum membrane]
# Acyl:1, O:-1, C:-16.512888, H:-30.509645999999996, charge:-2.7755575615628914e-17
#
# compFALPD_en
# 0.18897 hdca_en + 0.554586 hdcea_en + 0.052965 ocdca_en + 0.203479 ocdcea_en <=> falpd_en
# falpd_en	AcylO	-1	C00162	Fatty acid (from lipid)
# hdca_en	C16H31O2	-1	C00249	palmitate [cell envelope]
# hdcea_en	C16H29O2	-1	C08362	palmitoleate [cell envelope]
# ocdca_en	C18H35O2	-1	C01530	stearate [cell envelope]
# ocdcea_en	C18H33O2	-1	C00712	oleate [cell envelope]
# Acyl:1, O:-1, C:-16.512888, H:-30.509645999999996, charge:-2.7755575615628914e-17
#
# compCERANAERO_r
# 0.5 cer1_24_r + 0.5 cer1_26_r --> cer_r
# cer1_24_r	C42H85N1O3	0	      	ceramide-1 (C24) [endoplasmic reticulum]
# cer1_26_r	C44H89N1O3	0	      	ceramide-1 (C26) [endoplasmic reticulum]
# cer_r	Cer	0	C00195	Ceramide
# C:-43, H:-87, N:-1, O:-3, Cer:1, charge:0
#
# DICAT1_c
# mg2_c --> dicat_c
# dicat_c	None	2.0	      	Generic divalent cation
# mg2_c	Mg	2	C00305	Mg(2+) [cytoplasm]
# Mg:-1, charge:0
#
# DICAT2_c
# zn2_c --> dicat_c
# dicat_c	None	2.0	      	Generic divalent cation
# zn2_c	Zn	2	C00038	Zn(2+) [cytoplasm]
# Zn:-1, charge:0
#
# DICAT3_c
# ca2_c --> dicat_c
# ca2_c	Ca	2	C00076	Ca(2+) [cytoplasm]
# dicat_c	None	2.0	      	Generic divalent cation
# Ca:-1, charge:0
#
# DICAT4_c
# cu2_c --> dicat_c
# cu2_c	Cu	2	C00070	Cu2(+) [cytoplasm]
# dicat_c	None	2.0	      	Generic divalent cation
# Cu:-1, charge:0
#
# DICAT5_c
# fe2_c --> dicat_c
# dicat_c	None	2.0	      	Generic divalent cation
# fe2_c	Fe1	2	C14818	iron(2+) [cytoplasm]
# Fe:-1, charge:0
#
# DICAT6_c
# ni2_c --> dicat_c
# dicat_c	None	2.0	      	Generic divalent cation
# ni2_c	Ni	2.0	C19609	Nickel
# Ni:-1, charge:0
#
# DICAT7_c
# cobalt2_c --> dicat_c
# cobalt2_c	Co	2.0	C00175	Co2+
# dicat_c	None	2.0	      	Generic divalent cation
# Co:-1, charge:0
#
# DICAT8_c
# mn2_c --> dicat_c
# dicat_c	None	2.0	      	Generic divalent cation
# mn2_c	Mn	2	C19610	Mn(2+) [cytoplasm]
# Mn:-1, charge:0
#
# HEME1_c
# hemeA_c --> hemegen_c
# hemeA_c	C49H54FeN4O6	-2	C15670	heme a [cytoplasm]
# hemegen_c	None	None	      	Generic heme
# C:-49, H:-54, Fe:-1, N:-4, O:-6, charge:2
#
# HEME2_c
# hemeO_m --> hemegen_c
# hemeO_m	C49H56FeN4O5	-2	C15672	heme o [mitochondrion]
# hemegen_c	None	None	      	Generic heme
# C:-49, H:-56, Fe:-1, N:-4, O:-5, charge:2
#
# HEME3_c
# pheme_m --> hemegen_c
# hemegen_c	None	None	      	Generic heme
# pheme_m	C34H30N4O4Fe1	-2	C00032	ferroheme b [mitochondrion]
# C:-34, H:-30, N:-4, O:-4, Fe:-1, charge:2
#
# HEME4_c
# sheme_c --> hemegen_c
# hemegen_c	None	None	      	Generic heme
# sheme_c	C42H36N4O16Fe1	-8	C00748	siroheme [cytoplasm]
# C:-42, H:-36, N:-4, O:-16, Fe:-1, charge:8
#
# LIPOATE_m
# lipACP_m --> ACP_m + lipoate_m
# ACP_m	Acp	-1	C00229	ACP1 [mitochondrion]
# lipACP_m	C8H13OS3R	0	C16239	Lipoyl-[acp] [mitochondrion]
# lipoate_m	C8H13O2S2	-1.0	C16241	Lipoate
# Acp:1, C:0, H:0, O:1, S:-1, R:-1, charge:-2
#
# MONCAT1_c
# na1_c --> moncat_c
# moncat_c	None	1.0	      	Generic monovalent cation
# na1_c	Na	1	C01330	sodium [cytoplasm]
# Na:-1, charge:0
#
# MONCAT2_c
# k_c --> moncat_c
# k_c	K1	1	C00238	potassium [cytoplasm]
# moncat_c	None	1.0	      	Generic monovalent cation
# K:-1, charge:0
#
# MONCAT3_c
# nh4_c --> moncat_c
# moncat_c	None	1.0	      	Generic monovalent cation
# nh4_c	H4N1	1	C01342	ammonium [cytoplasm]
# H:-4, N:-1, charge:0

# %% [markdown]
# #### Assemble reactions

# %%
import itertools
import cobra.manipulation

def find_true_combinations(expression, use_knockout=False, variables:list=[]):
    """
    Finds all combinations of boolean values that make the given expression true.

    Args:
        expression: The boolean expression as a string.
        use_knockout: If True, the function will test combinations where only one variable is False, and use those to eliminate redundant combinations, saving time. Will return an error if the expression contains 'not' operators unless set to 'ignore warning'.
        variables: A list of strings (variable names in expression) to consider. If none provided, the function will extract variable names from the expression. Added in case consistent RegEx parsing proves too unreliable.
    Returns:
        A list of dictionaries, where each dictionary represents a true combination.

    """

    # Extract variables from the expression
    if variables == []:
        variables = set(re.findall(r'\b\w+\b', expression))
        if use_knockout and any([var in ['not','!'] for var in variables]):
            raise ValueError("The expression contains 'not' operators, which may cause issues with the 'use_knockout' option. If you still want to use this option, set it to 'ignore warning'.")
        # remove 'and', 'or', 'not' from variables
        variables = [var for var in variables if var not in ['and', 'or', 'not']]
    # print(variables)

    # Generate all possible combinations of True/False values for variables
    combinations = itertools.product([True, False], repeat=len(variables))
    # sort combinations from fewest to most True values
    combinations = sorted(combinations, key=lambda x: sum(x))
    combos_to_check = combinations.copy()
    # print(combinations)
    # find all combinations where only one variable is False
    knockout_combos = []
    essential_vars = [] # variables that must be True
    # test if combo where all variables are True makes the expression True
    all_true = dict(zip(variables, [True]*len(variables)))
    expr = expression
    for var in sorted(variables, key=len, reverse=True):
        expr = expr.replace(var, str(all_true[var]))
    if use_knockout != False:
        if eval(expr):
            # for each variable, find the combination where only that variable is False
            for var in variables:
                combo = [True]*len(variables)
                combo[variables.index(var)] = False
                knockout_combos.append(combo)
                expr = expression
                for var2 in sorted(variables, key=len, reverse=True):
                    expr = expr.replace(var2, str(combo[variables.index(var2)]))
                # add variable to essential_vars if it must be True
                if not eval(expr):
                    essential_vars.append(var)
                    # remove all combinations where this variable is False from combos_to_check
                    combos_to_check = [combo for combo in combos_to_check if combo[variables.index(var)]]
    # if len(combinations) != len(combos_to_check):
    #     print(f'Reduced combinations to check from {len(combinations)} to {len(combos_to_check)} by eliminating redundant combinations.')

    true_combinations = []
    for combo in combos_to_check:
        # Create a dictionary mapping variables to their assigned values
        values = dict(zip(variables, combo))
        # print(values)
        # print(combo)
        # replace variables with their values in 'values'
        # cobra.manipulation.knock_out_model_genes

        expr = expression
        # Replace variables with their values in the expression, starting with the longest variable names to avoid the risk of replacing substrings
        for var in sorted(variables, key=len, reverse=True):
            expr = expr.replace(var, str(values[var]))

        # print(expression)
        # print(expr,type(expr))
        # Evaluate the expression
        if eval(expr):
            # check if the combination's True values are a subset of any previous ones; if so, don't add it
            # print('\t',values)
            redundant_combos = False
            true_vals = [var for var in values if values[var]]
            for prev in true_combinations:
                prev_vals = [var for var in prev if prev[var]]
                if set(true_vals).issubset(set(prev_vals)) or set(prev_vals).issubset(set(true_vals)):
                    redundant_combos = True
                    # print('redundant:',true_vals)
                    break
            if not redundant_combos:
                true_combinations.append(values)

    return true_combinations

# Example usage:
expression = "rt05 and ((rt01 and (rt012 or rt0123)) or rt04)"
true_combos = find_true_combinations(expression, use_knockout=True)
print(true_combos)
# Out:
# [{'rt04': True, 'rt01': False, 'rt012': False, 'rt05': True, 'rt0123': False}, {'rt04': False, 'rt01': True, 'rt012': True, 'rt05': True, 'rt0123': False}, {'rt04': False, 'rt01': True, 'rt012': False, 'rt05': True, 'rt0123': True}]

# %%
# Automatically create placeholders for enzymes based on GPRs in model.reactions
rxns_to_skip = set(rxns_not_needing_enzymes)
enz_rxn_dict = {}
spont_rxn_dict = {}
rxn_updates = {rxn.id: {} for rxn in model.reactions}
GPR_enz_dict = {}
try:
	df_enz_rxns = read_spreadsheet('./input/ENZYME_stoich.tsv')
	# make set of rxns to skip, from combining the 'rxns' column cells in df_enz_rxns (to avoid reviewing existing rxns) and separating by commas. However, relying on this will prevent updates to their GPRs from being added to the model.
	# rxns_to_skip.update(set(df_enz_rxns.rxns.str.split(',').sum()))
	# make enz_rxn_dict from df_enz_rxns, with 'enz' as keys and 'rxns' and 'protein_stoich' as values
	for index, row in df_enz_rxns.iterrows():
		enz_rxn_dict[row['enz']] = {'rxns': sorted(list(dict.fromkeys(row['rxns'].split(',')))),
										'protein_stoich': {prot.split(':')[0]: float(prot.split(':')[1]) for prot in row['protein_stoich'].split(',')}}
		if not pd.isna(row[mw]):
			enz_rxn_dict[row['enz']][mw] = row[mw]
except:
	df_enz_rxns = pd.DataFrame(columns=['enz','rxns','protein_stoich',mw])
# add dict of protein_stoich to enz_rxn_dict, with each protein as a key and its stoichiometry as the value

# find all unique GPRs in model.reactions, and their associated reactions
for rxn in model.reactions:
	# print(rxn.id, rxn.gene_reaction_rule)
	if rxn.id in rxns_to_skip:
		continue
	if rxn.gene_reaction_rule not in spont_GPRs + ['']:
		if rxn.gene_reaction_rule in GPR_enz_dict.keys():
			# add rxn to corresponding enz in enz_rxn_dict
			enz_ids = GPR_enz_dict[rxn.gene_reaction_rule]
			for enz_id in enz_ids:
				enz_rxn_dict[enz_id]['rxns'].append(rxn.id)
				rxn_updates[rxn.id].setdefault('enz',enz_id)
		else:
			GPR_enz_dict[rxn.gene_reaction_rule] = set()
			enzs = sorted(find_true_combinations(rxn.gene_reaction_rule, use_knockout=True, variables=[g.id for g in rxn.genes]), key=lambda x: sorted(x.keys()))
			for enz in enzs:
				# print('\t',enz)
				enz_found = None
				# default: 1 copy of each protein is used
				# prot_stoich = ','.join([gene+':1' for gene in sorted(enz.keys()) if enz[gene]])
				prot_stoich = {gene:1 for gene in sorted(enz.keys()) if enz[gene]}
				# check if any enzymes with the same stoichiometry are already in enz_rxn_dict
				enz_id = ''.join(sorted(prot_stoich.keys()))

				for old_enz_id in enz_rxn_dict:
					# print(enz_id,enz_rxn_dict[enz_id])
					# automatically assumes enzymes are the same if they have the same proteins, regardless of order/count
					if sorted(enz_rxn_dict[old_enz_id]['protein_stoich'].keys()) == sorted(prot_stoich.keys()):
						enz_rxn_dict[old_enz_id]['rxns'].append(rxn.id)
						enz_found = old_enz_id
						break
				if not enz_found:
					# enz_rxn_dict[rxn.id] = enz
					enz_rxn_dict[enz_id] = {'rxns':[rxn.id],
											'protein_stoich':prot_stoich}
					rxn_updates[rxn.id].setdefault('enz',enz_id)
					GPR_enz_dict[rxn.gene_reaction_rule].add(enz_id)
				else:
					GPR_enz_dict[rxn.gene_reaction_rule].add(enz_found)
	else:
		# add to spont_rxn_dict under its GPR as a list of rxn IDs, if it is not already there
		spont_rxn_dict[rxn.gene_reaction_rule] = spont_rxn_dict.get(rxn.gene_reaction_rule, {'rxns':[],'protein_stoich':{'zeroCost':1}})
		spont_rxn_dict[rxn.gene_reaction_rule]['rxns'].append(rxn.id)
		rxn_updates[rxn.id].setdefault('gene_reaction_rule',rxn.gene_reaction_rule)
		# spont_rxn_dict[rxn.gene_reaction_rule] = spont_rxn_dict.get(rxn.gene_reaction_rule, [rxn.id])
		# spont_rxn_dict[rxn.gene_reaction_rule] = rxn.id
					
# give each enz in enz_rxn_dict a row in df_enz_rxns
new_rows = []
for enz in enz_rxn_dict:
	# only add enzymes that are not already in df_enz_rxns
	if df_enz_rxns[df_enz_rxns.enz == enz].empty:
		# calculate MW of each enzyme based on its protein stoichiometry
		if mw in enz_rxn_dict[enz] and enz_rxn_dict[enz][mw]:
			enz_mw = enz_rxn_dict[enz][mw]
		else:
			enz_mw = 0
			for prot in enz_rxn_dict[enz]['protein_stoich']:
				pro_mw = df_pro.loc[prot,mw] if prot in df_pro.index else 0
				# check in gene_src column
				if pro_mw == 0:
					if prot in df_pro.gene_src.to_list():
						# print(prot,df_pro.loc[df_pro.gene_src == prot,mw])
						# if there are multiple proteins with the same gene_src, check if their MW is the same
						# if not, print a warning
						# pick the first one
						pro_match = df_pro.loc[df_pro.gene_src == prot,mw].to_list()
						if df_pro.loc[df_pro.gene_src == prot,mw].nunique() > 1:
							print(f'Warning: {prot} has multiple MWs in df_pro')
						pro_mw = pro_match[0]
					else:
						print(f'Warning: {prot} not found in df_pro')
				enz_mw += pro_mw*enz_rxn_dict[enz]['protein_stoich'][prot]
		new_rows.append({'enz':enz,'rxns':','.join(enz_rxn_dict[enz]['rxns']),
						'protein_stoich':','.join([prot+':'+str(enz_rxn_dict[enz]['protein_stoich'][prot]) for prot in enz_rxn_dict[enz]['protein_stoich']]),
						mw:enz_mw,
						'status':'automatically added'})
df_enz_rxns = pd.concat([df_enz_rxns, pd.DataFrame(new_rows)], sort=False, ignore_index=True)
# sort by id, MW, and then by rxns
df_enz_rxns = df_enz_rxns.sort_values(by=['rxns',mw,'enz'])
# save automatically updated df_enz_rxns as separate file
df_enz_rxns.to_csv('./model/ENZYME_stoich.tsv', sep='\t', index=False)
# Out:
# /var/folders/fx/q_x2rm651s91fj2m6_tb19pxvpxbmb/T/ipykernel_5621/1784060244.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_enz_rxns = pd.concat([df_enz_rxns, pd.DataFrame(new_rows)], sort=False, ignore_index=True)

# %%
# check if all rxns in model are accounted for in df_enz_rxns, and if they have been automatically updated
# make a list of all rxns in df_enz_rxns
enz_rxns = []
for index, row in df_enz_rxns.iterrows():
	enz_rxns += row['rxns'].split(',')
enz_rxns = sorted(list(dict.fromkeys(enz_rxns)))
# check if all rxns in model are in enz_rxns
missing_rxns = []
for rxn in model.reactions:
	if rxn.id not in rxns_not_needing_enzymes and rxn.id not in enz_rxns and rxn.id not in whole_biomass_rxns and rxn.gene_reaction_rule not in spont_rxn_dict.keys():
		missing_rxns.append(rxn.id)
if len(missing_rxns) > 0:
	print(f'Warning: the following reactions are not accounted for in df_enz_rxns:')
	for rxn in missing_rxns:
		print(rxn)
# remove rxns from rxn_updates if their value is {}
for rxn in rxn_updates.copy():
	if not rxn_updates[rxn]:
		del rxn_updates[rxn]
	else:
		print(f'Updating {rxn} with {rxn_updates[rxn]}')
# if rxn_updates isn't empty, print a warning
# if len(rxn_updates) > 0:
# 	raise ValueError(f'Warning: the following reactions have been automatically updated:\n{rxn_updates}')
# Out:
# Updating RLFC2O_c with {'enz': 'YDL174C'}
# Updating RLFC2O_m with {'enz': 'YDL178W'}
# Updating BTDDH_c with {'enz': 'YAL060W'}
# Updating LLFC2O_c with {'enz': 'YEL039CYML054C'}
# Updating 13GS_c with {'enz': 'YGR032WYPR165W'}
# Updating 16GS_c with {'enz': 'YGR143W'}
# Updating PRMICI_c with {'enz': 'YIL020C'}
# Updating P5CD_m with {'enz': 'YHR037W'}
# Updating DKMPPD_c with {'enz': 'YEL038WYMR009W'}
# Updating DHPPDA2_c with {'enz': 'YOL066C'}
# Updating DRAPPRy_c with {'enz': 'YBR153W'}
# Updating ACHBS_m with {'enz': 'YMR108W'}
# Updating HPPK2_m with {'enz': 'YNL256W'}
# Updating AATA_c with {'enz': 'YER152C'}
# Updating DPR_c with {'enz': 'YHR063C'}
# Updating Q6MT1_m with {'enz': 'YDR204WYGL119WYGR255CYLR201CYML110CYOL096CYOR125C'}
# Updating Q6MO_m with {'enz': 'YDR204WYGL119WYGR255CYLR201CYML110CYOL096CYOR125C'}
# Updating IPPMIb_c with {'enz': 'YGL009C'}
# Updating IPPS_c with {'enz': 'YOR108W'}
# Updating UNK3_c with {'enz': 'YHR137W'}
# Updating HCITR_m with {'enz': 'YDR234W'}
# Updating MCITS_m with {'enz': 'YPR001W'}
# Updating BPNT_c with {'enz': 'YOL064C'}
# Updating PDE1_c with {'enz': 'YOR360C'}
# Updating PDE3_c with {'enz': 'YOR360C'}
# Updating PDE4_c with {'enz': 'YOR360C'}
# Updating PDE5_c with {'enz': 'YOR360C'}
# Updating DB4PS_c with {'enz': 'YDR487C'}
# Updating DHQTi_c with {'enz': 'YDR127W'}
# Updating DHQS_c with {'enz': 'YDR127W'}
# Updating 3DSPHR_r with {'enz': 'YBR265W'}
# Updating DDPA_c with {'enz': 'YDR035W'}
# Updating 3HXPHBH_c with {'enz': 'YDR376W'}
# Updating 3HPH5MBDC_m with {'enz': 'YDR539W'}
# Updating HKYNH_c with {'enz': 'YLR231C'}
# Updating HACD140i_x with {'enz': 'YKR009C'}
# Updating 3HAO_c with {'enz': 'YJR025C'}
# Updating 3IPM3MT_c with {'enz': 'YER175C'}
# Updating IPPMIa_c with {'enz': 'YGL009C'}
# Updating IPMD_c with {'enz': 'YCL018W'}
# Updating 3MOBDC_c with {'enz': 'YGR087C'}
# Updating MTMOHT_m with {'enz': 'YBR176W'}
# Updating PSCIT_c with {'enz': 'YDR127W'}
# Updating ADCS_c with {'enz': 'YNR033W'}
# Updating ADCL_c with {'enz': 'YMR289W'}
# Updating ABTA_c with {'enz': 'YGR019W'}
# Updating 4HTHRS_c with {'enz': 'YCR053W'}
# Updating 4HBZF_m with {'gene_reaction_rule': ''}
# Updating 4DPMIPPH_c with {'enz': 'YOR163W'}
# Updating IPPYP1_c with {'enz': 'YDR017C'}
# Updating MTAP_c with {'enz': 'YLR017W'}
# Updating NTD4pp_c with {'enz': 'YGL224C'}
# Updating NTD11_c with {'enz': 'YOR155C'}
# Updating NTD2pp_c with {'enz': 'YER037W'}
# Updating PRFGS_c with {'enz': 'YGR061C'}
# Updating MTHFR3_c with {'enz': 'YPL023C'}
# Updating ALAS_m with {'enz': 'YDR232W'}
# Updating PMI12346PS_c with {'enz': 'YDR017C'}
# Updating MHPGLUT_c with {'enz': 'YER091C'}
# Updating MDRPD_c with {'enz': 'YJR024C'}
# Updating MTRI_c with {'enz': 'YPR118W'}
# Updating IPPYP3_c with {'enz': 'YLR410W'}
# Updating PFK_4_c with {'enz': 'YOL136C'}
# Updating PGL_c with {'enz': 'YHR163W'}
# Updating 6DPMIPPH_c with {'enz': 'YOR163W'}
# Updating IPPYP4_c with {'enz': 'YDR017C'}
# Updating AOXS_c with {'enz': 'YAR069W-A'}
# Updating ACALDCD_c with {'enz': 'YGR087C'}
# Updating KARA1i_m with {'enz': 'YLR355C'}
# Updating ACLS_m with {'enz': 'YMR108W'}
# Updating ACOATA_m with {'enz': 'YKL192C'}
# Updating ACACT180i_x with {'enz': 'YIL160C'}
# Updating ACACT260i_x with {'enz': 'YIL160C'}
# Updating ACACT160i_x with {'enz': 'YIL160C'}
# Updating ACACT40ir_c with {'enz': 'YPL028W'}
# Updating ACACT40ir_m with {'enz': 'YPL028W'}
# Updating ACACT140i_x with {'enz': 'YIL160C'}
# Updating ACACT100i_x with {'enz': 'YIL160C'}
# Updating ACACT120i_x with {'enz': 'YIL160C'}
# Updating ACCOAC_m with {'enz': 'YMR207C'}
# Updating ACCOAC_c with {'enz': 'YDL141WYNR016C'}
# Updating ACOAHi_m with {'enz': 'YBL015W'}
# Updating ACS_c with {'enz': 'YLR153C'}
# Updating ACGK_m with {'enz': 'YER069W'}
# Updating ACP1_e with {'enz': 'YHR215W'}
# Updating ACONT2_m with {'enz': 'YPR002W'}
# Updating ACOTAi_m with {'enz': 'YOL140W'}
# Updating COAHL_m with {'enz': 'YPL148C'}
# Updating ACOAO100_x with {'enz': 'YGL205W'}
# Updating ACOAO120_x with {'enz': 'YGL205W'}
# Updating ACOAO260_x with {'enz': 'YGL205W'}
# Updating ACOAO160_x with {'enz': 'YGL205W'}
# Updating ACOAO180_x with {'enz': 'YGL205W'}
# Updating ACOAO140_x with {'enz': 'YGL205W'}
# Updating STATe181_rm with {'enz': 'YCR048W'}
# Updating STATg181_rm with {'enz': 'YNR019W'}
# Updating STATf181_rm with {'enz': 'YCR048W'}
# Updating STATl181_rm with {'enz': 'YCR048W'}
# Updating STATz181_rm with {'enz': 'YCR048W'}
# Updating STATe161_rm with {'enz': 'YCR048W'}
# Updating STATg161_rm with {'enz': 'YNR019W'}
# Updating STATf161_rm with {'enz': 'YCR048W'}
# Updating STATl161_rm with {'enz': 'YCR048W'}
# Updating STATz161_rm with {'enz': 'YCR048W'}
# Updating GPIA3_r with {'enz': 'YJL091C'}
# Updating ADD_c with {'enz': 'YNL141W'}
# Updating ADPT_c with {'enz': 'YML022W'}
# Updating ADA_c with {'enz': 'YNL141W'}
# Updating ADNK1_c with {'enz': 'YJR105W'}
# Updating AMPDA_c with {'enz': 'YML035C'}
# Updating AHCi_c with {'enz': 'YER043C'}
# Updating ADMDC_c with {'enz': 'YOL052C'}
# Updating AMAOTr_c with {'enz': 'YNR058W'}
# Updating ADNCYC_c with {'enz': 'YJL005W'}
# Updating ADK1_c with {'enz': 'YDL166C'}
# Updating ADK1_m with {'enz': 'YER170W'}
# Updating ADK3_m with {'enz': 'YER170W'}
# Updating ADSL2i_c with {'enz': 'YLR359W'}
# Updating ADSL1r_c with {'enz': 'YLR359W'}
# Updating ADSS_c with {'enz': 'YNL220W'}
# Updating ADSK_c with {'enz': 'YKL001C'}
# Updating 23CAPPD_c with {'enz': 'YGR247W'}
# Updating AGTi_c with {'enz': 'YFL030W'}
# Updating ALATRS_c with {'enz': 'YOR335C'}
# Updating OHACT3_c with {'enz': 'YOR377W'}
# Updating OHACT1_c with {'enz': 'YGR177C'}
# Updating OHACT2_c with {'enz': 'YGR177C'}
# Updating OHACT4_c with {'enz': 'YGR177C'}
# Updating OHACT5_c with {'enz': 'YGR177C'}
# Updating ALCD2i1_c with {'enz': 'YMR303C'}
# Updating ALCD19y_c with {'enz': 'YDR368W'}
# Updating ALCD2i2_m with {'enz': 'YGL256W'}
# Updating ALCD22xi_c with {'enz': 'YBR145W'}
# Updating ALCD22xi_m with {'enz': 'YMR083W'}
# Updating ALCD22yi_c with {'enz': 'YCR105W'}
# Updating ALCD25xi_c with {'enz': 'YBR145W'}
# Updating ALCD25xi_m with {'enz': 'YMR083W'}
# Updating ALDD22x_c with {'enz': 'YMR110C'}
# Updating ALDD2y_c with {'enz': 'YPL061W'}
# Updating ALDD2x_m with {'enz': 'YOR374W'}
# Updating ALDD2y_m with {'enz': 'YER073W'}
# Updating ALDD20x_m with {'enz': 'YOR374W'}
# Updating ALDD20y_c with {'enz': 'YPL061W'}
# Updating ALCD24xi_c with {'enz': 'YBR145W'}
# Updating ALCD24xi_m with {'enz': 'YMR083W'}
# Updating ALCD24yi_c with {'enz': 'YCR105W'}
# Updating ALCD23xi_c with {'enz': 'YBR145W'}
# Updating ALCD23xi_m with {'enz': 'YMR083W'}
# Updating ALCD23yi_c with {'enz': 'YCR105W'}
# Updating ALCD26xi_c with {'enz': 'YBR145W'}
# Updating ALCD26xi_m with {'enz': 'YMR083W'}
# Updating AKP1_c with {'enz': 'YDR481C'}
# Updating ATAH_c with {'enz': 'YIR029W'}
# Updating ALLTN_c with {'enz': 'YIR027C'}
# Updating ALPHNH_c with {'enz': 'YBR208C'}
# Updating 12AMANTF_g with {'enz': 'YBR205W'}
# Updating TREH_v with {'enz': 'YPR026W'}
# Updating TREH_c with {'enz': 'YDR001C'}
# Updating TRE6PS_c with {'enz': 'YBR126CYDR074WYML100W'}
# Updating MALT_c with {'enz': 'YBR299W'}
# Updating AMID_c with {'enz': 'YDR242W'}
# Updating AACTOOR_c with {'gene_reaction_rule': ''}
# Updating ABUTD_m with {'enz': 'YOR374W'}
# Updating ANPRT_c with {'enz': 'YDR354W'}
# Updating ANS_c with {'enz': 'YER090WYKL211C'}
# Updating AP4AH_c with {'enz': 'YDR305C'}
# Updating ARGN_c with {'enz': 'YPL111W'}
# Updating ARGSL_c with {'enz': 'YHR018C'}
# Updating ARGSS_c with {'enz': 'YOL058W'}
# Updating ARGTRS_c with {'enz': 'YDR341C'}
# Updating ARGTRS_m with {'enz': 'YHR091C'}
# Updating ASNS1_c with {'enz': 'YGR124W'}
# Updating ASNTRS_c with {'enz': 'YHR019C'}
# Updating ASNTRS_m with {'enz': 'YCR024C'}
# Updating ASPCT_c with {'enz': 'YJL130C'}
# Updating ASPK_c with {'enz': 'YER052C'}
# Updating ASPTA_c with {'enz': 'YLR027C'}
# Updating ASPTAi_m with {'enz': 'YKL106W'}
# Updating ASPTA_x with {'enz': 'YLR027C'}
# Updating ASAD_c with {'enz': 'YDR158W'}
# Updating ASPTRS_c with {'enz': 'YLL018C'}
# Updating ASPTRS_m with {'enz': 'YPL104W'}
# Updating ATPATF1_c with {'enz': 'YDR530C'}
# Updating ATPATF2_c with {'enz': 'YCL050C'}
# Updating ATPATF3_c with {'enz': 'YCL050C'}
# Updating ATPPRT_c with {'enz': 'YER055C'}
# Updating ATPS_m with {'enz': 'Q0080Q0085Q0130YBL099WYBR039WYDL004WYDR298CYDR322C-AYDR377WYJR121WYKL016CYLR295CYML081C-AYPL078CYPL271W'}
# Updating ATPASEP2e_c with {'enz': 'YCR024C-AYEL017C-AYPL036W'}
# Updating 14BMANTF_c with {'enz': 'YBR110W'}
# Updating BTS1_c with {'enz': 'YGR286C'}
# Updating C14STR_c with {'enz': 'YNL280C'}
# Updating C22STDSy_c with {'enz': 'YMR015C'}
# Updating C3STDH2_c with {'enz': 'YGL001C'}
# Updating C3STDH1_c with {'enz': 'YGL001C'}
# Updating C3STKR1_c with {'enz': 'YLR100W'}
# Updating C3STKR2_c with {'enz': 'YLR100W'}
# Updating C4STMO1_c with {'enz': 'YGR060W'}
# Updating C4STMO2_c with {'enz': 'YGR060W'}
# Updating C4STMO3_c with {'enz': 'YGR060W'}
# Updating C4STMO4_c with {'enz': 'YGR060W'}
# Updating C5STDS_c with {'enz': 'YLR056W'}
# Updating C8STI_c with {'enz': 'YMR202W'}
# Updating C24STR_r with {'enz': 'YGL012W'}
# Updating FRTT4HBZ_c with {'enz': 'YDL090CYKL019W'}
# Updating CBPS_c with {'enz': 'YJL130CYJR109CYOR303W'}
# Updating CRNOAT_c with {'enz': 'YER024W'}
# Updating CRNOAT_x with {'enz': 'YML042W'}
# Updating CRNOAT_m with {'enz': 'YML042W'}
# Updating CAT_c with {'enz': 'YGR088W'}
# Updating CAT_x with {'enz': 'YDR256C'}
# Updating CERH124A_r with {'enz': 'YDR297W'}
# Updating CERH124B_r with {'enz': 'YMR272C'}
# Updating CERH126A_r with {'enz': 'YDR297W'}
# Updating CERH126B_r with {'enz': 'YMR272C'}
# Updating CERS124_r with {'enz': 'YHL003CYMR298W'}
# Updating CERS126_r with {'enz': 'YKL008CYMR298W'}
# Updating CERS2A24_r with {'enz': 'YKL008CYMR298W'}
# Updating CERS2A26_r with {'enz': 'YKL008CYMR298W'}
# Updating CERH2A24_r with {'enz': 'YMR272C'}
# Updating CERH2A26_r with {'enz': 'YMR272C'}
# Updating CERH324_r with {'enz': 'YMR272C'}
# Updating CERH326_r with {'enz': 'YMR272C'}
# Updating CHTNDA_c with {'enz': 'YLR307W'}
# Updating CHTNS_c with {'enz': 'YNL192W'}
# Updating CHOLK_c with {'enz': 'YLR133W'}
# Updating CHLPCTD_c with {'enz': 'YGR202C'}
# Updating CHORM_c with {'enz': 'YPR060C'}
# Updating CHORS_c with {'enz': 'YGL148W'}
# Updating ACONTb_m with {'enz': 'YLR304C'}
# Updating FRTT_l with {'enz': 'YDL193WYMR101C'}
# Updating GGTT_l with {'enz': 'YDL193WYMR101C'}
# Updating PPTT_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT6_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT7_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT8_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT9_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT10_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT11_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT12_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT13_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT14_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT15_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT16_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT17_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT18_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT19_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT20_l with {'enz': 'YDL193WYMR101C'}
# Updating PRENT21_l with {'enz': 'YDL193WYMR101C'}
# Updating CS_m with {'enz': 'YNR001C'}
# Updating CS_x with {'enz': 'YCR005C'}
# Updating ACONTa_m with {'enz': 'YLR304C'}
# Updating ACONTa_c with {'enz': 'YLR304C'}
# Updating CPPPGO_c with {'enz': 'YDR044W'}
# Updating CTPS2_c with {'enz': 'YJR103W'}
# Updating CBL_c with {'enz': 'YFR055W'}
# Updating CYSTS_c with {'enz': 'YGR155W'}
# Updating CYSTGL_c with {'enz': 'YAL012W'}
# Updating METB1_c with {'enz': 'YJR130C'}
# Updating CYSS_c with {'enz': 'YLR303W'}
# Updating CYSTRS_c with {'enz': 'YNL247W'}
# Updating CYTD_c with {'enz': 'YLR245C'}
# Updating CYTDK2_c with {'enz': 'YNR012W'}
# Updating LNS14DMy_c with {'enz': 'YHR007CYHR042W'}
# Updating CSND_c with {'enz': 'YPR062W'}
# Updating ARAB14LO_c with {'enz': 'YML086C'}
# Updating ARAB1Dx_c with {'enz': 'YMR041C'}
# Updating ARAB1D2_c with {'enz': 'YBR149W'}
# Updating FBA2_c with {'enz': 'YKL060C'}
# Updating SBTD_D2_c with {'enz': 'YDL246C'}
# Updating DCMPDA_c with {'enz': 'YHR144C'}
# Updating DCTPD_c with {'enz': 'YHR144C'}
# Updating DADA_c with {'enz': 'YNL141W'}
# Updating DCYTD_c with {'enz': 'YLR245C'}
# Updating DGK1_c with {'enz': 'YDR454C'}
# Updating DXHPS_c with {'enz': 'YHR068W'}
# Updating DRBK_c with {'enz': 'YCR036W'}
# Updating DPCOAK_m with {'enz': 'YDR196C'}
# Updating DBTS_c with {'enz': 'YNR057C'}
# Updating DHCRD124_r with {'enz': 'YPL087W'}
# Updating DHCRD126_r with {'enz': 'YPL087W'}
# Updating DHCRD2A24_r with {'enz': 'YPL087W'}
# Updating DHCRD2A26_r with {'enz': 'YPL087W'}
# Updating DHFRi_c with {'enz': 'YOR236W'}
# Updating DHFRi_m with {'enz': 'YOR236W'}
# Updating DHFS_1_c with {'enz': 'YMR113W'}
# Updating DHNPA2i_m with {'enz': 'YNL256W'}
# Updating DNMPPA_c with {'enz': 'YDL100C'}
# Updating DHORTS_c with {'enz': 'YLR420W'}
# Updating DHPTS_m with {'enz': 'YNL256W'}
# Updating FOLD3_m with {'enz': 'YNL256W'}
# Updating DHAD1_m with {'enz': 'YJR016C'}
# Updating DHAD2_m with {'enz': 'YJR016C'}
# Updating DHAK_c with {'enz': 'YML070W'}
# Updating DMATT_c with {'enz': 'YJL167W'}
# Updating DPGM_c with {'enz': 'YKL152C'}
# Updating PMI1346PH_c with {'enz': 'YOR163W'}
# Updating PMI1346PS_c with {'enz': 'YDR017C'}
# Updating DIPS_c with {'enz': 'YLR172C'}
# Updating DOLK_c with {'enz': 'YMR013C'}
# Updating DOLPMT_c with {'enz': 'YPR183W'}
# Updating DOLPMMT_r with {'enz': 'YJR143C'}
# Updating DTMPK_c with {'enz': 'YJR057W'}
# Updating DUTPDP_c with {'enz': 'YBR252W'}
# Updating EPGALURS_e with {'enz': 'YJR153W'}
# Updating ENO_c with {'enz': 'YMR323W'}
# Updating ETHAK_c with {'enz': 'YDR147W'}
# Updating ACHLE3_c with {'enz': 'YOR126C'}
# Updating 13BGH_e with {'enz': 'YGR282C'}
# Updating FRTT_c with {'enz': 'YPL069C'}
# Updating FACOAL100_x with {'enz': 'YER015W'}
# Updating FACOAL120_x with {'enz': 'YER015W'}
# Updating FACOAL160_x with {'enz': 'YER015W'}
# Updating FACOAL80_x with {'enz': 'YER015W'}
# Updating FACOAL140_x with {'enz': 'YER015W'}
# Updating FCLT_m with {'enz': 'YOR176W'}
# Updating FECPOR_m with {'enz': 'YEL039CYKR066C'}
# Updating FECOOR_m with {'enz': 'Q0045Q0250Q0275YDL067CYDR231CYGR062CYHR116WYJL003WYLL018C-AYPL132W'}
# Updating FECRq6_m with {'enz': 'Q0105YBL045CYDR529CYEL024WYFR033CYGR183CYHR001W-AYJL166WYJR048WYOR065WYPR191W'}
# Updating AFAT_c with {'enz': 'YDL045C'}
# Updating FMNRx_c with {'enz': 'YLR011W'}
# Updating FMNRx2_c with {'enz': 'YLR011W'}
# Updating FDH_c with {'enz': 'YOR388C'}
# Updating FTHFL_c with {'enz': 'YGR204W'}
# Updating FTHFL_m with {'enz': 'YBR084W'}
# Updating FBP2_c with {'enz': 'YJL155C'}
# Updating FBP_c with {'enz': 'YLR377C'}
# Updating FBA_c with {'enz': 'YKL060C'}
# Updating FUM_m with {'enz': 'YPL262W'}
# Updating FUM_c with {'enz': 'YPL262W'}
# Updating DHORDfum_c with {'enz': 'YKL216W'}
# Updating FRD_m with {'enz': 'YJR051W'}
# Updating FRD_c with {'enz': 'YEL047C'}
# Updating GTMLT_c with {'enz': 'YLR299W'}
# Updating GALKi_c with {'enz': 'YBR020W'}
# Updating GLUCYS_c with {'enz': 'YJL101C'}
# Updating GGTT_c with {'gene_reaction_rule': ''}
# Updating GRTT_c with {'enz': 'YJL167W'}
# Updating GLCGSD_c with {'enz': 'YPR184W'}
# Updating GLCGSD_v with {'enz': 'YIL099W'}
# Updating G6PDA_c with {'gene_reaction_rule': ''}
# Updating G6PDH2i_c with {'enz': 'YNL241C'}
# Updating PGI_c with {'enz': 'YBR196C'}
# Updating GLU5K_c with {'enz': 'YDR300C'}
# Updating GLUDC_c with {'enz': 'YMR250W'}
# Updating GLUDxi_c with {'enz': 'YDL215C'}
# Updating GLUDy_c with {'enz': 'YAL062W'}
# Updating GLUSx_c with {'enz': 'YDL171C'}
# Updating G5SDy_c with {'enz': 'YOR323C'}
# Updating GLUN_c with {'enz': 'YFL060C'}
# Updating GLNS_c with {'enz': 'YPR035W'}
# Updating GF6PTA_c with {'enz': 'YMR084W'}
# Updating GLNTRS_c with {'enz': 'YOR168W'}
# Updating GLUTRS_c with {'enz': 'YGL105WYGL245W'}
# Updating GLUTRS_m with {'enz': 'YOL033W'}
# Updating GTHO_c with {'enz': 'YCL035CYPL091W'}
# Updating GTHO_m with {'enz': 'YPL059WYPL091W'}
# Updating GTHP_c with {'enz': 'YPL091W'}
# Updating GTHP_m with {'enz': 'YBL064C'}
# Updating GTHS_c with {'enz': 'YOL049W'}
# Updating GAPD_c with {'enz': 'YJR009C'}
# Updating GLYCDy_c with {'enz': 'YOR120W'}
# Updating GLYK_c with {'enz': 'YHL032C'}
# Updating G3PT_c with {'enz': 'YER062C'}
# Updating G3PDf_m with {'enz': 'YIL155C'}
# Updating G3PD1r_c with {'enz': 'YDL022W'}
# Updating GPDDA1pp_c with {'enz': 'YPL110C'}
# Updating GARFT_c with {'enz': 'YDR408C'}
# Updating GLYAT_c with {'gene_reaction_rule': ''}
# Updating GLYCL_m with {'enz': 'YAL044CYDR019CYFL018CYMR189W'}
# Updating GHMT2r_c with {'enz': 'YLR058C'}
# Updating GHMT2r_m with {'enz': 'YBR263W'}
# Updating GLYGS_c with {'enz': 'YFR015CYJL137C'}
# Updating GLCP_c with {'enz': 'YPR160W'}
# Updating GLYTRS_c with {'enz': 'YPR081C'}
# Updating GMPS2_c with {'enz': 'YMR217W'}
# Updating GPIA2_r with {'enz': 'YMR281W'}
# Updating GPIA5_r with {'enz': 'YCL052CYJR013W'}
# Updating GPIA6_r with {'enz': 'YKL165C'}
# Updating GPIA7_r with {'enz': 'YBR004CYNL158W'}
# Updating GPIA8_r with {'enz': 'YGL142C'}
# Updating GPIA9_r with {'enz': 'YLL031C'}
# Updating GTPCI_c with {'enz': 'YGR267C'}
# Updating GTPCII2_c with {'enz': 'YBL033C'}
# Updating GUAD_1_c with {'enz': 'YDL238C'}
# Updating GUAPRT_c with {'enz': 'YDR399W'}
# Updating GK1_c with {'enz': 'YDR454C'}
# Updating GK2_c with {'enz': 'YDR454C'}
# Updating HOMOX_m with {'enz': 'YDR376WYER141WYPL252C'}
# Updating HEMEOS_m with {'enz': 'YPL172C'}
# Updating Q6MT2_m with {'enz': 'YDR204WYGL119WYGR255CYLR201CYML110CYOL096CYOR125C'}
# Updating HEX7_c with {'enz': 'YGL253W'}
# Updating HEX1_c with {'enz': 'YCL040W'}
# Updating HEX4_c with {'enz': 'YGL253W'}
# Updating HISTD_c with {'enz': 'YCL030C'}
# Updating HISTP_c with {'enz': 'YFR025C'}
# Updating HSTPT_c with {'enz': 'YIL116W'}
# Updating HISTRS_c with {'enz': 'YPR033C'}
# Updating HISTRS_m with {'enz': 'YPR033C'}
# Updating ARMT_c with {'enz': 'YBR034C'}
# Updating HACNH_m with {'enz': 'YJL200C'}
# Updating HCYSMT_c with {'enz': 'YLL062C'}
# Updating HICITD_m with {'enz': 'YIL094C'}
# Updating HSDx_c with {'enz': 'YJR139C'}
# Updating HSDy_c with {'enz': 'YJR139C'}
# Updating HSK_c with {'enz': 'YHR025W'}
# Updating HSERTA_c with {'enz': 'YNL277W'}
# Updating THIORDXi_c with {'enz': 'YDR453CYLR043C'}
# Updating THIORDXi_x with {'enz': 'YLR043CYLR109W'}
# Updating GLYOX_c with {'enz': 'YDR272W'}
# Updating GLYOX_m with {'enz': 'YOR040W'}
# Updating HBZOPT6_m with {'enz': 'YNR041C'}
# Updating HETZK_c with {'enz': 'YPL214C'}
# Updating PPBNGD_c with {'enz': 'YDL205C'}
# Updating HMGCOAR_c with {'enz': 'YLR450W'}
# Updating HMGCOAS_c with {'enz': 'YML126C'}
# Updating HMGCOAS_m with {'enz': 'YML126C'}
# Updating HMPK1_c with {'enz': 'YOL055C'}
# Updating HXPRT_c with {'enz': 'YDR399W'}
# Updating IG3PS_c with {'enz': 'YBR248C'}
# Updating IGPDH_c with {'enz': 'YOR202W'}
# Updating IMPD_c with {'enz': 'YLR432W'}
# Updating IGPS_c with {'enz': 'YKL211C'}
# Updating INDPYRD_c with {'enz': 'YGR087C'}
# Updating PPA_c with {'enz': 'YBR011C'}
# Updating PPA_m with {'enz': 'YMR267W'}
# Updating IMPC_c with {'enz': 'YMR120C'}
# Updating IPK1_n with {'enz': 'YDR315C'}
# Updating IPK2_n with {'enz': 'YDR173C'}
# Updating IPK3_n with {'enz': 'YDR173C'}
# Updating IPK4_n with {'enz': 'YDR173C'}
# Updating IPK5_n with {'enz': 'YDR173C'}
# Updating ACHLE1_c with {'enz': 'YOR126C'}
# Updating ACHLE2_c with {'enz': 'YOR126C'}
# Updating ICDHx_m with {'enz': 'YNL037CYOR136W'}
# Updating ICDHy_c with {'enz': 'YLR174W'}
# Updating ICDHy_x with {'enz': 'YNL009W'}
# Updating ICL_1_c with {'enz': 'YER065C'}
# Updating ILETA_c with {'enz': 'YJR148W'}
# Updating ILETA_m with {'enz': 'YHR208W'}
# Updating ILETRS_c with {'enz': 'YBL076C'}
# Updating ILETRS_m with {'enz': 'YPL040C'}
# Updating IPDDI_c with {'enz': 'YPL117C'}
# Updating ITCOAL_m with {'enz': 'YGR244CYOR142W'}
# Updating KARA2i_m with {'enz': 'YLR355C'}
# Updating KYN_c with {'enz': 'YLR231C'}
# Updating KYN3OX_c with {'enz': 'YBL098W'}
# Updating PHCD_m with {'enz': 'YHR037W'}
# Updating 4HGLSD_m with {'enz': 'YHR037W'}
# Updating ALATA_L_m with {'enz': 'YLR089C'}
# Updating THRA2_c with {'enz': 'YEL046C'}
# Updating ATHRDHr_c with {'enz': 'YMR226C'}
# Updating AASADy_c with {'enz': 'YBR115CYGL154C'}
# Updating ASNN_c with {'enz': 'YDR321W'}
# Updating ASNN_e with {'enz': 'YLR158C'}
# Updating EGHLAT_c with {'enz': 'YLR027C'}
# Updating EGHLAT_m with {'enz': 'YKL106W'}
# Updating EGHLAT_x with {'enz': 'YLR027C'}
# Updating HPRORy_c with {'enz': 'YER023W'}
# Updating LALDO3_c with {'enz': 'YOL151W'}
# Updating SERD_L_c with {'enz': 'YCL064C'}
# Updating LSERDHi_c with {'enz': 'YMR226C'}
# Updating THRD_L_c with {'enz': 'YCL064C'}
# Updating THRD_L_m with {'enz': 'YCL064C'}
# Updating TRPO2_c with {'enz': 'YJR078W'}
# Updating TYRNFT_c with {'enz': 'YDR403W'}
# Updating LGTHL_c with {'enz': 'YML004C'}
# Updating LNSTLS_c with {'enz': 'YHR072W'}
# Updating LEUTA_c with {'enz': 'YJR148W'}
# Updating LEUTA_m with {'enz': 'YHR208W'}
# Updating LEUTRS_c with {'enz': 'YPL160W'}
# Updating LEUTRS_m with {'enz': 'YLR382C'}
# Updating LTA4H_c with {'enz': 'YNL045W'}
# Updating LTA4H_n with {'enz': 'YNL045W'}
# Updating LTA4H2_c with {'enz': 'YNL045W'}
# Updating LTA4H2_n with {'enz': 'YNL045W'}
# Updating LTA4H3_c with {'enz': 'YNL045W'}
# Updating LTA4H3_n with {'enz': 'YNL045W'}
# Updating LYSTRS_c with {'enz': 'YDR037W'}
# Updating LYSTRS_m with {'enz': 'YNL073W'}
# Updating MDH_m with {'enz': 'YKL085W'}
# Updating MDH_c with {'enz': 'YOL126C'}
# Updating MDH_x with {'enz': 'YDL078C'}
# Updating MALS_c with {'enz': 'YNL117W'}
# Updating ME1_m with {'enz': 'YKL029C'}
# Updating ME2_m with {'enz': 'YKL029C'}
# Updating MCOATA_m with {'enz': 'YKL192CYOR221C'}
# Updating MAN1PT_c with {'enz': 'YDL055C'}
# Updating MAN6PI_c with {'enz': 'YER003C'}
# Updating MTHFC_m with {'enz': 'YBR084W'}
# Updating MTHFC_c with {'enz': 'YGR204W'}
# Updating METAT_c with {'enz': 'YDR502C'}
# Updating METS_c with {'enz': 'YER091C'}
# Updating FMETTRS_m with {'enz': 'YBL013W'}
# Updating METTRS_c with {'enz': 'YGL105WYGR264C'}
# Updating METTRS_m with {'enz': 'YGR171C'}
# Updating MTHFD2i_c with {'enz': 'YKR080W'}
# Updating MTHFD_c with {'enz': 'YGR204W'}
# Updating MTHFD_m with {'enz': 'YBR084W'}
# Updating MCITL2_m with {'enz': 'YPR006C'}
# Updating MEVK1_c with {'enz': 'YMR208W'}
# Updating MEVK2_c with {'enz': 'YMR208W'}
# Updating MEVK3_c with {'enz': 'YMR208W'}
# Updating MEVK4_c with {'enz': 'YMR208W'}
# Updating DPMVD_c with {'enz': 'YNR043W'}
# Updating MI1PP_c with {'enz': 'YHR046C'}
# Updating M1PS_c with {'enz': 'YJL153C'}
# Updating AGPRi_m with {'enz': 'YER069W'}
# Updating ACGAM6PS_c with {'enz': 'YFL017C'}
# Updating ACGS_m with {'enz': 'YJL071W'}
# Updating FKYNH_c with {'enz': 'YDR428C'}
# Updating NFTYROX_c with {'enz': 'YDR402CYDR403W'}
# Updating NADDP_x with {'enz': 'YGL067W'}
# Updating NADK_c with {'enz': 'YEL041W'}
# Updating NADK_m with {'enz': 'YPL188W'}
# Updating NADN_n with {'enz': 'YPL015C'}
# Updating NADS2_c with {'enz': 'YHR074W'}
# Updating NADS2_n with {'enz': 'YHR074W'}
# Updating NADHq6_c with {'enz': 'YMR145C'}
# Updating NADHK1_c with {'enz': 'YEL041W'}
# Updating NADHK1_m with {'enz': 'YJR049C'}
# Updating NADHq6_m with {'enz': 'YML120C'}
# Updating NAMNPP_c with {'enz': 'YOR209C'}
# Updating NAMNPP_m with {'enz': 'YOR209C'}
# Updating NNAM_c with {'enz': 'YGL037C'}
# Updating NNMT_c with {'enz': 'YLR285W'}
# Updating ANNAT_c with {'enz': 'YCL047C'}
# Updating ANNAT_n with {'enz': 'YGR010W'}
# Updating NNATi_c with {'enz': 'YLR328W'}
# Updating NNDPR_c with {'enz': 'YFR047C'}
# Updating NNDPR_m with {'enz': 'YFR047C'}
# Updating NDP1_c with {'enz': 'YER005W'}
# Updating NDP3_c with {'enz': 'YER005W'}
# Updating NDP7_c with {'enz': 'YER005W'}
# Updating NDP7_g with {'enz': 'YEL042W'}
# Updating NDP5_c with {'enz': 'YER005W'}
# Updating NDP10_c with {'enz': 'YER005W'}
# Updating NDPK3_c with {'enz': 'YKL067W'}
# Updating NDPK8_c with {'enz': 'YKL067W'}
# Updating NDPK7_c with {'enz': 'YKL067W'}
# Updating NDPK5_c with {'enz': 'YKL067W'}
# Updating NDPK4_c with {'enz': 'YKL067W'}
# Updating NDPK1_c with {'enz': 'YKL067W'}
# Updating NDPK9_c with {'enz': 'YKL067W'}
# Updating NDPK10_c with {'enz': 'YKL067W'}
# Updating NDPK6_c with {'enz': 'YKL067W'}
# Updating NTP3_c with {'enz': 'YAL035W'}
# Updating NTP7_c with {'enz': 'YER005W'}
# Updating NTP5_c with {'enz': 'YER005W'}
# Updating NTP10_c with {'enz': 'YER005W'}
# Updating NDP3_g with {'enz': 'YEL042W'}
# Updating NDPK2_c with {'enz': 'YKL067W'}
# Updating AHSERL_c with {'enz': 'YLR303W'}
# Updating AHSERL2_c with {'enz': 'YLR303W'}
# Updating SHSL1_c with {'enz': 'YLL058W'}
# Updating OCBT_c with {'enz': 'YJL088W'}
# Updating ORNDC_c with {'enz': 'YKL184W'}
# Updating ORNTA_c with {'enz': 'YLR438W'}
# Updating ORPT_c with {'enz': 'YMR271C'}
# Updating OMPDC_c with {'enz': 'YEL021W'}
# Updating PTPAT_c with {'enz': 'YGR277C'}
# Updating PNTK_c with {'enz': 'YDR531W'}
# Updating PBAL_c with {'enz': 'YIL145C'}
# Updating FACOAE100_x with {'enz': 'YJR019C'}
# Updating FACOAE120_x with {'enz': 'YJR019C'}
# Updating FACOAE160_x with {'enz': 'YJR019C'}
# Updating FACOAE140_x with {'enz': 'YJR019C'}
# Updating FACOAE180_x with {'enz': 'YJR019C'}
# Updating FACOAE80_x with {'enz': 'YJR019C'}
# Updating PHETRS_c with {'enz': 'YFL022CYLR060W'}
# Updating PHETRS_m with {'enz': 'YPR047W'}
# Updating PPYRDC_c with {'enz': 'YDR380W'}
# Updating PRAIS_c with {'enz': 'YGL234W'}
# Updating ACGAMPM_c with {'enz': 'YEL058W'}
# Updating PAPSR_c with {'enz': 'YLR043CYPR167C'}
# Updating PPCK_c with {'enz': 'YKR097W'}
# Updating PETHCT_c with {'enz': 'YGR007W'}
# Updating PFK_c with {'enz': 'YMR205C'}
# Updating PGMT_c with {'enz': 'YMR105C'}
# Updating GND_c with {'enz': 'YHR183W'}
# Updating PGAMT_c with {'enz': 'YEL058W'}
# Updating PGCD_c with {'enz': 'YER081W'}
# Updating PGK_c with {'enz': 'YCR012W'}
# Updating PGM_c with {'enz': 'YOR283W'}
# Updating PMANM_c with {'enz': 'YFL045C'}
# Updating PMPK_c with {'enz': 'YPR121W'}
# Updating PMEVK_c with {'enz': 'YMR220W'}
# Updating PPNCL2_c with {'enz': 'YIL083C'}
# Updating PPCDC_c with {'enz': 'YKL088WYOR054C'}
# Updating PPM_c with {'enz': 'YMR278W'}
# Updating PRASCSi_c with {'enz': 'YAR015W'}
# Updating PRAMPC_c with {'enz': 'YCL030C'}
# Updating PRATPP_c with {'enz': 'YCL030C'}
# Updating AIRC1_c with {'enz': 'YOR128C'}
# Updating AICART_c with {'enz': 'YLR028C'}
# Updating PRAIi_c with {'enz': 'YDR007W'}
# Updating PRAGSi_c with {'enz': 'YGL234W'}
# Updating GLUPRT_c with {'enz': 'YMR300C'}
# Updating PRPPS_c with {'enz': 'YBL068WYKL181W'}
# Updating PSP_L_c with {'enz': 'YGR208W'}
# Updating PSERT_c with {'enz': 'YOR184W'}
# Updating CERSFA2A24_r with {'enz': 'YBR183W'}
# Updating PSPHPL_r with {'enz': 'YDR294C'}
# Updating PSPHS_r with {'enz': 'YDR297W'}
# Updating POLYAO1_c with {'enz': 'YMR020W'}
# Updating PPBNGS_1_c with {'enz': 'YGL040C'}
# Updating POLYAO2_c with {'enz': 'YMR020W'}
# Updating POLYAO3_c with {'enz': 'YMR020W'}
# Updating PPNDH_c with {'enz': 'YNL316C'}
# Updating PPND2_c with {'enz': 'YBR166C'}
# Updating PROD2_m with {'enz': 'YLR142W'}
# Updating PROTRS_c with {'enz': 'YHR020W'}
# Updating PPPGO_m with {'enz': 'YER014W'}
# Updating PNP_c with {'enz': 'YLR209C'}
# Updating PUNP3_c with {'enz': 'YLR209C'}
# Updating PUNP3_m with {'enz': 'YLR209C'}
# Updating PUNP5_c with {'enz': 'YLR209C'}
# Updating PYDXO_c with {'enz': 'YBR035C'}
# Updating PYAM5PO_c with {'enz': 'YBR035C'}
# Updating PDX5POi_c with {'enz': 'YBR035C'}
# Updating PYDXNO_c with {'enz': 'YBR035C'}
# Updating P5CR_c with {'enz': 'YER023W'}
# Updating PC_c with {'enz': 'YBR218C'}
# Updating PYRDC_c with {'enz': 'YGR087C'}
# Updating PYRDC2_c with {'enz': 'YGR087C'}
# Updating PDH_m with {'enz': 'YBR221CYER178WYFL018CYGR193CYNL071W'}
# Updating PYK_c with {'enz': 'YAL038W'}
# Updating Q6OR_m with {'enz': 'YDR204WYGL119WYGR255CYLR201CYML110CYOL096CYOR125C'}
# Updating RBFK_c with {'enz': 'YDR236C'}
# Updating RBFK_m with {'enz': 'YDR236C'}
# Updating RBFSa_c with {'enz': 'YOL143C'}
# Updating RBFSb_c with {'enz': 'YBR256C'}
# Updating RBK_c with {'enz': 'YCR036W'}
# Updating RNDR1_c with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR1_n with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR3_c with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR3_n with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR4_c with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR4_n with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR2_c with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RNDR2_n with {'enz': 'YER070WYGR180CYJL026W'}
# Updating RPI_c with {'enz': 'YOR095C'}
# Updating RNMK_c with {'enz': 'YNL129W'}
# Updating RPE_c with {'enz': 'YJL121C'}
# Updating 3DH5HPBMT_m with {'enz': 'YDR204WYGL119WYGR255CYLR201CYML110CYOL096CYOR125C'}
# Updating SAM24MT_c with {'enz': 'YML008C'}
# Updating SFGTHi_c with {'enz': 'YJL068C'}
# Updating SACCD2_c with {'enz': 'YIR034C'}
# Updating SACCD1_c with {'enz': 'YNR050C'}
# Updating FBA3_c with {'enz': 'YKL060C'}
# Updating SERAT_c with {'enz': 'YDL040CYHR013CYOR253W'}
# Updating SERPT_r with {'enz': 'YDR062WYMR296C'}
# Updating SERTRS_c with {'enz': 'YHR011W'}
# Updating SHK3Di_c with {'enz': 'YDR127W'}
# Updating SHKK_c with {'enz': 'YDR127W'}
# Updating SHCHD2_c with {'enz': 'YBR213W'}
# Updating SHCHF_c with {'enz': 'YBR213W'}
# Updating SPMS_c with {'enz': 'YPR069C'}
# Updating SPRMS_c with {'enz': 'YLR146C'}
# Updating SPHPL_r with {'enz': 'YDR294C'}
# Updating SBPP2_r with {'enz': 'YJL134W'}
# Updating SBPP1_r with {'enz': 'YJL134W'}
# Updating SPHGLpK_r with {'enz': 'YLR260W'}
# Updating SLCBK1_r with {'enz': 'YOR171C'}
# Updating ACONIs_m with {'gene_reaction_rule': 'SPONT'}
# Updating ACONIs_c with {'gene_reaction_rule': 'SPONT'}
# Updating SQLEx_r with {'enz': 'YGR175C'}
# Updating SQLEy_r with {'enz': 'YGR175C'}
# Updating SQLS_c with {'enz': 'YHR190W'}
# Updating SUCDq6_m with {'enz': 'YDR178WYJL045WYKL141WYLL041C'}
# Updating SUCOAS_m with {'enz': 'YGR244CYOR142W'}
# Updating SSALy_c with {'enz': 'YBR006W'}
# Updating SUCR_e with {'enz': 'YIL162W'}
# Updating SADT_c with {'enz': 'YJR010W'}
# Updating SLFAT_c with {'enz': 'YCL050C'}
# Updating SO3R_c with {'enz': 'YFR030WYJR137C'}
# Updating TAUDO_c with {'enz': 'YLL057C'}
# Updating THFGLUS_c with {'enz': 'YOR241W'}
# Updating THMP_e with {'enz': 'YBR092C'}
# Updating TMDPK_c with {'enz': 'YOR143C'}
# Updating TMDPPK_c with {'enz': 'YOR143C'}
# Updating TMPPP_c with {'enz': 'YPL214C'}
# Updating THIORDXi_n with {'enz': 'YIL010WYLR043C'}
# Updating TRDR_c with {'enz': 'YDR353W'}
# Updating TRDR_m with {'enz': 'YCR083WYHR106W'}
# Updating THRA_c with {'enz': 'YEL046C'}
# Updating THRS_c with {'enz': 'YCR053W'}
# Updating THRTRS_c with {'enz': 'YIL078W'}
# Updating THRTRS_m with {'enz': 'YKL194C'}
# Updating TMDS_c with {'enz': 'YOR074C'}
# Updating ACONMT_c with {'enz': 'YER175C'}
# Updating PPTT_m with {'enz': 'YBR003W'}
# Updating TALA_c with {'enz': 'YGR043C'}
# Updating TKT1_c with {'enz': 'YPR074C'}
# Updating TKT2_c with {'enz': 'YPR074C'}
# Updating TRE6PP_c with {'enz': 'YBR126CYDR074WYML100W'}
# Updating TPI_c with {'enz': 'YDR050C'}
# Updating TRPS1_c with {'enz': 'YGL026C'}
# Updating TRPTRS_c with {'enz': 'YOL097C'}
# Updating TRPTRS_m with {'enz': 'YDR268W'}
# Updating TYRTA_c with {'enz': 'YGL202W'}
# Updating TYRTAi_x with {'enz': 'YLR027C'}
# Updating TYRTRS_c with {'enz': 'YGR185C'}
# Updating TYRTRS_m with {'enz': 'YPL097W'}
# Updating ERGSTGLCT_c with {'enz': 'YLR189C'}
# Updating UAGDP_c with {'enz': 'YDL103C'}
# Updating UDPG4E_c with {'enz': 'YBR019C'}
# Updating UGLT_c with {'enz': 'YBR018C'}
# Updating UMPK_c with {'enz': 'YKL024C'}
# Updating UMPK_n with {'enz': 'YKL024C'}
# Updating UPPRT_c with {'enz': 'YHR128W'}
# Updating UREASE_c with {'enz': 'YBR208C'}
# Updating ULGYCH_c with {'enz': 'YIR032C'}
# Updating URIK1_c with {'enz': 'YDR020C'}
# Updating URIK2_c with {'enz': 'YNR012W'}
# Updating URIDK2i_c with {'enz': 'YKL024C'}
# Updating URIDK2_n with {'enz': 'YKL024C'}
# Updating UPPDC1_c with {'enz': 'YDR047W'}
# Updating UPP3MT_2_c with {'enz': 'YKR069W'}
# Updating UPP3S_c with {'enz': 'YOR278W'}
# Updating GALUi_c with {'enz': 'YKL035W'}
# Updating VALTA_c with {'enz': 'YJR148W'}
# Updating VALTA_m with {'enz': 'YHR208W'}
# Updating VALTRS_c with {'enz': 'YGR094W'}
# Updating VALTRS_m with {'enz': 'YGR094W'}
# Updating XPPT_c with {'enz': 'YJR133W'}
# Updating XYLTD_D_c with {'enz': 'YLR070C'}
# Updating XYLR_c with {'enz': 'YHR104W'}
# Updating XYLK_c with {'enz': 'YGR194C'}
# Updating YUMPS_c with {'enz': 'YNL292W'}
# Updating HCITS_m with {'enz': 'YDL131W'}
# Updating PYDXNK_c with {'enz': 'YEL029C'}
# Updating KYNIs_c with {'gene_reaction_rule': 'SPONT'}
# Updating QUILSYN_c with {'gene_reaction_rule': 'SPONT'}
# Updating SBP_c with {'enz': 'YKR043C'}
# Updating ICDHyi_m with {'enz': 'YDL066W'}
# Updating lumpFACS160_c with {'enz': 'YKL182WYPL231W'}
# Updating lumpFACS180_c with {'enz': 'YKL182WYPL231W'}
# Updating KAS14_m with {'enz': 'YER061CYKL192C'}
# Updating 3OAS60_m with {'enz': 'YER061CYKL192C'}
# Updating 3OAS80_m with {'enz': 'YER061CYKL192C'}
# Updating 3OAR40_m with {'enz': 'YKL055C'}
# Updating 3OAR60_m with {'enz': 'YKL055C'}
# Updating 3OAR80_m with {'enz': 'YKL055C'}
# Updating 3HAD40_m with {'enz': 'YHR067W'}
# Updating 3HAD60_m with {'enz': 'YHR067W'}
# Updating 3HAD80_m with {'enz': 'YHR067W'}
# Updating EAR40y_m with {'enz': 'YBR026C'}
# Updating EAR60y_m with {'enz': 'YBR026C'}
# Updating EAR80y_m with {'enz': 'YBR026C'}
# Updating 3OACE200_rm with {'enz': 'YCR034W'}
# Updating 3OACE220_rm with {'enz': 'YCR034W'}
# Updating 3OACE240_rm with {'enz': 'YCR034W'}
# Updating 3OACR200_rm with {'enz': 'YBR159W'}
# Updating 3OACR220_rm with {'enz': 'YBR159W'}
# Updating 3OACR240_rm with {'enz': 'YBR159W'}
# Updating 3OACR260_rm with {'enz': 'YBR159W'}
# Updating 3HACD200_rm with {'enz': 'YJL097W'}
# Updating 3HACD220_rm with {'enz': 'YJL097W'}
# Updating 3HACD240_rm with {'enz': 'YJL097W'}
# Updating 3HACD260_rm with {'enz': 'YJL097W'}
# Updating ECOAR200_rm with {'enz': 'YDL015C'}
# Updating ECOAR220_rm with {'enz': 'YDL015C'}
# Updating ECOAR240_rm with {'enz': 'YDL015C'}
# Updating ECOAR260_rm with {'enz': 'YDL015C'}
# Updating ACOADS160_rm with {'enz': 'YGL055W'}
# Updating ACOADS180_rm with {'enz': 'YGL055W'}
# Updating FACOAL120_rm with {'enz': 'YOR317W'}
# Updating FACOAL140_rm with {'enz': 'YMR246W'}
# Updating FACOAL160_rm with {'enz': 'YOR317W'}
# Updating FACOAL161_rm with {'enz': 'YOR317W'}
# Updating FACOAL180_rm with {'enz': 'YOR317W'}
# Updating FACOAL181_rm with {'enz': 'YOR317W'}
# Updating FACOAL120_l with {'enz': 'YOR317W'}
# Updating FACOAL140_l with {'enz': 'YOR317W'}
# Updating FACOAL160_l with {'enz': 'YOR317W'}
# Updating FACOAL161_l with {'enz': 'YOR317W'}
# Updating FACOAL180_l with {'enz': 'YOR317W'}
# Updating FACOAL181_l with {'enz': 'YOR317W'}
# Updating FACOAL161_x with {'enz': 'YER015W'}
# Updating FACOAL180_x with {'enz': 'YER015W'}
# Updating FACOAL181_x with {'enz': 'YER015W'}
# Updating FACOAL200_en with {'enz': 'YIL009W'}
# Updating FACOAL220_en with {'enz': 'YIL009W'}
# Updating FACOAL240_en with {'enz': 'YIL009W'}
# Updating FACOAL260_en with {'enz': 'YIL009W'}
# Updating FACOAL220_l with {'enz': 'YBR041W'}
# Updating FACOAL240_l with {'enz': 'YBR041W'}
# Updating FACOAL260_l with {'enz': 'YBR041W'}
# Updating FACOAE40_x with {'enz': 'YJR019C'}
# Updating FACOAE60_x with {'enz': 'YJR019C'}
# Updating FACOAE161_x with {'enz': 'YJR019C'}
# Updating FACOAE181_x with {'enz': 'YJR019C'}
# Updating ACOAO40_x with {'enz': 'YGL205W'}
# Updating ACOAO60_x with {'enz': 'YGL205W'}
# Updating ACOAO80_x with {'enz': 'YGL205W'}
# Updating ACOAO200_x with {'enz': 'YGL205W'}
# Updating ACOAO220_x with {'enz': 'YGL205W'}
# Updating ACOAO240_x with {'enz': 'YGL205W'}
# Updating ACOAO161b_x with {'enz': 'YGL205W'}
# Updating ACOAO141b_x with {'enz': 'YGL205W'}
# Updating ACOAO121a_x with {'enz': 'YGL205W'}
# Updating ACOAO181a_x with {'enz': 'YGL205W'}
# Updating ACOAO161a_x with {'enz': 'YGL205W'}
# Updating ACOAO141a_x with {'enz': 'YGL205W'}
# Updating ECOAH100_x with {'enz': 'YKR009C'}
# Updating ECOAH120_x with {'enz': 'YKR009C'}
# Updating ECOAH140_x with {'enz': 'YKR009C'}
# Updating ECOAH160_x with {'enz': 'YKR009C'}
# Updating ECOAH180_x with {'enz': 'YKR009C'}
# Updating ECOAH260_x with {'enz': 'YKR009C'}
# Updating ECOAH40_x with {'enz': 'YKR009C'}
# Updating ECOAH60_x with {'enz': 'YKR009C'}
# Updating ECOAH80_x with {'enz': 'YKR009C'}
# Updating ECOAH200_x with {'enz': 'YKR009C'}
# Updating ECOAH220_x with {'enz': 'YKR009C'}
# Updating ECOAH240_x with {'enz': 'YKR009C'}
# Updating ECOAH161b_x with {'enz': 'YKR009C'}
# Updating ECOAH141b_x with {'enz': 'YKR009C'}
# Updating ECOAH121a_x with {'enz': 'YKR009C'}
# Updating ECOAH181a_x with {'enz': 'YKR009C'}
# Updating ECOAH161c_x with {'enz': 'YKR009C'}
# Updating ECOAH141c_x with {'enz': 'YKR009C'}
# Updating HACD100i_x with {'enz': 'YKR009C'}
# Updating HACD120i_x with {'enz': 'YKR009C'}
# Updating HACD160i_x with {'enz': 'YKR009C'}
# Updating HACD180i_x with {'enz': 'YKR009C'}
# Updating HACD260i_x with {'enz': 'YKR009C'}
# Updating HACD40i_x with {'enz': 'YKR009C'}
# Updating HACD60i_x with {'enz': 'YKR009C'}
# Updating HACD80i_x with {'enz': 'YKR009C'}
# Updating HACD200i_x with {'enz': 'YKR009C'}
# Updating HACD220i_x with {'enz': 'YKR009C'}
# Updating HACD240i_x with {'enz': 'YKR009C'}
# Updating HACD161bi_x with {'enz': 'YKR009C'}
# Updating HACD141bi_x with {'enz': 'YKR009C'}
# Updating HACD121ai_x with {'enz': 'YKR009C'}
# Updating HACD181ai_x with {'enz': 'YKR009C'}
# Updating HACD161ai_x with {'enz': 'YKR009C'}
# Updating HACD141ai_x with {'enz': 'YKR009C'}
# Updating ACACT40i_x with {'enz': 'YIL160C'}
# Updating ACACT60i_x with {'enz': 'YIL160C'}
# Updating ACACT80i_x with {'enz': 'YIL160C'}
# Updating ACACT200i_x with {'enz': 'YIL160C'}
# Updating ACACT220i_x with {'enz': 'YIL160C'}
# Updating ACACT240i_x with {'enz': 'YIL160C'}
# Updating ACACT161bi_x with {'enz': 'YIL160C'}
# Updating ACACT141bi_x with {'enz': 'YIL160C'}
# Updating ACACT121ai_x with {'enz': 'YIL160C'}
# Updating ACACT181ai_x with {'enz': 'YIL160C'}
# Updating ACACT161ai_x with {'enz': 'YIL160C'}
# Updating ACACT141ai_x with {'enz': 'YIL160C'}
# Updating ECOAI101a_x with {'enz': 'YLR284C'}
# Updating ECOAI122c_x with {'enz': 'YLR284C'}
# Updating ECOAI121b_x with {'enz': 'YLR284C'}
# Updating ECOAI121a_x with {'enz': 'YLR284C'}
# Updating ECOAI142c_x with {'enz': 'YLR284C'}
# Updating ECOAI141a_x with {'enz': 'YLR284C'}
# Updating ECOAI5d_x with {'enz': 'YOR180C'}
# Updating ECOAI6d_x with {'enz': 'YOR180C'}
# Updating ECOAR122_x with {'enz': 'YNL202W'}
# Updating ECOAR142_x with {'enz': 'YNL202W'}
# Updating ACONTb_c with {'enz': 'YLR304C'}
# Updating STEHg161_l with {'enz': 'YKL140W'}
# Updating STEHg181_l with {'enz': 'YKL140W'}
# Updating STEHe181_l with {'enz': 'YLL012W'}
# Updating STEHf161_l with {'enz': 'YLL012W'}
# Updating STEHf181_l with {'enz': 'YLL012W'}
# Updating STEHl161_l with {'enz': 'YLL012W'}
# Updating STEHl181_l with {'enz': 'YLL012W'}
# Updating STEHz161_l with {'enz': 'YLL012W'}
# Updating STEHz181_l with {'enz': 'YLL012W'}
# Updating STEHz161_en with {'enz': 'YLR020C'}
# Updating STEHz181_en with {'enz': 'YLR020C'}
# Updating SUCACCT_m with {'enz': 'YBL015W'}
# Updating RAFH_e with {'enz': 'YIL020C'}
# Updating URIH_c with {'enz': 'YDR400W'}
# Updating GTHRDtabc_v with {'enz': 'YDR135C'}
# Updating TCHOLAtabc_v with {'enz': 'YLL048C'}
# Updating ATPASEVg_c with {'enz': 'YBR127CYDL185WYEL027WYEL051WYGR020CYHR026WYHR039C-AYKL080WYLR447CYMR054WYOR332WYPL234CYPR036W'}
# Updating ATPASEVv_c with {'enz': 'YBR127CYDL185WYEL027WYEL051WYGR020CYHR026WYHR039C-AYKL080WYLR447CYOR270CYOR332WYPL234CYPR036W'}
# Updating MEVt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating BTDt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 2MBACt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 2OXOADPt_c_m with {'enz': 'YPL134C'}
# Updating 3DH5HPBt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 4ABUTtps_e with {'enz': 'YDL210W'}
# Updating 5FTHFt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 8AONNtps_e with {'enz': 'YNR056C'}
# Updating ACt_c_e with {'enz': 'YCR010C'}
# Updating ETACt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating ADEtps_e with {'enz': 'YER060W'}
# Updating ADNtps_e with {'enz': 'YAL022C'}
# Updating ADPATPt_c_m with {'enz': 'YMR056C'}
# Updating ADPATPt_c_x with {'enz': 'YPR128C'}
# Updating AKGCITta_m with {'enz': 'YMR241W'}
# Updating ALLTTt_c_e with {'enz': 'YJR152W'}
# Updating ALLTNt_c_e with {'enz': 'YIR028W'}
# Updating NH4t_c_e with {'enz': 'YGR121C'}
# Updating AMPATPt_c_x with {'enz': 'YPR128C'}
# Updating ASPGLUt_c_m with {'enz': 'YPR021C'}
# Updating BTNtps_e with {'enz': 'YGR065C'}
# Updating CRNACRNt_c_m with {'enz': 'YOR100C'}
# Updating CER2B24_g_r with {'gene_reaction_rule': ''}
# Updating CER2B26_g_r with {'gene_reaction_rule': ''}
# Updating CHOLtps_e with {'enz': 'YGL077C'}
# Updating CITMALta_m with {'enz': 'YBR291C'}
# Updating CITPEPt_c_m with {'enz': 'YBR291C'}
# Updating CITICITt_c_m with {'enz': 'YBR291C'}
# Updating COAt_c_m with {'enz': 'YHR002W'}
# Updating CTPt2_m with {'enz': 'YBR192W'}
# Updating CTPCMPt_c_m with {'enz': 'YBR192W'}
# Updating CYTDtps_e with {'enz': 'YAL022C'}
# Updating CSNtps_e with {'enz': 'YER060W-A'}
# Updating FRUtps_e with {'enz': 'YMR011W'}
# Updating GALtps_e with {'enz': 'YLR081W'}
# Updating LACDtps_e with {'enz': 'YKL217W'}
# Updating LACtps_m with {'gene_reaction_rule': 'SPONT'}
# Updating LACPYRt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating MANtps_e with {'enz': 'YJL214W'}
# Updating EPISTt_c_e with {'enz': 'YIL013C'}
# Updating ERGSTt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating ETHAt_c_e with {'enz': 'YGL077C'}
# Updating FADH2t_c_m with {'enz': 'YIL134W'}
# Updating FECOSTt_e with {'enz': 'YOR011W'}
# Updating FECOSTt_en with {'enz': 'YOR011W'}
# Updating FOLt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating GDPMANt_c_g with {'enz': 'YGL225W'}
# Updating GLCt_c_e with {'enz': 'YDR387C'}
# Updating GTHRDt_c_e with {'enz': 'YJL212C'}
# Updating GTHRDt_c_v with {'enz': 'YLL015W'}
# Updating G3PIt_c_e with {'enz': 'YCR098C'}
# Updating G3PCt_c_e with {'enz': 'YCR098C'}
# Updating GLYCtps_e with {'enz': 'YGL084C'}
# Updating GLYCt_e with {'enz': 'YFL054C'}
# Updating GLYtps_e with {'enz': 'YPL265W'}
# Updating GLYCOGENt_c_v with {'gene_reaction_rule': 'SPONT'}
# Updating GTPGDPtp_m with {'enz': 'YDL198C'}
# Updating GUAtps_e with {'enz': 'YER060W-A'}
# Updating INOSTtps_e with {'enz': 'YOL103W'}
# Updating FE2t_c_e with {'enz': 'YMR058W'}
# Updating FE2t_c_m with {'enz': 'YJL133W'}
# Updating IAMACt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating IBUTACt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating IPDPt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating ALAtps_e with {'enz': 'YDR046C'}
# Updating ARGtps_e with {'enz': 'YNL270C'}
# Updating ARGtpa_v with {'enz': 'YBR293W'}
# Updating ASNtps_e with {'enz': 'YDR508C'}
# Updating ASNtpa_v with {'enz': 'YJR001W'}
# Updating ASNtps_v with {'enz': 'YNL101W'}
# Updating ASPtps_v with {'enz': 'YER119C'}
# Updating ASPtps_e with {'enz': 'YFL055W'}
# Updating CRNt_e with {'enz': 'YBR132C'}
# Updating CYStps_e with {'enz': 'YBR069C'}
# Updating CYSItps_v with {'enz': 'YCR075C'}
# Updating GLUt_c_m with {'enz': 'YBR104W'}
# Updating GLUtps_v with {'enz': 'YER119C'}
# Updating GLNtpa_v with {'enz': 'YJR001W'}
# Updating GLNtps_v with {'enz': 'YNL101W'}
# Updating GLNtps_e with {'enz': 'YKR039W'}
# Updating HIStpa_v with {'enz': 'YMR088C'}
# Updating HIStps_e with {'enz': 'YGR191W'}
# Updating ILEt_c_v with {'enz': 'YCL038C'}
# Updating ILEtpa_v with {'enz': 'YJR001W'}
# Updating ILEtps_v with {'enz': 'YNL101W'}
# Updating LACt_c_m with {'enz': 'YKL217W'}
# Updating LACLtps_e with {'enz': 'YKL217W'}
# Updating LEUt_c_v with {'enz': 'YCL038C'}
# Updating LEUtpa_v with {'enz': 'YJR001W'}
# Updating LEUtps_v with {'enz': 'YNL101W'}
# Updating LYStpa_v with {'enz': 'YMR088C'}
# Updating LYStps_e with {'enz': 'YNL268W'}
# Updating METtps_e with {'enz': 'YGR055W'}
# Updating SERtps_e with {'enz': 'YDR105C'}
# Updating TYRt_c_v with {'enz': 'YCL038C'}
# Updating TYRtps_v with {'enz': 'YNL101W'}
# Updating VALtps_e with {'enz': 'YBR069C'}
# Updating LANOSTt_c_e with {'enz': 'YOR011W'}
# Updating MALt2_m with {'enz': 'YLR348C'}
# Updating MALTtps_e with {'enz': 'YGR289C'}
# Updating NFORTYR2t_c_e with {'enz': 'YBR180W'}
# Updating NADt_c_m with {'enz': 'YEL006W'}
# Updating NADt2_m with {'enz': 'YIL006W'}
# Updating NADt3_m with {'enz': 'YIL006W'}
# Updating NACt_c_e with {'enz': 'YGR260W'}
# Updating ORNtpa_m with {'enz': 'YOR130C'}
# Updating OAAtps_m with {'enz': 'YKL120W'}
# Updating PNTOtps_e with {'enz': 'YCR028C'}
# Updating PENDPt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating PHEACt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating PItps_e with {'enz': 'YJL198W'}
# Updating PItps_m with {'enz': 'YER053C'}
# Updating Ktps_e with {'enz': 'YDR456W'}
# Updating PTRCtpa_e with {'enz': 'YOR273C'}
# Updating PTRCtpa_v with {'enz': 'YOR273C'}
# Updating PYRtps_e with {'enz': 'YKL217W'}
# Updating AMETtps_e with {'enz': 'YPL274W'}
# Updating AMETt_c_m with {'enz': 'YNL003C'}
# Updating MMETtps_e with {'enz': 'YLL061W'}
# Updating NAtpa_e with {'enz': 'YLR138W'}
# Updating SPMDtpa_e with {'enz': 'YHL016C'}
# Updating SPMDtpa_v with {'enz': 'YOR273C'}
# Updating SPRMtpa_e with {'enz': 'YPR156C'}
# Updating SPRMtpa_v with {'enz': 'YGR138C'}
# Updating SUCCt2_m with {'enz': 'YLR348C'}
# Updating SUCFUMt_c_m with {'enz': 'YJR095W'}
# Updating SO4t_c_e with {'enz': 'YLR092W'}
# Updating SO3t_c_e with {'enz': 'YPL092W'}
# Updating TAURt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating THMPPt_m with {'enz': 'YGR096W'}
# Updating THMtps_e with {'enz': 'YOR192C'}
# Updating URAtps_e with {'enz': 'YBR021W'}
# Updating URItps_e with {'enz': 'YBL042C'}
# Updating UTPt_c_m with {'enz': 'YBR192W'}
# Updating UTPUMPtp_m with {'enz': 'YBR192W'}
# Updating H2Ot_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating ZYMSTt_e_en with {'enz': 'YOR011W'}
# Updating ARGtps_m with {'enz': 'YBR147W'}
# Updating PYRtps_m with {'enz': 'YGL080WYGR243W'}
# Updating AKGMALta_m with {'enz': 'YPL134C'}
# Updating FACOA120tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA140tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA160tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA161tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA180tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA181tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA200tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA220tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA240tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating FACOA260tabc_x with {'enz': 'YKL188CYPL147W'}
# Updating EX_13BDglucan_e with {'gene_reaction_rule': ''}
# Updating 13BDGLUCANt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating EX_crn_e with {'gene_reaction_rule': ''}
# Updating EX_lac__D_e with {'gene_reaction_rule': ''}
# Updating EX_mev__R_e with {'gene_reaction_rule': ''}
# Updating EX_pnto__R_e with {'gene_reaction_rule': ''}
# Updating EX_btd_e with {'gene_reaction_rule': ''}
# Updating EX_3mop_e with {'gene_reaction_rule': ''}
# Updating EX_lac__L_e with {'gene_reaction_rule': ''}
# Updating EX_mal__L_e with {'gene_reaction_rule': ''}
# Updating EX_g3pi_e with {'gene_reaction_rule': ''}
# Updating EX_1agpc_gen_e with {'gene_reaction_rule': ''}
# Updating MI13456Pt_c_n with {'gene_reaction_rule': 'SPONT'}
# Updating MI1Pt_c_r with {'gene_reaction_rule': 'SPONT'}
# Updating EX_dad_2_e with {'gene_reaction_rule': ''}
# Updating EX_dgsn_e with {'gene_reaction_rule': ''}
# Updating EX_din_e with {'gene_reaction_rule': ''}
# Updating EX_duri_e with {'gene_reaction_rule': ''}
# Updating 2DDA7Pt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 2DHPt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating EX_3c3hmp_e with {'gene_reaction_rule': ''}
# Updating 3C3HMPt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 3C3HMPt_c_m with {'enz': 'YKL120W'}
# Updating 2MBTOHt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 2MBTOHt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating EX_2mbald_e with {'gene_reaction_rule': ''}
# Updating 2MBALDt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 2MBALDt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating EX_2mbtoh_e with {'gene_reaction_rule': ''}
# Updating EX_2mbac_e with {'gene_reaction_rule': ''}
# Updating IBTALDt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating IBTALDt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 2OBUTt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating EX_akg_e with {'gene_reaction_rule': ''}
# Updating AKGt_c_n with {'gene_reaction_rule': 'SPONT'}
# Updating AKGt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating EX_2phetoh_e with {'gene_reaction_rule': ''}
# Updating 2PHETOHt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 2PHETOHt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 3C4MOPt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 3MOPt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 3MOPt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating EX_3mbald_e with {'gene_reaction_rule': ''}
# Updating 3MBALDt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 3MBALDt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 3HXPHBt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating AHMMPS4_c with {'enz': 'YFL058W'}
# Updating EX_4abz_e with {'gene_reaction_rule': ''}
# Updating 4ABZt_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating 4ABZt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating 4ABUTNt_c_m with {'gene_reaction_rule': 'SPONT'}
# ...
# Updating G3PIt_c_en with {'enz': 'YCR098C'}
# Updating HDCAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating HDCEAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating OCDCAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating OCDCEAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating ICOSCOAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating DOCOSCOAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating TTCCOAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating HXCCOAt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating H2Ot_c_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PIt_c_vm with {'enz': 'YNR013C'}
# Updating Ht_c_vm with {'gene_reaction_rule': 'SPONT'}
# Updating ATPt_c_vm with {'gene_reaction_rule': 'SPONT'}
# Updating ADPt_c_vm with {'gene_reaction_rule': 'SPONT'}
# Updating CO2t_c_vm with {'gene_reaction_rule': 'SPONT'}
# Updating H2Ot_c_gm with {'gene_reaction_rule': 'SPONT'}
# Updating PIt_c_gm with {'gene_reaction_rule': 'SPONT'}
# Updating Ht_c_gm with {'gene_reaction_rule': 'SPONT'}
# Updating CO2t_c_gm with {'gene_reaction_rule': 'SPONT'}
# Updating ATPt_c_gm with {'gene_reaction_rule': 'SPONT'}
# Updating ADPt_c_gm with {'gene_reaction_rule': 'SPONT'}
# Updating H2Ot_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating CO2t_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating HDCOAt_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating ODECOAt_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating HDCAt_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating OCDCAt_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating COAt_c_mm with {'enz': 'YHR002W'}
# Updating DDCAt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating TTDCAt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating TTCt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating HXCAt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating EPISTt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating FECOSTt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating LANOSTt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ZYMSTt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ERGST161t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ERGST181t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating EPIST161t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating EPIST181t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating FECOST161t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating FECOST181t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating LANOST161t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating LANOST181t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ZYM161t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ZYM181t_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating TTCt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating HXCAt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ZYM161t_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ZYM181t_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating TTCt_r_rm with {'gene_reaction_rule': 'SPONT'}
# Updating HXCAt_r_rm with {'gene_reaction_rule': 'SPONT'}
# Updating ERGSTt_r_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PIt_r_rm with {'gene_reaction_rule': 'SPONT'}
# Updating Ht_m_mm with {'gene_reaction_rule': 'SPONT'}
# Updating GLYC3Pt_m_mm with {'gene_reaction_rule': 'SPONT'}
# Updating CMPt_m_mm with {'enz': 'YBR192W'}
# Updating CTPt_m_mm with {'enz': 'YBR192W'}
# Updating PPIt_m_mm with {'gene_reaction_rule': 'SPONT'}
# Updating HEMEAt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating EX_melib_e with {'gene_reaction_rule': ''}
# Updating ATPM_c with {'gene_reaction_rule': ''}
# Updating CYCCL_m with {'enz': 'YKL087C'}
# Updating ACTNOR_c with {'enz': 'YAL061W'}
# Updating ACTNOR_n with {'enz': 'YAL061W'}
# Updating PADPRGH_c with {'enz': 'YBR022W'}
# Updating ADPRIB1P_c with {'enz': 'YBR046C'}
# Updating ALG14RXN_r with {'enz': 'YBR070CYGL047W'}
# Updating ARGt_c_v with {'enz': 'YDR352W'}
# Updating HISt_c_v with {'enz': 'YBR147W'}
# Updating LYSt_c_v with {'enz': 'YBR147W'}
# Updating NA1CLKt_c_v with {'enz': 'YBR235W'}
# Updating GTHH_c with {'enz': 'YBR281CYNL191W'}
# Updating MN2tabc_c_r with {'enz': 'YEL031W'}
# Updating OAADC_c with {'enz': 'YER010C'}
# Updating GTHCT_c with {'enz': 'YER163C'}
# Updating ZN2t_c_r with {'enz': 'YIL023C'}
# Updating 5OPROAH_c with {'enz': 'YKL215C'}
# Updating CYSGLYP_c with {'enz': 'YFR044C'}
# Updating FMNH_c with {'enz': 'YDL024C'}
# Updating NA1tabc_c_e with {'enz': 'YDR040C'}
# Updating GLCNK_c with {'enz': 'YDR248C'}
# Updating DNTPPY2_c with {'enz': 'YJR069C'}
# Updating DNTPPY3_c with {'enz': 'YJR069C'}
# Updating APOOCT_m with {'enz': 'YLR239C'}
# Updating APOLIPT_m with {'enz': 'YLR239C'}
# Updating 4ABTORx_c with {'enz': 'YMR110C'}
# Updating r_4323_m with {'enz': 'YOR196C'}
# Updating r_4324_m with {'enz': 'YOR196C'}
# Updating MG2t_c_m with {'enz': 'YPL060W'}
# Updating PYDXR_c with {'enz': 'YPR127W'}
# Updating ENPP_c with {'enz': 'YDR452W'}
# Updating 2HGOR_c with {'gene_reaction_rule': ''}
# Updating CA2tps_c_e with {'enz': 'YOL122C'}
# Updating CUtps_c_e with {'enz': 'YOL122C'}
# Updating ZN2tps_c_e with {'enz': 'YGL255W'}
# Updating MG2tps_c_e with {'enz': 'YOL130W'}
# Updating EX_cl_e with {'gene_reaction_rule': ''}
# Updating EX_cu2_e with {'gene_reaction_rule': ''}
# Updating EX_mn2_e with {'gene_reaction_rule': ''}
# Updating EX_zn2_e with {'gene_reaction_rule': ''}
# Updating EX_mg2_e with {'gene_reaction_rule': ''}
# Updating EX_ca2_e with {'gene_reaction_rule': ''}
# Updating PIt_c_g with {'gene_reaction_rule': 'SPONT'}
# Updating PPCOAt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating UDPt_c_g with {'gene_reaction_rule': 'SPONT'}
# Updating UDPt_c_n with {'gene_reaction_rule': 'SPONT'}
# Updating UMPt_c_g with {'gene_reaction_rule': 'SPONT'}
# Updating DHAPAT_rm with {'enz': 'YBL011W'}
# Updating G3PAT_rm with {'enz': 'YKR067W'}
# Updating G3PAT_l with {'enz': 'YKR067W'}
# Updating AGNPR_rm with {'enz': 'YIL124W'}
# Updating AGNPR_l with {'enz': 'YIL124W'}
# Updating AGPAT_rm with {'enz': 'YOR175C'}
# Updating AGPAT_l with {'enz': 'YOR081C'}
# Updating ETHAPT_rm with {'enz': 'YHR123W'}
# Updating CHOLPT_rm with {'enz': 'YNL130C'}
# Updating CDPDAGS_rm with {'enz': 'YBR029C'}
# Updating PSSA_rm with {'enz': 'YER026C'}
# Updating PAILS_rm with {'enz': 'YPR113W'}
# Updating PGPS_mm with {'enz': 'YCL004W'}
# Updating PGPP_mm with {'enz': 'YHR100C'}
# Updating CLPNS_mm with {'enz': 'YDL142C'}
# Updating 1MLCLAT_mm with {'enz': 'YPR140W'}
# Updating 3MLCLAT_mm with {'enz': 'YPR140W'}
# Updating PAP_rm with {'enz': 'YMR165C'}
# Updating PAP_vm with {'enz': 'YDR284C'}
# Updating PAP_gm with {'enz': 'YDR503C'}
# Updating DGAT_rm with {'enz': 'YOR245C'}
# Updating DGAT_l with {'enz': 'YOR245C'}
# Updating TAGL_l with {'enz': 'YCR068W'}
# Updating DAGL_m with {'enz': 'YDR058C'}
# Updating MAGL_l with {'enz': 'YKL094W'}
# Updating DAGK_rm with {'enz': 'YOR311C'}
# Updating PAK_gm with {'gene_reaction_rule': ''}
# Updating PAK_vm with {'gene_reaction_rule': ''}
# Updating DGPP_vm with {'enz': 'YDR284C'}
# Updating DGPP_gm with {'enz': 'YDR503C'}
# Updating LPAP_vm with {'enz': 'YDR284C'}
# Updating LPAP_c with {'enz': 'YER037W'}
# Updating LPAP_gm with {'enz': 'YDR503C'}
# Updating PDAGATpe_rm with {'enz': 'YNR008W'}
# Updating PDAGATpc_rm with {'enz': 'YNR008W'}
# Updating PSD_mm with {'enz': 'YNL169C'}
# Updating PSD_gm with {'enz': 'YGR170W'}
# Updating PSD_vm with {'enz': 'YGR170W'}
# Updating PEMT_rm with {'enz': 'YGR157W'}
# Updating PMEMT_rm with {'enz': 'YJR073C'}
# Updating PDMEMT_rm with {'enz': 'YJR073C'}
# Updating LPCAT_mm with {'gene_reaction_rule': ''}
# Updating LPEAT_l with {'enz': 'YMR313C'}
# Updating PLAA2pe_l with {'enz': 'YKR089C'}
# Updating PLAclpn1_mm with {'enz': 'YGR110W'}
# Updating PLAclpn3_mm with {'enz': 'YGR110W'}
# Updating PLABlpc_en with {'enz': 'YMR008C'}
# Updating PLABlpc_rm with {'enz': 'YML059C'}
# Updating PLABlpe_en with {'enz': 'YMR006C'}
# Updating PLABlpi_en with {'enz': 'YOL011W'}
# Updating PLABpc_en with {'enz': 'YMR008C'}
# Updating PLABpc_rm with {'enz': 'YML059C'}
# Updating PLABpe_en with {'enz': 'YMR006C'}
# Updating PLABpi_en with {'enz': 'YOL011W'}
# Updating PLABps_en with {'enz': 'YOL011W'}
# Updating PLACipc_r with {'enz': 'YER019W'}
# Updating PLACmipc_r with {'enz': 'YER019W'}
# Updating PLACmip2c_r with {'enz': 'YER019W'}
# Updating PLACipc_m with {'enz': 'YER019W'}
# Updating PLACmipc_m with {'enz': 'YER019W'}
# Updating PLACmip2c_m with {'enz': 'YER019W'}
# Updating PLACpail45p_c with {'enz': 'YPL268W'}
# Updating PLACpail45p_n with {'enz': 'YPL268W'}
# Updating PLACpg_mm with {'enz': 'YPL206C'}
# Updating PLADpc_en with {'enz': 'YKR031C'}
# Updating PI3PP_en with {'enz': 'YOR109W'}
# Updating PI3PP_c with {'enz': 'YJR110W'}
# Updating PI3PP_rm with {'enz': 'YKL212W'}
# Updating PI3PP_gm with {'enz': 'YKL212W'}
# Updating PI4PP_en with {'enz': 'YOR109W'}
# Updating PI4PP_c with {'enz': 'YOR109W'}
# Updating PI4PP_rm with {'enz': 'YKL212W'}
# Updating PI4PP_gm with {'enz': 'YKL212W'}
# Updating LPIAT_rm with {'enz': 'YBR042C'}
# Updating PAIL4K_en with {'enz': 'YLR305C'}
# Updating PAIL4K_gm with {'enz': 'YDR373WYNL267W'}
# Updating PAIL4K_n with {'enz': 'YNL267W'}
# Updating PAIL3K_vm with {'enz': 'YBR097WYLR240W'}
# Updating PI4P5K_n with {'enz': 'YDR208W'}
# Updating PI4P5K_en with {'enz': 'YDR208W'}
# Updating PI45P5P_c with {'enz': 'YIL002C'}
# Updating PI45P5P_en with {'enz': 'YIL002C'}
# Updating PI45P5P_rm with {'enz': 'YOL065C'}
# Updating PI3P5K_vm with {'enz': 'YFR019WYFR021WYLR386WYNL054WYNL325C'}
# Updating PI35P5P_en with {'enz': 'YOR109W'}
# Updating PI35P5P_c with {'enz': 'YOR109W'}
# Updating PI35P5P_vm with {'enz': 'YLR386WYNL325C'}
# Updating IPCS_g with {'enz': 'YDR367WYKL004W'}
# Updating MIPCS_g with {'enz': 'YBR036CYPL057C'}
# Updating IPT_g with {'enz': 'YDR072C'}
# Updating compCER_m with {'gene_reaction_rule': 'SPONT'}
# Updating compCER_r with {'gene_reaction_rule': 'SPONT'}
# Updating compCER_g with {'gene_reaction_rule': 'SPONT'}
# Updating compACYLCOA_c with {'gene_reaction_rule': 'SPONT'}
# Updating compACYLCOA_l with {'gene_reaction_rule': 'SPONT'}
# Updating compACYLCOA_m with {'gene_reaction_rule': 'SPONT'}
# Updating compACYLCOA_r with {'gene_reaction_rule': 'SPONT'}
# Updating compACYLCOA_rm with {'gene_reaction_rule': 'SPONT'}
# Updating compACYLCOA_x with {'gene_reaction_rule': 'SPONT'}
# Updating compFALPD_mm with {'gene_reaction_rule': 'SPONT'}
# Updating compFALPD_l with {'gene_reaction_rule': 'SPONT'}
# Updating compFALPD_m with {'gene_reaction_rule': 'SPONT'}
# Updating compFALPD_rm with {'gene_reaction_rule': 'SPONT'}
# Updating compFALPD_en with {'gene_reaction_rule': 'SPONT'}
# Updating PAt_gm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAt_mm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAt_rm_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating DAGt_c_l with {'gene_reaction_rule': 'SPONT'}
# Updating DAGt_c_mm with {'gene_reaction_rule': 'SPONT'}
# Updating DAGt_c_n with {'gene_reaction_rule': 'SPONT'}
# Updating DAGt_c_rm with {'gene_reaction_rule': 'SPONT'}
# Updating DAGt_gm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating TAGt_c_rm with {'gene_reaction_rule': 'SPONT'}
# Updating TAGt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating 1AGPEt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating 1AGPCt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PSt_c_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PSt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PSt_mm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PSt_gm_rm with {'enz': 'YIL048W'}
# Updating PSt_rm_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAILt_c_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAILt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAILt_rm_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAILt_gm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAILt_n_rm with {'gene_reaction_rule': 'SPONT'}
# Updating CERt_g_r with {'gene_reaction_rule': 'SPONT'}
# Updating PCt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PCt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PCt_mm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PCt_c_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PEt_l_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PEt_gm_rm with {'enz': 'YAL026C'}
# Updating PEt_c_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PEt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PEt_mm_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PEt_rm_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL4Pt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL4Pt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL45Pt_c_n with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL45Pt_c_en with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL45Pt_en_rm with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL3Pt_gm_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL3Pt_rm_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL35Pt_c_vm with {'gene_reaction_rule': 'SPONT'}
# Updating PAIL35Pt_en_vm with {'gene_reaction_rule': 'SPONT'}
# Updating IPCt_g_r with {'gene_reaction_rule': 'SPONT'}
# Updating MIPCt_g_r with {'gene_reaction_rule': 'SPONT'}
# Updating MIP2Ct_g_r with {'gene_reaction_rule': 'SPONT'}
# Updating BIOMASS_AERO_SC_RBA with {'gene_reaction_rule': 'SPONT'}
# Updating AKGDH_m with {'enz': 'YDR148CYFL018CYIL125W'}
# Updating ETFOXRq6_m with {'enz': 'YGR207CYOR356WYPR004C'}
# Updating FADt_c_m with {'enz': 'YIL134W'}
# Updating PYDX5PS_c with {'enz': 'YFL059WYMR095C'}
# Updating PRENT13_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT11_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT20_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT16_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT8_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT19_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT14_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT7_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT12_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT21_rm with {'enz': 'YBR002CYDL193W'}
# Updating GGTT_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT6_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT10_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT18_rm with {'enz': 'YBR002CYDL193W'}
# Updating FRTT_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT17_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT9_rm with {'enz': 'YBR002CYDL193W'}
# Updating PPTT_rm with {'enz': 'YBR002CYDL193W'}
# Updating PRENT15_rm with {'enz': 'YBR002CYDL193W'}
# Updating SERD_L_m with {'enz': 'YCL064C'}
# Updating HCITS_c with {'enz': 'YDL182W'}
# Updating HCITt_c_m with {'gene_reaction_rule': 'SPONT'}
# Updating THFGLUS_m with {'enz': 'YKL132C'}
# Updating PEPSM1_c with {'enz': 'YBL091C'}
# Updating FLPT_c with {'enz': 'YDR538W'}
# Updating FMETTRS_c with {'enz': 'YBL013W'}
# Updating LDHDf_c with {'enz': 'YEL071W'}
# Updating compCERANAERO_r with {'gene_reaction_rule': 'SPONT'}
# Updating BIOMASS_BATCHANAERO_SC_hvd with {'gene_reaction_rule': 'SPONT'}
# Updating BIOMASS_CHEMOANAERO_SC_hvd with {'gene_reaction_rule': 'SPONT'}
# Updating BIOMASS_STARVEAERO_SC_hvd with {'gene_reaction_rule': 'SPONT'}
# Updating BIOMASS_STARVEANAERO_SC_hvd with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT1_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT2_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT3_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT4_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT5_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT6_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT7_c with {'gene_reaction_rule': 'SPONT'}
# Updating DICAT8_c with {'gene_reaction_rule': 'SPONT'}
# Updating EX_cobalt2_e with {'gene_reaction_rule': 'SPONT'}
# Updating COBALT2t_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating EX_ni2_e with {'gene_reaction_rule': 'SPONT'}
# Updating NI2t_c_e with {'gene_reaction_rule': 'SPONT'}
# Updating HEME1_c with {'gene_reaction_rule': 'SPONT'}
# Updating HEME2_c with {'gene_reaction_rule': 'SPONT'}
# Updating HEME3_c with {'gene_reaction_rule': 'SPONT'}
# Updating HEME4_c with {'gene_reaction_rule': 'SPONT'}
# Updating LIPOATE_m with {'gene_reaction_rule': 'SPONT'}
# Updating MONCAT1_c with {'gene_reaction_rule': 'SPONT'}
# Updating MONCAT2_c with {'gene_reaction_rule': 'SPONT'}
# Updating MONCAT3_c with {'gene_reaction_rule': 'SPONT'}

# %%
# convert df_enz_rxns to old ENZYME_stoich_curation file format from 2024 version of scRBA, for compatibility
df_rxn_enz_pairs = pd.DataFrame(columns=['id','rxn_src','enz','protein_stoich'])
catalyst_rxn_dict = {**spont_rxn_dict, **enz_rxn_dict}
for k, v in catalyst_rxn_dict.items():
	if k in spont_rxn_dict:
		catalyst_rxn_dict[k]['rxns'].extend(spont_rxn_dict[k]['rxns']) # adds rxns that were overrided by merger with enz_rxn_dict
		catalyst_rxn_dict[k]['rxns'] = list(dict.fromkeys(catalyst_rxn_dict[k]['rxns']))
for enz in catalyst_rxn_dict:
	enz_id = enz if enz != '' else 'SPONT'
	# don't seem to need MW of enzyme in prior RBA code
	prot_stoich_str = 'zeroCost' if enz in spont_GPRs + [''] else ','.join([prot+':'+str(catalyst_rxn_dict[enz]['protein_stoich'][prot]) for prot in catalyst_rxn_dict[enz]['protein_stoich']])
	for rxn in catalyst_rxn_dict[enz]['rxns']:
		dirs = []
		# add FWD and REV to rxn_src if those directions are possible
		if model.reactions.get_by_id(rxn).lower_bound < 0:
			dirs.append('REV')
		if model.reactions.get_by_id(rxn).upper_bound > 0:
			dirs.append('FWD')
		for dir in dirs:
			# print(enz,rxn)
			# df_rxn_enz_pairs = df_rxn_enz_pairs.append({'id':f'RXN-{rxn}_{dir}-{enz}','enz':enz,'gpr':'','protein_stoich':','.join([prot+':'+str(enz_rxn_dict[enz]['protein_stoich'][prot]) for prot in enz_rxn_dict[enz]['protein_stoich']]),'status':'automatically added'}, ignore_index=True)
			df_rxn_enz_pairs.loc[len(df_rxn_enz_pairs)] = [f'RXN-{rxn}_{dir}-{enz_id}',rxn,enz,prot_stoich_str]
			# df_rxn_enz_pairs = pd.concat([df_rxn_enz_pairs,pd.DataFrame({'id':f'RXN-{rxn}_{dir}-{enz}','enz':enz,'protein_stoich':','.join([prot+':'+str(enz_rxn_dict[enz]['protein_stoich'][prot]) for prot in enz_rxn_dict[enz]['protein_stoich']])})], ignore_index=True)

# sort by ID
df_rxn_enz_pairs = df_rxn_enz_pairs.sort_values(by='id')			
df_rxn_enz_pairs.to_csv('./model/ENZYME_rxn_pairs.tsv', sep='\t', index=False)

# %%
df_eqn = pd.DataFrame(columns=['id', 'type', 'coupling_type', 'coupling_species', 'reaction','tag','FBA_name','dir','enz_id'])
c = -1
medium = []

### Metabolic network reaction
# Exchange reactions
for rxn in model.reactions:
	# check if rxn is in df_enz
	# if rxn.id not in df_enz.rxn_src.to_list():
	if rxn.id[:3] == 'EX_':
		enz_id = 'SPONT'
		make_reversible = True
# else:
# 	gpr = rxn.gene_reaction_rule if rxn.gene_reaction_rule != "" else 'UNKNOWN'

		protein_stoich = 'zeroCost' if enz_id in spont_GPRs else ''
		
		met = [i for i in rxn.metabolites.keys()][0]
		c += 1
		tag = 'RXN'
		dir = 'FWD'
		new_id = f'{tag}-{rxn.id}_{dir}-{enz_id}'
		df_eqn.loc[c, 'id'] = new_id
		df_eqn.loc[c, 'type'] = 'metabolic'
		df_eqn.loc[c, 'reaction'] = 'MET-' + met.id + ' -->'
		# df_eqn.loc[c, ['FBA_name','dir']] = [rxn.id,'FWD']
		df_eqn.loc[c, ['tag','FBA_name','dir','enz_id']] = [tag,rxn.id,dir,enz_id]
		
		c += 1
		dir = 'REV'
		new_id = f'{tag}-{rxn.id}_{dir}-{enz_id}'
		df_eqn.loc[c, 'id'] = new_id
		df_eqn.loc[c, 'type'] = 'metabolic'
		df_eqn.loc[c, 'reaction'] = '-->' + 'MET-' + met.id
		# df_eqn.loc[c, ['FBA_name','dir']] = [rxn.id,'REV']
		df_eqn.loc[c, ['tag','FBA_name','dir','enz_id']] = [tag,rxn.id,dir,enz_id]

# Reactions that are not exchange reactions
for i in df_enz.index:
	rxn_id = df_enz.id[i]
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(rxn_id)
	
	if rxn_base_id[:3] == 'EX_':
		continue
	
	c += 1
	rxn_base = model.reactions.get_by_id(rxn_base_id)
	
	met_dict = metabolites_dict_from_reaction_equation_RBA(rxn_base.reaction)
	met_dict = {k:v for k,v in met_dict.items() if k != ''}
	met_dict = {'MET-' + k:v for k,v in met_dict.items()}
	if rxn_dir == 'REV':
		met_dict = {k:-v for k,v in met_dict.items()}
	elif rxn_dir == 'FWD':
		None
	else:
		print("Unknown ID that indicate reaction direction, only accepting 'FWD' and 'REV'")
	
	if enz_id not in spont_GPRs:
		df_eqn.loc[c, 'coupling_type'] = 'rxn_enz'
		df_eqn.loc[c, 'coupling_species'] = enz_id
	
	df_eqn.loc[c, 'id'] = rxn_id
	df_eqn.loc[c, 'type'] = 'metabolic'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(met_dict, arrow='-->')
	df_eqn.loc[c, ['tag','FBA_name','dir','enz_id']] = [tag,rxn_base_id,rxn_dir,enz_id]
	
### Enzyme synthesis network reaction
enz_stoich = OrderedDict()
for i in df_enz.index:
	enz_stoich[df_enz.enz[i]] = df_enz.protein_stoich[i]

c = df_eqn.shape[0] - 1
for enz_id,prot_str in enz_stoich.items():
	if prot_str == 'zeroCost':
		continue
	
	c += 1
	prot_str = prot_str.split(',')
	coeffs = OrderedDict({'PTMPRO-' + i.split(':')[0]:-int(i.split(':')[1]) for i in prot_str})
	coeffs['ENZ-' + enz_id] = 1
	
	df_eqn.loc[c, 'id'] = 'ENZSYN-' + enz_id
	df_eqn.loc[c, 'type'] = 'enzyme'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(coeffs, arrow='-->')

#these ENZLOAD equations also need to have their MW listed in the enz_mw_g_per_mmol file
#initialize an enzload sting
enzload_str = ""
for i in df_enz.index:
	if df_enz.protein_stoich[i] == 'zeroCost':
		continue
		
	c += 1
	coeffs = OrderedDict()
	coeffs['ENZ-' + df_enz.enz[i]] = -1

	enzload_id = 'ENZLOAD-' + df_enz.id[i][4:]

	#for debugging, comment out if unused
	#print("i: ",i,"\tenzload_id: ", enzload_id)
	
	df_eqn.loc[c, 'id'] = enzload_id
	df_eqn.loc[c, 'type'] = 'enzymeRxnLoad'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(coeffs, arrow='-->')

	#get the associated mw
	enz_mw = getattr(df_enz,"MW (g/mmol)")[i]

	new_line = enzload_id + "\t" + str(enz_mw) + "\n"
	enzload_str = enzload_str + new_line

# write the file resulting from enzload_str
with open('./model/enz_mw_g_per_mmol.txt', 'w') as f:
	f.write(enzload_str)
with open('../input/enz_mw_g_per_mmol.txt', 'w') as f:
	f.write(enzload_str)

### Ribosome
ribo_subunits = {}
c = df_eqn.shape[0] - 1
for rna in df_rnas.index:
	c += 1
	rna_stoich = OrderedDict({i:0 for i in ['MET-'+rna, 'MET-atp_c', 'MET-ctp_c',
											'MET-gtp_c', 'MET-utp_c', 'MET-ppi_c']})
	rna_stoich['RIBO-'+rna] = 1
	rna_stoich['MET-atp_c'] = -int(df_rnas.A[rna])
	rna_stoich['MET-ctp_c'] = -int(df_rnas.C[rna])
	rna_stoich['MET-gtp_c'] = -int(df_rnas.G[rna])
	rna_stoich['MET-utp_c'] = -int(df_rnas.U[rna])
	rna_stoich['MET-ppi_c'] = int(df_rnas.loc[rna, ['A','C','G','U']].sum())
	rna_stoich['BIO-rrna'] = df_rnas.loc[rna, 'MW (g/mmol)']
	
	df_eqn.loc[c, 'id'] = 'RIBOSYN-' + rna
	df_eqn.loc[c, 'type'] = 'ribosome'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(rna_stoich, arrow='-->')
	gene_expression_dict.setdefault(rna, []).append(df_eqn.loc[c, 'id'])
with open('./model/prosyn_ribo_subunits.txt', 'w') as f, open('./model/pro_ribo_subunits.txt', 'w') as f2, open('./model/kribo.txt', 'w') as f4, open('./model/j_ribo.txt', 'w') as f5, open('./model/ribosomes.txt', 'w') as f6:
	for file in [f,f2,f4,f5,f6]: file.write('/')
	for loc, ribo in ribo_dict.items():
		## proteins into ribosome subunits (to account for paralogs)
		ribo_stoich = OrderedDict()
		# if only 1 ribosome is present, all rRNAs are used
		rnas = [item for item in df_rnas.index if item.endswith(loc) or len(ribo_dict.keys()) == 1]
		# assume 1 of each rRNA and protein is used per ribosome
		for i in ribo.index:
			if ribo.id[i] in ribo_subunits:
				ribo_subunits[ribo.id[i]].append(loc[1:])
			else:
				ribo_subunits[ribo.id[i]] = [loc[1:]]
			if ribo.id[i] in rnas:
				ribo_stoich['RIBO-' + ribo.id[i]] = -1
			else:
				f.write("\n'"+loc[1:]+"'.'PROSYN-"+ribo.id[i]+"'")
				f2.write("\n'"+loc[1:]+"'.'"+ribo.id[i]+"'")
				# if it's not a paralog of another protein, all paralogs between it and the next non-paralog are treated as paralogs
				if pd.isnull(ribo.paralog[i]):
					ribosub_name = 'RIBOSUB-' + ribo.id[i]
				# add rxn converting the protein into the ribosome subunit (RIBOSUB prefix)
				c += 1
				ribosub_stoich = OrderedDict()
				ribosub_stoich['PTMPRO-' + ribo.id[i]] = -1
				ribosub_stoich[ribosub_name] = 1
				df_eqn.loc[c, 'id'] = 'RIBOSUBSYN-' + ribosub_name + '-FROM-' + ribo.id[i]
				df_eqn.loc[c, 'type'] = 'ribosome-subunit'
				df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(ribosub_stoich, arrow='-->')
				# add the ribosome subunit to the ribosome
				ribo_stoich[ribosub_name] = -1
		# making the ribosome itself from the subunits
		c += 1
		df_eqn.loc[c, 'id'] = 'RIBOSYN-ribonuc' if loc == '_c' else 'RIBOSYN-ribomito' if loc == '_m' else 'RIBOSYN-ribo'+loc[1:]
		# add to ribosome files
		ribo_id = "'"+loc[1:]+"'"
		f6.write('\n'+ribo_id); f5.write('\n'+ribo_id+".'"+df_eqn.loc[c, 'id']+"'"); f4.write('\n'+ribo_id+' '+str(kribo_default))
		df_eqn.loc[c, 'type'] = 'ribosome'
		df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(ribo_stoich, arrow='-->')
	for file in [f,f2,f4,f5,f6]: file.write('\n/')
# write the ribosome subunit stoichiometry to a json file
with open('./model/ribo_subunits.json', 'w') as f:
	json.dump(ribo_subunits, f)

# %% [markdown]
# #### Build files related to MW

# %%
data = getattr(df_pro,'MW (g/mmol)').to_dict()
ids = getattr(df_pro,'id').to_list()

#build the string to write
prot_mw_str = ""

#for each id
for id in ids:
	new_line = id + "\t" + str(data[id]) + "\n"
	prot_mw_str = prot_mw_str + new_line
# add dummy proteins to the string
for prot in dummy_list:
	new_line = prot["name"].replace('PROSYN-','') + "\t" + str(prot["MW"]) + "\n"
	prot_mw_str = prot_mw_str + new_line

#write to output
with open('./model/pro_mw_g_per_mmol.txt', 'w') as f:
	f.write(prot_mw_str)
with open('../input/pro_mw_g_per_mmol.txt', 'w') as f:
	f.write(prot_mw_str)

# %%
#TEST: this whole block. get MW list
mw_list = getattr(df_enz,"MW (g/mmol)").to_list()

#get enz list
enz_list = getattr(df_enz,"enz").to_list()

#create string for writing output file
enz_mw_str = "enz_id\tMW (g/mmol)\n"

#add to the string for enzyme entries
#need to initialize a counter
c = 0

#list to keep track of existing entries
#predefined values prevent adding unknown
existing_pro = ['nan','unknown']

for enz in enz_list:

	#only add a new line if unique entry
	if not(str(enz) in existing_pro):

		#for debugging, comment out if unused
		#print("enz: |",enz,"|, type: ",type(enz))
	
		new_line = str(enz) + "\t" + str(mw_list[c]) + "\n"

		#for debugging, comment out if unused
		#print(new_line)

		enz_mw_str = enz_mw_str + new_line

		existing_pro.append(enz)

	c = c + 1

#write to output
with open('../input/enz_mw_g_per_mmol_norxnmapped.txt', 'w') as f:
	f.write(enz_mw_str)

# %% [markdown]
# #### Protein file

# %%
### Protein

pro_lengths = dict()

c = df_eqn.shape[0] - 1
translation_loci = set()
unknown_ribo_prosyn = set()
protein_functions = dict()

def edit_stoich(stoich:OrderedDict,edits):
	if not pd.isna(edits):
		cofs_st = edits.split(',')
		cofs_st = OrderedDict({c.split(':')[0]:c.split(':')[1] for c in cofs_st})
		for k,v in cofs_st.items():
			stoich['MET-'+k] = -int(v)
	return stoich

for i in df_pro.index: 
	c += 1
	pro_id = df_pro.loc[i, 'id'] if 'id' in df_pro.columns else i
	prepro = 'PRO-' + str(pro_id) # preprotein (from translation)
	prot = 'PTMPRO-' + str(pro_id) # protein after post-translational modifications (PTMs)

	trans_st = OrderedDict()
	PTM_st = OrderedDict({prepro:-1,prot:1})
	for met in ['MET-atp_c', 'MET-h2o_c',
				'MET-adp_c', 'MET-pi_c', 'MET-h_c', 'MET-gtp_c',
				'MET-gdp_c']:
		trans_st[met] = 0
	seq = df_pro.sequence[i].replace("*","")

	trans_st = edit_stoich(trans_st,df_pro.trans_stoich_edits[i])
	PTM_st = edit_stoich(PTM_st,df_pro.PTM_stoich_edits[i])

	pro_lengths[i] = len(seq)
	for aa in df_aamap.index:
		trans_st[df_aamap.tRNA_in[aa]] = -seq.count(aa)
		trans_st[df_aamap.tRNA_out[aa]] = seq.count(aa)
				
	trans_st[prepro] = 1
	df_eqn.loc[c, 'coupling_type'] = 'prot_ribo'
	df_eqn.loc[c, 'coupling_species'] = 'ribo'
	
	# protein will occupy cellular space in its specific compartment
	if df_pro.subloc_assigned[i] in mito_compartments:
		trans_st['BIO-protmito'] = df_pro.loc[i, 'MW (g/mmol)']
	else:
		trans_st['BIO-protcyt'] = df_pro.loc[i, 'MW (g/mmol)']
	
	# Cost: Initiation: 1 ATP + 2 GTP (initiate and bind Methionine)
	for met in ['MET-atp_c', 'MET-h2o_c']:
		trans_st[met] -= 1
	for met in ['MET-adp_c', 'MET-pi_c', 'MET-h_c']:
		trans_st[met] += 1
				
	# Elongation: 2 GTP / cycle (2(n-1) cycles for n amino acids + 2 GTP from initiation = 2n GTP consumed so far)
	# (elongation process excludes Methionine since it is already bound in initiation process)
	# Termination and recycling: 1 GTP + 1 ATP: https://doi.org/10.1534/genetics.115.186221
	# 	However, we exclude these costs since it's not always required (e.g., via "leaky scanning"): https://doi.org/10.1093/nar/gkp765
	for met in ['MET-gtp_c', 'MET-h2o_c']:
		trans_st[met] -= 2*len(seq)
	for met in ['MET-gdp_c', 'MET-pi_c', 'MET-h_c']:
		trans_st[met] += 2*len(seq)
	
	df_eqn.loc[c, 'id'] = 'PROSYN-' + df_pro.id[i]

	# add translation rxn to gene_expression_dict list, or create a new list if it doesn't exist
	gene_expression_dict.setdefault(df_pro.gene_src[i], []).append(df_eqn.loc[c, 'id'])

	# add to protein functions dictionary under its gene_src
	protein_functions.setdefault(df_pro.gene_src[i], {})[df_pro.id[i]] = {}
	df_eqn.loc[c, 'type'] = 'protein'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(trans_st, arrow='-->')
	# Set ribosome translating the protein
	if df_pro.loc[i, 'translation_loc'] in ['unknown','any']:
		unknown_ribo_prosyn.add("'"+df_eqn.loc[c, 'id']+"'")
	else:
		translation_loci.add("'"+df_pro.loc[i, 'translation_loc']+"'.'"+df_eqn.loc[c, 'id']+"'")
	# add PTM reaction
	c += 1
	df_eqn.loc[c, 'id'] = 'PTM-' + df_pro.id[i]
	df_eqn.loc[c, 'type'] = 'proteinPTM'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(PTM_st, arrow='-->')
# write the protein length file
len_str = "/\n"
for prot in pro_lengths:
	len_str = len_str + "'PROSYN-" + prot + "' " + str(pro_lengths[prot]) + "\n"
for prot in dummy_list:
	len_str += "'" + prot["name"] + "' " + str(prot["medianL"]) + "\n"
len_str = len_str + "/"
with open('./model/RBA_proteinLength.txt', 'w') as f:
	f.write(len_str)

### Dummy protein
for prot in dummy_list:
	dummy_MW = prot["MW"]
	trans_st = make_dummy_protein_stoich(aa_standards_df=df_aamap, prot_df=prot["df"], length=prot["medianL"], rxn_name=prot["name"], mw=dummy_MW)

	c += 1
	# prot_st["BIO-protdummy"] = prot["MW"]
	df_eqn.loc[c, 'id'] = prot["name"]
	df_eqn.loc[c, 'coupling_type'] = 'prot_ribo'
	df_eqn.loc[c, 'coupling_species'] = 'ribo' #TEST: Update for ribonuc, ribomito, and other ribo types
	df_eqn.loc[c, 'type'] = 'protein'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(trans_st,
															arrow='-->', floatdecimal=6)
	if prot["translation_loc"] in ['unknown','any']:
		unknown_ribo_prosyn.add("'"+df_eqn.loc[c, 'id']+"'")
	else:
		translation_loci.add("'"+df_eqn.loc[c, 'id']+"'.'"+df_eqn.loc[c, 'id']+"'")

# Protein waste reactions
c = df_eqn.shape[0] - 1
with open('./model/pro_syn_waste.txt', 'w') as f:
	f.write('/')
	for i in df_pro.index: 
		for abbv,tag in {'':'PROSYN','PTM':'PTM'}.items():
			c += 1
			pro=abbv+'PRO-'+df_pro.id[i]
			new_st = OrderedDict()
			new_st[pro] = -1
			# add the protein's MW as the coefficient for BIO-protwasted
			new_st['BIO-protwasted'] = df_pro.loc[i, 'MW (g/mmol)']
			
			pw_id = f"{abbv}PROWASTE-{df_pro.id[i]}"
			f.write(f"\n'{tag}-{df_pro.id[i]}'.'{pw_id}'")

			df_eqn.loc[c, 'id'] = pw_id
			df_eqn.loc[c, 'type'] = 'proteinWaste'
			df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA(new_st, arrow='-->')

	f.write('\n/')
# Pseudoreaction representing mass of waste protein (for kapps): PROWASTE-TOTALPROTEIN
c += 1
df_eqn.loc[c, 'id'] = 'PROWASTE-TOTALPROTEIN'
df_eqn.loc[c, 'type'] = 'proteinWaste'
df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA({'BIO-protwasted':-1}, arrow='-->')
for loc in ['modeled','dummy','cyt','mito']: # add PROWASTE rxns for biomass-related byproduct of PROSYN rxns, to support simulations at 0 growth
	c += 1
	df_eqn.loc[c, 'id'] = 'PROWASTE-PROT'+loc.upper()
	df_eqn.loc[c, 'type'] = 'proteinWaste'
	df_eqn.loc[c, 'reaction'] = build_reaction_equation_from_metabolites_dict_RBA({'BIO-prot'+loc:-1}, arrow='-->')

### Write translation localization lists
with open('./model/translation.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(list(translation_loci)) + ['/']))
with open('./model/translated_by_any_ribo.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(list(unknown_ribo_prosyn)) + ['/']))

### Biomass
for i in df_biom.index:
	c += 1
	if not pd.isna(df_biom.rxn_id[i]):
		df_eqn.loc[c, 'id'] = df_biom.rxn_id[i]
		df_eqn.loc[c, 'type'] = 'biomass'
		df_eqn.loc[c, 'reaction'] = df_biom.rxn_equation[i]
# make into file RBA_rxns_whole_biomass.txt
with open('./model/RBA_rxns_whole_biomass.txt', 'w') as f:
	# find whole_biomass_rxns in df_eqn and write them to file
	f.write('\n'.join(['/'] + [i for i in whole_biomass_rxns if i in df_eqn.id.to_list()] + ['/']))

# %%
for k,v in gene_expression_dict.items():
	# check for entries in v starting with "'RIBO"
	if any([i.startswith("'RIBO") for i in v]):
		print(f"Warning: {k} has entries starting with 'RIBO' in gene_expression_dict")

# %%
# save gene list to file
with open('./model/genes.txt', 'w') as f:
	f.write('\n'.join(['/'] + [f"'{i}'" for i in genes] + ['/']))
for gene in genes:
	if gene not in gene_expression_dict:
		gene_expression_dict[gene] = []
# remove duplicates from gene_expression_dict, preserve order
gene_expression_dict = {k: list(dict.fromkeys([f"'{i}'" for i in v])) for k, v in gene_expression_dict.items()}
# save gene-protein mapping to file
with open('./model/genes_expression.txt', 'w') as f:
	f.write('\n'.join(['/'] + [f"'{gene}'.({','.join(gene_expression_dict[gene])})" for gene in genes if gene_expression_dict[gene]] + ['/']))

# %%
# make extra kapp calculation files
directory = '../GAMS/parameterization/enz_from_proteome'
if not os.path.exists(directory):
	os.makedirs(directory)

with open(directory + '/pro_and_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(list(set(["'ENZ-" + i + "'" for i in enz_list] + ["'PTMPRO-" + i + "'" for i in df_pro.index]))) + ['/']))

# %% [markdown]
# #### Save excel files

# %%
df_eqn.to_csv('./model/RBA_stoichiometry.tsv', sep='\t', index=None)

# %% [markdown]
# # Build GAMS Sij and flux bounds (originally A02_build_GAMS_Sij_and_fluxBounds.ipynb)

# %% [markdown]
# #### Load excel file

# %%
df_eqn = read_spreadsheet('./model/RBA_stoichiometry.tsv')

# %% [markdown]
# #### Assemble list of species

# %%
met_list_raw = []
for i in df_eqn.index:
	met_dict = metabolites_dict_from_reaction_equation_RBA(df_eqn.reaction[i])
	met_list_raw += met_dict.keys()

met_list = sorted(list(set(met_list_raw)))
met_list = [i for i in met_list if i != '']
with open('./model/RBA_species.txt', 'w') as f:
	f.write('\n'.join(['/'] + ["'" + i + "'" for i in met_list] + ['/']))
# add list of demand rxns for each metabolite (for testing purposes)
demand_list = ["DM-" + i for i in met_list]
# WIP: add to df_eqn
with open('./model/RBA_rxns_demand.txt', 'w') as f:
	f.write('\n'.join(['/'] + ["'DM-" + i + "'" for i in met_list] + ['/']))

# %% [markdown]
# #### Assemble list of reactions

# %%
rxn_list = df_eqn.id.to_list()
rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of uptake reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(i)
	if tag == 'RXN' and rxn_base_id[:3] == 'EX_' and rxn_dir == 'REV':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_EXREV.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of secretion reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(i)
	if tag == 'RXN' and rxn_base_id[:3] == 'EX_' and rxn_dir == 'FWD':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_EXFWD.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of protein waste reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag in ['PROWASTE','PTMPROWASTE']:
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_prowaste.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of enzyme syn reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag == 'ENZSYN':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_enzsyn.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %% [markdown]
# #### Get list of enzyme load reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag == 'ENZLOAD':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
# list created so GAMS knows which ENZLOAD corresponds to which rxn
rxn_enzload_coupling_list = [i + '.' + i.replace('ENZLOAD-','RXN-') + ' 1' for i in rxn_list]
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_enzload.txt', 'w') as f:
	f.write('\n'.join(rxn_list))
with open('./model/RBA_rxn_enzload_coupling.txt', 'w') as f:
	f.write('\n'.join(['/'] + rxn_enzload_coupling_list + ['/']))

# %% [markdown]
# #### Get list of metabolic network reactions

# %%
rxn_list = []
for i in df_eqn.id:
	tag = i.split('-')[0]
	if tag == 'RXN':
		rxn_list.append(i)

rxn_list = ["'" + i + "'" for i in rxn_list if i != '']
rxn_list = ['/'] + rxn_list + ['/']

# %%
with open('./model/RBA_rxns_rxnmetabolicnetwork.txt', 'w') as f:
	f.write('\n'.join(rxn_list))

# %%
# Make k_app (enzyme turnover rate) file draft using placeholder values
kapp_list = []
kapp_list = [i + " 360000" for i in rxn_list if i != '/']
kapp_list = ['/'] + kapp_list + ['/']
with open('./model/kapp_placeholders.txt', 'w') as f:
	f.write('\n'.join(kapp_list))

# %% [markdown]
# #### Assemble stoichiometry

# %%
# make extra kapp calculation files
directory = '../GAMS/parameterization/enz_from_proteome/'
if not os.path.exists(directory):
	os.makedirs(directory)

sij = []
rxns_enz = []
rxns_proenz = []
sij_proenz = []

for i in df_eqn.index:
	x = metabolites_dict_from_reaction_equation_RBA(df_eqn.reaction[i])
	met_dict = dict()
	for k,v in x.items():
		if k == '':
			continue
		# note when a protein is used in a reaction other than its PROWASTE and production reactions
		met = k.split('-',1)[1]
		if k.startswith('PTMPRO-') and df_eqn.id[i] not in ['PTMPROWASTE-' + met,'PTM-' + met]:
			for gene,prots in protein_functions.items():
				if met in prots:
					protein_functions[gene][met].update({df_eqn.id[i]:v})
					break
		if v.is_integer():
			met_dict[k] = int(v)
		else:
			met_dict[k] = v
			
	if df_eqn.id[i].startswith("ENZ") or df_eqn.id[i].startswith("PROSYN"):
		rxns_proenz.append("'" + df_eqn.id[i].replace('PROSYN-','PROIN-') + "'")
		if df_eqn.id[i].startswith("ENZ"):
			rxns_enz.append("'" + df_eqn.id[i] + "'")
		# sij.append("'" + df_eqn.id[i] + "'.'" + df_eqn.id[i] + "' 1")
		for k,v in met_dict.items():
			sij.append("'" + k + "'.'" + df_eqn.id[i] + "' " + str(v))
			if k.startswith('PTMPRO-') or k.startswith('ENZ-'):
				sij_proenz.append("'" + k + "'.'" + df_eqn.id[i].replace('PROSYN-','PROIN-') + "' " + str(v))
	else:
		for k,v in met_dict.items():
			sij.append("'" + k + "'.'" + df_eqn.id[i] + "' " + str(v))
	
sij = ['/'] + sij + ['/']
with open('./model/RBA_sij.txt', 'w') as f:
	f.write('\n'.join(sij))
# write protein functions to file
with open('./protein_functions.json', 'w') as f:
	json.dump(protein_functions, f)
# make set of all proteins in protein_functions with no modeled functions
proteins_without_modeled_functions = set()
# identify them by checking if all values within values are empty
for gene,prots in protein_functions.items():
	for prot,funcs in prots.items():
		# if all values are empty, add to set
		if not any(funcs.values()):
			proteins_without_modeled_functions.add(prot)
with open('./proteins_without_modeled_functions.txt', 'w') as f:
	f.write('\n'.join(sorted(list(proteins_without_modeled_functions))))
with open(directory + 'rxns_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(rxns_enz) + ['/']))
with open(directory + 'rxns_pro_and_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(rxns_proenz) + ['/']))
with open(directory + 'sij_pro_and_enz.txt', 'w') as f:
	f.write('\n'.join(['/'] + sij_proenz + ['/']))

# %% [markdown]
# # Build GAMS RBA constraints (originally A03_build_GAMS_RBA_constraints.ipynb)

# %%
#### LOAD INPUTS AND PARAMETERS
copy_to_gams = True # if True, copy the model to the gams folder

# Stoichiometry
df_stoich = read_spreadsheet('./model/RBA_stoichiometry.tsv')
df_stoich.index = df_stoich.id.to_list()

# %%
### Write prosyn reaction
idx = [i for i in df_stoich.index if i[:7] == 'PROSYN-']
prosyn = ["'" + i + "'" for i in idx]
prosyn = ['/'] + prosyn + ['/']
with open('./model/RBA_rxns_prosyn.txt', 'w') as f:
	f.write('\n'.join(prosyn))
## write ribosyn set
idx = [i for i in df_stoich.index if i[:8] == 'RIBOSYN-']
ribosyn = ["'" + i + "'" for i in idx]
ribosyn = ['/'] + ribosyn + ['/']
with open('./model/RBA_rxns_ribosyn.txt', 'w') as f:
	f.write('\n'.join(ribosyn))

# %%
# Make fwd and reversible rxn list for metabolic network and all rxns (not needed but helpful for testing)
# Also, make flux coupling analysis file in case you use that for testing

# Using Patrick's FCA code
rxn_types = {'irrev': 0, 'reversible-fwd-half': 1, 'reversible-rev-half': 2, 'pseudoreaction': 3, 'exchange-fwd-half': 4, 'exchange-rev-half': 5}

rev_rxn_list = []; rev_list = []
fwd_rxn_list = []; fwd_list = []
fca_list = []

for i in df_stoich.id:
	tag,rxn_base_id,rxn_dir,enz_id = extract_details_from_rxnid(i)
	#print("'"+i+"' "+str(rxn_types['irrev']))
	#print(rxn_base_id)
	#print(i,'\t',tag,'\t',rxn_dir)
	if rxn_dir == 'FWD':
		fwd_list.append(i)
		if tag == 'RXN':
			fwd_rxn_list.append(i)
		if rxn_base_id[:3] == 'EX_':
			fca_list.append("'"+i+"' "+str(rxn_types['exchange-fwd-half']))
		# Add as irreversible if no counterpart found in other direction
		elif i.replace("_FWD-","_REV-") not in df_stoich.id:
			fca_list.append("'"+i+"' "+str(rxn_types['irrev'])) 
		else:
			fca_list.append("'"+i+"' "+str(rxn_types['reversible-fwd-half']))
	elif rxn_dir == 'REV':
		rev_list.append(i)
		if tag == 'RXN':
			rev_rxn_list.append(i)
		if rxn_base_id[:3] == 'EX_':
			fca_list.append("'"+i+"' "+str(rxn_types['exchange-rev-half']))
		# Add as irreversible if no counterpart found in other direction
		elif i.replace("_REV-","_FWD-") not in df_stoich.id:
			fca_list.append("'"+i+"' "+str(rxn_types['irrev'])) 
		else:
			fca_list.append("'"+i+"' "+str(rxn_types['reversible-rev-half']))
	else:
		fca_list.append("'"+i+"' "+str(rxn_types['irrev'])) 

fwd_rxn_list = ["'" + i + "'" for i in fwd_rxn_list if i != '/']
fwd_rxn_list = ['/'] + fwd_rxn_list + ['/']
with open('./model/RBA_rxns_rxnmetabolicnetworkFWD.txt', 'w') as f:
	f.write('\n'.join(fwd_rxn_list))
rev_rxn_list = ["'" + i + "'" for i in rev_rxn_list if i != '/']
rev_rxn_list = ['/'] + rev_rxn_list + ['/']
with open('./model/RBA_rxns_rxnmetabolicnetworkREV.txt', 'w') as f:
	f.write('\n'.join(rev_rxn_list))

fwd_list = ["'" + i + "'" for i in fwd_list if i != '/']
fwd_list = ['/'] + fwd_list + ['/']
with open('./model/RBA_rxns_FWD.txt', 'w') as f:
	f.write('\n'.join(fwd_list))
rev_list = ["'" + i + "'" for i in rev_list if i != '/']
rev_list = ['/'] + rev_list + ['/']
with open('./model/RBA_rxns_REV.txt', 'w') as f:
	f.write('\n'.join(rev_list))

fca_list = ['/'] + fca_list + ['/']
with open('./model/rxntype.txt', 'w') as f:
	f.write('\n'.join(fca_list))

# %%
# creating set pairing SM values w/ RBA ones, for use in converting flux constraints from SM format to RBA

# filter out rxns with no FBA_name
df_sm = df_stoich[df_stoich.FBA_name.notnull()]
# get SM rxn IDs from FBA_name column
sm_rxn_ids = df_sm.FBA_name.to_list()
# get RBA rxn IDs from index
rba_rxn_ids = df_sm.index.to_list()
rba_rxn_dirs = [extract_details_from_rxnid(i)[2] for i in rba_rxn_ids]
# convert dir to -1 if rev, 1 otherwise
rba_rxn_dirs = [-1 if i == 'REV' else 1 for i in rba_rxn_dirs]
# create list of strings pairing SM rxn IDs with RBA rxn IDs
sm_rba_rxn_pairs_dict = {rba_rxn_ids[i]:sm_rxn_ids[i] for i in range(0, len(sm_rxn_ids))}
# save as JSON file
with open('./model/SM_RBA_rxn_pairs.json', 'w') as f:
	json.dump(sm_rba_rxn_pairs_dict, f)
sm_rba_rxn_pairs = ["'"+sm_rxn_ids[i]+"'.'"+rba_rxn_ids[i]+"'"+' '+str(int(rba_rxn_dirs[i])) for i in range(0, len(sm_rxn_ids))]
# convert SM rxn bounds to RBA format; for each sm rxn, get the corresponding rba rxn and its direction
with open('./model/SM_rxn_bounds.txt', 'w') as f:
	delim = ' '
	sm_rxns_checked = []
	# find longest rxn ID for formatting purposes
	max_sm_rxn_id_len = max([len(i)+2 for i in sm_rxn_ids])+1
	max_lb_len = max([len(str(rxn.lower_bound)) for rxn in model.reactions if rxn.id in sm_rxn_ids])+1
	max_ub_len = max([len(str(rxn.upper_bound)) for rxn in model.reactions if rxn.id in sm_rxn_ids])
	# write headers to file, with ljust
	f.write(f"{'':>{max_sm_rxn_id_len}}{'lo':>{max_lb_len}}{' up':<{max_ub_len}}")
	for rba_rxn,sm_rxn in sm_rba_rxn_pairs_dict.items():
		# find bounds of sm rxn in model
		rxn = model.reactions.get_by_id(sm_rxn)
		ub = rxn.upper_bound
		lb = rxn.lower_bound

		if sm_rxn not in sm_rxns_checked:
			sm_rxns_checked.append(sm_rxn)
			name=f"'{sm_rxn}'"
			# make string with SM rxn ID, lb, and ub, using max lengths for formatting
			f.write(f"\n{name:>{max_sm_rxn_id_len}}{str(lb):>{max_lb_len}} {str(ub):<{max_ub_len}}")
# write to file
with open('./model/SM_RBA_rxn_pairs.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(sm_rba_rxn_pairs) + ['/']))
# make file w/ all FBA IDs
with open('./model/SM_rxn_ids.txt', 'w') as f:
	f.write('\n'.join(['/'] + sorted(["'"+i+"'" for i in set(sm_rxn_ids)]) + ['/']))

# %%
# make file for all formula weights (some may be inaccurate due to R groups and other non-standard groups)
with open('./model/formula_weights.txt','w') as f:
	f.write('/\n')
	for met in model.metabolites:
		# write met name, formula, and formula weight
		try:
			formula = str(met.formula)
			mw = str(met.formula_weight)
		except:
			mw = 'unknown'
			formula = 'unknown'
		f.write(str(met.id) + '\t' + formula + '\t' + mw + '\n')
	f.write('/')
# Out:
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'R' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'Tr' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'X' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")
# /Applications/anaconda3/envs/rba/lib/python3.9/site-packages/cobra/core/metabolite.py:191: UserWarning: The element 'Fd' does not appear in the periodic table
#   warn(f"The element {e} does not appear in the periodic table")

# %%
# for AA in df_aamap, find all mets in met_list that match its name (without the location)
with open('./model/aa.txt', 'w') as f, open('./model/tRNAs.txt', 'w') as f2:
	fis = [f,f2]
	for fi in fis: fi.write('/')
	for aa in df_aamap.index:
		aa_mets = [f"'{met}'" for met in met_list if met.rsplit('_',1)[0] == df_aamap.tRNA_in[aa].rsplit('_',1)[0]]
		f.write(f"\n'{aa}'")
		if aa_mets:
			f2.write(f"\n'{aa}'.({','.join(aa_mets)})")
	for fi in fis: fi.write('\n/')

# %%
# write combinations of gene_src and protein IDs in form 'gene_src'.('protein1','protein2',...)
with open('./model/proteins_and_locations.txt', 'w') as f, open('./model/proteins.txt', 'w') as f2:
	fis = [f,f2]
	for fi in fis: fi.write('/')
	for gene,prots in protein_functions.items():
		prots_str = ','.join([f"'PROSYN-{prot}'" for prot in prots])
		f.write(f"\n'{gene}'.({prots_str})")
		f2.write(f"\n'{gene}'")
	for fi in fis: fi.write('\n/')

# %%
if copy_to_gams: # automatically copies the model folder to the GAMS folder (removing the previous version), if you choose to
	import shutil
	# copy "model" folder to GAMS folder
	# Source folder path
	source_folder = './model'

	# Destination folder path
	destination_folder = '../GAMS/model'

	# Remove the existing destination folder
	shutil.rmtree(destination_folder)

	# Copy the folder
	shutil.copytree(source_folder, destination_folder)
